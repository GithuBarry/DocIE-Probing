# %%
import json
import re
from collections import Counter
from collections import defaultdict
from itertools import combinations
from multiprocessing import Pool, cpu_count

import nltk
import spacy
from tqdm.auto import tqdm

# %%
dataset_name = "wikievents"
wikievents246_input = open("../../Corpora/WikiEvents/gtt_format/all-test-dev-train.jsonl")
examples = [json.loads(l) for l in wikievents246_input.readlines()]
wikievents246_input.close()
example_len = 246
dev_start, test_start,train_start = 0, 20,40
type_to_roles =  json.load(open("../../Corpora/WikiEvents/gtt_format/EventTypeToRoles.json"))
types = [*type_to_roles.keys()]

# %%
def clean(string):
    string = string.lower()
    cleaned_string = re.sub(r'[^a-z]', '', string)
    return cleaned_string


def find_substring_indices(string, substring):
    indices = []
    length = len(substring)
    for i in range(len(string) - length + 1):
        if string[i:i + length] == substring:
            indices.append(i)
    return indices


def indices_in_tokenized_text(role_filler, tokens):
    cleaned_text = ""
    d = {}
    for i, token in enumerate(tokens):
        cleaned = clean(token)
        for ii in range(len(cleaned)):
            d[ii + len(cleaned_text)] = i
        cleaned_text += cleaned
    return [d[index] for index in find_substring_indices(cleaned_text, clean(role_filler))]


def flatten_list(nested_list):
    return [item for sublist in nested_list for item in
            (flatten_list(sublist) if isinstance(sublist, list) else [sublist])]


def generate_pairs(lists):
    pairs = set()
    for i in range(len(lists)):
        for j in range(i + 1, len(lists)):
            for elem1 in lists[i]:
                for elem2 in lists[j]:
                    if elem1 != elem2:
                        l = sorted([elem1, elem2])
                        pairs.add((l[0], l[1]))
    return pairs


def n_comb(l):
    return len(l) * (len(l) - 1) // 2
nlp = spacy.load("en_core_web_sm")

def is_not_pronoun(phrase):
    return phrase.lower().strip() not in {
        "he", "him", "his", "himself",
        "she", "her", "hers", 
        "it", "its", 
        "they", "them", "their", "theirs", "themselves",
        "we", "us", "our", "ours", "ourselves",
        "you", "your", "yours", "yourself", "yourselves",
        "one", "ones", "oneself",
        "who", "whom", "whose",
        "i", "me", "my", "mine", "myself", "that", "which", "some", "anyone", "those", "this", "these", "other", "another", "such", "each", "neither","both", "all"
    }
    doc = nlp(phrase)
    for token in doc:
        # Check if the token is a pronoun
        if token.text.lower() == "the":
            continue
        if token.pos_ == "PRON" or token.text.lower() in ["one", "ones"]:
            print(token)
            return False
    return True

# %%
example_template_entity_mentions = []
counts = defaultdict(lambda: 0)
mention_count = []
qualified_mention_count = []
coref_pairs = []
coref_negative_examples = []
coref_pairs_non_single_mention = []
coenv_positive_examples = []
coenv_negative_examples = []
event_typing_examples = []
roling_examples = []
all_role_examples = []
for ex in tqdm(examples):
    templates = ex['templates']
    text = ex['doctext']
    cleanedtext = clean(" ".join(text))
    template_of_entities = []
    flattened_list_all_templates = []
    per_example_coref_pairs = set()
    per_example_coref_pairs_non_single_mention = set()
    coref_negative_examples.append(set())
    coenv_positive_examples.append(set())
    event_typing_examples.append(set())
    roling_examples.append(set())
    coenv_negative_examples.append(set())
    list_of_mention_per_template = []
    for template in templates:
        flattened_list_within_template = []
        arguments = [l for l in template.values() if isinstance(l, list)]
        roles = type_to_roles[template['incident_type']]
        qualified_entities = []

        for role_index, role_fillers in enumerate(arguments):
            role = roles[role_index]
            list_of_entity_mentions = []
            for entity in role_fillers:
                qualified_mentions = []
                mentions_per_entity = []
                for mention_w_index in entity:
                    mention = mention_w_index[0]
                    if not is_not_pronoun(mention):
                        continue
                    #assert cleanedtext.count(clean(mention)) > 0
                    mentions_per_entity.append(mention)
                    roling_examples[-1].add((mention, role))
                    if cleanedtext.count(clean(mention)) == 1:
                        qualified_mentions.append(mention)
                        counts['qualified_mentions'] += 1

                        if mention in flattened_list_all_templates:
                            counts['duplicated qualified mention across templates'] += 1
                        flattened_list_all_templates.append(mention)

                        if mention in flattened_list_within_template:
                            counts['duplicated qualified mention within templates'] += 1
                        flattened_list_within_template.append(mention)

                if len(qualified_mentions) > 0:
                    counts['qualified_entities'] += 1
                    qualified_entities.append(qualified_mentions)

                    per_example_coref_pairs = per_example_coref_pairs.union(
                        [p for p in list(combinations(qualified_mentions, 2)) if p[0] < p[1]])
                per_example_coref_pairs_non_single_mention = per_example_coref_pairs_non_single_mention.union(
                    [p for p in list(combinations(mentions_per_entity, 2)) if p[0] < p[1]])
                mention_count.append(len(mentions_per_entity))
                qualified_mention_count.append(len(qualified_mentions))
                list_of_entity_mentions.append(mentions_per_entity)
            coref_negative_examples[-1] = coref_negative_examples[-1].union(generate_pairs(list_of_entity_mentions))

        counts['qualified_coenv'] += n_comb(set(flattened_list_within_template))
        coenv_positive_examples[-1] = coenv_positive_examples[-1].union(
            ([p for p in list(combinations(flattened_list_within_template, 2)) if p[0] < p[1]]))
        event_typing_examples[-1] = event_typing_examples[-1].union(([p for p in [p + (types.index(template["incident_type"].split("/")[0].strip()),) for p in
                                                                                  combinations(flattened_list_within_template, 2)]
                                                                      if p[0] < p[1]]))
        list_of_mention_per_template.append(flattened_list_within_template)
        template_of_entities.append(qualified_entities)
    all_role_examples.append(flattened_list_all_templates)
    coenv_negative_examples[-1] = coenv_negative_examples[-1].union(generate_pairs(list_of_mention_per_template))
    counts['actual_coref_pairs'] += len(per_example_coref_pairs)
    coref_pairs.append(per_example_coref_pairs)
    counts['actual_coref_pairs_non_single'] += len(per_example_coref_pairs_non_single_mention)
    coref_pairs_non_single_mention.append(per_example_coref_pairs_non_single_mention)

    example_template_entity_mentions.append(template_of_entities)
# Out:
#   0%|          | 0/246 [00:00<?, ?it/s]

# %%
def get_named_entities(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    entities = []
    for ent in doc.ents:
        entities.append((ent.text, ent.label_))
    return entities


counts['ne'] = 0
id_to_tag = []

pool = Pool(cpu_count())
for named_entities in tqdm(pool.imap(get_named_entities, [ex['doctext'] for ex in examples]), total=example_len ):
    id_to_tag.append(named_entities)
    counts['ne'] += len(named_entities)
pool.close()
pool.join()
# Out:
#   0%|          | 0/246 [00:00<?, ?it/s]

# %%
ne_examples = [[p[0] for p in ex if p[1] in {"PERSON","ORG"}] for ex in id_to_tag]
ne_examples = [list(set(ex)) for ex in ne_examples]
sum([len(ex) for ex in ne_examples])
ne_neg_examples = [[n for n in ne_examples[i] if n not in " ".join(all_role_examples[i])] for i in range(len(ne_examples))]

# %%
ne_pos_examples = [list(set(ex)) for ex in all_role_examples]

# %%
ne_neg_examples[1]
# Out:
# ['Allah',
#  'Prophet Muhammad',
#  'Worlds',
#  'Court',
#  'Islam',
#  'The Prophet Muhammad']

# %%
roles,counts
# Out:
# (['Detainee', 'Place', 'Jailer'],
#  defaultdict(<function __main__.<lambda>()>,
#              {'qualified_mentions': 4467,
#               'qualified_entities': 3069,
#               'qualified_coenv': 3934,
#               'duplicated qualified mention across templates': 2132,
#               'actual_coref_pairs': 414,
#               'actual_coref_pairs_non_single': 3770,
#               'duplicated qualified mention within templates': 103,
#               'ne': 18110}))

# %%
Counter(mention_count)
# Out:
# Counter({16: 49,
#          6: 194,
#          9: 135,
#          2: 875,
#          1: 1899,
#          3: 505,
#          22: 43,
#          5: 296,
#          11: 83,
#          4: 346,
#          7: 153,
#          0: 99,
#          8: 152,
#          18: 34,
#          14: 38,
#          12: 80,
#          10: 119,
#          13: 52,
#          23: 2,
#          28: 19,
#          25: 7,
#          15: 92,
#          17: 39,
#          20: 45,
#          37: 7,
#          35: 14,
#          33: 4,
#          45: 1,
#          26: 3,
#          34: 10,
#          19: 14,
#          21: 4,
#          46: 11,
#          24: 35,
#          55: 11,
#          58: 17,
#          31: 6,
#          29: 18,
#          38: 5,
#          30: 17,
#          97: 3})

# %%
Counter(qualified_mention_count)
# Out:
# Counter({2: 573, 0: 2467, 1: 2177, 3: 202, 4: 65, 5: 34, 6: 18})

# %%
coref_pairs_nonempty = [coref_pairs[i] for i in range(len(coref_pairs)) if coref_pairs[i]]
coref_pairs_nonempty
# Out:
# [{('Amin', 'Milton J. Valencia')},
#  {('Chechen', 'immigrant'),
#   ('Dzhokhar Tsarnaev', 'immigrant'),
#   ('Karen Rand McWatters', 'friend'),
#   ('Patricia Campbell', 'mother')},
#  {('country', 'where')},
#  {('attacker', 'soldier')},
#  {('Boylston Street', 'thoroughfare'), ('Sean Collier', 'policeman')},
#  {('Both brothers', 'lifeguards'),
#   ('Ruger pistol', 'Ruger semi-automatic handgun'),
#   ('Ruger pistol', 'Ruger semi-automatic pistol'),
#   ('Ruger pistol', 'a gun'),
#   ('Ruger semi-automatic pistol', 'a gun'),
#   ('Sean Collier', 'officer'),
#   ('Stephen Silva', 'his close friend')},
#  {('Osama bin Laden', 'suspect')},
#  {('dead', 'victims')},
#  {('Bilal Mohammed', 'client')},
#  {('Nestor Reverol', 'minister')},
#  {('Birmingham Mail', 'Birmingham Post & Mail'),
#   ('Irishmen', 'bombers'),
#   ('group', 'organisation')},
#  {('Badia al-Sukhnah', 'spot'),
#   ('Badia al-Sukhnah', 'zone'),
#   ('Tass', 'agency'),
#   ('spot', 'zone')},
#  {('U.S. State Department', 'U.S. Treasury Department')},
#  {('Christophe Castaner', 'Minister'),
#   ('Islamic State', 'group'),
#   ('Rue Victor Hugo', 'street')},
#  {('Federal', 'Russian Federation'),
#   ('Moscow', 'Russian Federation'),
#   ('Republic of Dagestan', 'state'),
#   ('province', 'state')},
#  {('gunmen', 'insurgents')},
#  {('Alejandro Pérez', 'Brayan Oropeza'), ('Luis Guerra', 'Yanin Pernía')},
#  {('Tamerlan Tsarnaev', 'brother')},
#  {('Christophe Castaner', 'minister'), ('Chérif Chekatt', 'killer')},
#  {('Chinook', 'helicopter'),
#   ('aircraft', 'missiles'),
#   ('aircraft', 'unmanned aerial vehicles'),
#   ('chemicals', 'material'),
#   ('missiles', 'unmanned aerial vehicles')},
#  {('Zabiullah Mujahid', 'spokesperson')},
#  {('Central Hospital of Maracay', 'the Maracay Central Hospital')},
#  {('Antonio Durán', 'Vicente Sainz de la Peña'),
#   ('Antonio Durán', 'worker'),
#   ('Bernardo Badell', 'pilot'),
#   ('Carlos Arias Navarro', 'Minister'),
#   ('Eliseo Bayo', 'María Paz Ballesteros'),
#   ('Eliseo Bayo', 'actress'),
#   ('Eliseo Bayo', 'writer'),
#   ('María Paz Ballesteros', 'actress'),
#   ('María Paz Ballesteros', 'writer'),
#   ('Vicente Sainz de la Peña', 'worker'),
#   ('customers', 'employees')},
#  {('Azamat Tazhayakov', 'friends'), ('Azamat Tazhayakov', 'student')},
#  {("David D'Albini", 'manager')},
#  {('Terry Duffield', 'client')},
#  {('Timothy McVeigh', 'bomber'), ('co-conspirators', 'ilk')},
#  {('center', 'where')},
#  {('palco presidencial', 'the president')},
#  {('government', 'kingdom')},
#  {('home', 'house')},
#  {('Nicolas Maduro', 'the president')},
#  {('Islamists', 'perpetrators')},
#  {('attackers', 'hostage-takers')},
#  {('Joe Kebartas', 'resident'), ('Sean Collier', 'officer')},
#  {('Aaron Driver', 'Harun Abdurahman'), ('Strathroy', 'town')},
#  {('al-Qaeda', 'group')},
#  {('Boston Bomber', 'immigrant'),
#   ('Krystal Campbell', 'daughter'),
#   ('Lingzi Lu', 'student')},
#  {('driver', 'person')},
#  {('Centro Andino', 'mall'),
#   ('Iván Márquez', 'commander'),
#   ('José Aldemar Rojas Rodríguez', 'Mocho Kiko'),
#   ('José Aldemar Rojas Rodríguez', 'chief'),
#   ('José Aldemar Rojas Rodríguez', 'expert'),
#   ('José Aldemar Rojas Rodríguez', 'old'),
#   ('Mocho Kiko', 'expert'),
#   ('Mocho Kiko', 'old'),
#   ('chief', 'expert'),
#   ('chief', 'old'),
#   ('expert', 'old')},
#  {('Abdirahman Omar Osman', 'Mayor'),
#   ('al-Shabaab', 'group'),
#   ('bomber', 'herself')},
#  {('paramedics', 'services'), ('plaza', 'where')},
#  {('Teen', 'boy'), ('Teen', 'suspect'), ('boy', 'suspect')},
#  {('Armed Forces Recruiting Station', 'building'),
#   ('Gerald Koch', 'anarchist')},
#  {('Abu Mahdi al-Muhandis', 'chief')},
#  {('Azamat Tazhayakov', 'client'),
#   ('Azamat Tazhayakov', 'first'),
#   ('Azamat Tazhayakov', 'man'),
#   ('client', 'man'),
#   ('first', 'man')},
#  {('Terry Nichols', 'accomplice')},
#  {('IED', 'Improvised Explosive Device'), ('officers', 'policemen')},
#  {('Ahmad Khan Rahami', 'son')},
#  {('Michael Christopher Hayes', 'maker'),
#   ('Michael Christopher Hayes', 'volunteer'),
#   ('maker', 'volunteer')},
#  {('Accused Boston Bomber', 'client'),
#   ('Dzhokhar Tsarnaev', 'client'),
#   ('Krystle Campbell', 'manager'),
#   ('Lingzi Lu', 'student'),
#   ('United States', 'country')},
#  {('Ali Khamenei', 'Ayatollah')},
#  {('a car', 'vehicle'), ('station', 'train')},
#  {('Citi Plaza', 'mall')},
#  {('Nohad Machnouk', 'minister')},
#  {("King's Cross railway station", "King's Cross station"),
#   ('Provisional IRA', 'organization')},
#  {('Afghanistan', 'government'),
#   ('Bagram Air Base', 'airfield'),
#   ('attackers', 'insurgents')},
#  {('Commissioner', 'diplomat'),
#   ('Karachi', 'Sindh'),
#   ('Muhammad Raza', 'participant'),
#   ('Qari Saifullah', 'spokesperson'),
#   ('SMQureshiPTI', 'country'),
#   ('Thomas Drew CMG', 'diplomat')},
#  {('United States', 'abuser')},
#  {('Oscar Perez', 'lnspector')},
#  {('Bomber Tsarnaev', 'citizen'),
#   ('Bomber Tsarnaev', 'immigrant'),
#   ('Denise Richard', 'parents'),
#   ('Louis Jones', 'kidnapper'),
#   ('citizen', 'immigrant')},
#  {('Abdul Jabar Naeemi', 'governor'),
#   ('Mahbubullah Sayedi', 'chief'),
#   ('Noor Agha Faizi', 'spokesman')},
#  {('Alan Fry', 'Commissioner'), ('Alan Fry', 'head')},
#  {('Tamerlan (C) Tsarnaev', 'mastermind'), ('follower', 'mastermind')},
#  {('suspect', 'youth')},
#  {('Gen. Santander National Police Academy', 'establishment')},
#  {('El Mocho', 'member'),
#   ('El Mocho', 'suspect'),
#   ('José Aldemar Rojas Rodríguez', 'Kiko'),
#   ('José Aldemar Rojas Rodríguez', 'member'),
#   ('José Aldemar Rojas Rodríguez', 'suspect'),
#   ('Kiko', 'member'),
#   ('Kiko', 'suspect'),
#   ('expert', 'member'),
#   ('expert', 'suspect'),
#   ('itself it', 'terrorists')},
#  {('Jorge Rodríguez', 'Minister')},
#  {('country', 'government')},
#  {('Maxine', 'sister'), ('group Justice4the21', 'supporters')},
#  {('Bahrun Naim', 'mastermind'),
#   ('assailants', 'attackers'),
#   ('capital', 'city'),
#   ('government', 'nation')},
#  {('explosive device', 'such a bomb'), ('the van', 'vehicle')},
#  {('Dias Kadyrbayev', 'defendant')},
#  {('German man', 'main suspect'), ('Markus Beisicht', 'leader')},
#  {('Sean Collier', 'officer'),
#   ('Sean Collier', 'policeman'),
#   ('officer', 'policeman')},
#  {('American', 'government'),
#   ('Anwar al-Awlaki', 'cleric'),
#   ('James M. Branum', 'lawyer'),
#   ('Major', 'shooter'),
#   ('Naser Jason Abdo', 'Pfc'),
#   ('Naser Jason Abdo', 'client'),
#   ('bombs', 'dual')},
#  {('Oscar Perez', 'officer'),
#   ('attackers', 'the alleged conspirators'),
#   ('plotters', 'the alleged conspirators')},
#  {('bogey', 'compartments')},
#  {('Yasuo Yamamoto', 'resident')},
#  {('home', 'secretary')},
#  {('Farc', 'Revolutionary Armed Forces of Colombia'),
#   ('Iván Duque', 'President')},
#  {('Brother', 'Osama Bin Laden')},
#  {('Anwar al-Awlaki', 'cleric')},
#  {('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'defendant'),
#   ('Bomber', 'suspect'),
#   ('Chechnya', 'region'),
#   ('Dzhokhar Tsarnaev', 'defendant'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Ibragim Todashev', 'son-in-law'),
#   ('James "Whitey" Bulger', 'James Whitey Bulger'),
#   ('James "Whitey" Bulger', 'boss'),
#   ('James Whitey Bulger', 'boss')},
#  {('Carter', 'Secretary'),
#   ('Genieve David', 'Maj'),
#   ('Phil Novack', 'spokesman'),
#   ('Republican', 'Senator'),
#   ('Republican', 'Ted Cruz'),
#   ('Senator', 'Ted Cruz')},
#  {('Deval Patrick', 'Governor'),
#   ('a "person of interest', 'suspect'),
#   ('any other bombs', 'no unexploded bombs')},
#  {('Jeremy Snow', 'Major'),
#   ('New Lodge Road', 'district'),
#   ('New Lodge Road', 'neighbourhood'),
#   ('companies', 'troops'),
#   ('district', 'neighbourhood'),
#   ('someone', 'spokesman')},
#  {('Bomber', 'Suspect Two'),
#   ('Bomber', 'kid'),
#   ('Dzokhar', 'djohar tsarnaev'),
#   ('Suspect Two', 'kid'),
#   ('Tsnarnaev', 'kid')},
#  {('Ewing Werlein Jr.', 'Judge'),
#   ('Ewing Werlein Jr.', 'court'),
#   ('Judge', 'court')},
#  {('Chuck Hagel', 'Secretary'), ('Deval Patrick', 'Governor')},
#  {('people', 'victims')},
#  {('Mohammed Mansour Jabarah', 'colleague'), ('fundamentalist', 'operative')},
#  {('Aaron Driver', 'supporter'),
#   ('Aaron Driver', 'suspect'),
#   ('supporter', 'suspect')},
#  {('Army Pfc', 'native'),
#   ('US soldier', 'convert'),
#   ('US soldier', 'native'),
#   ('convert', 'native')},
#  {('Maithripala Sirisena', 'President')},
#  {('Abu Anas al-Libi', 'operative')},
#  {('Olivia Jones', 'senior')},
#  {('Samuel', 'son'), ('Timothy McVeigh', 'bomber'), ('Vicki Weaver', 'wife')},
#  {('Joe Kebartas', 'resident'),
#   ('charmer', 'nephew'),
#   ('charmer', 'slacker'),
#   ('nephew', 'slacker')},
#  {('Alfred P. Murrah Federal Building', 'Murrah Building'),
#   ('culprits', 'defendants'),
#   ('culprits', 'individuals')},
#  {('18-year-old', 'activist'),
#   ('Dolours', 'student'),
#   ('Dolours', 'teachers'),
#   ('Dolours', 'three')},
#  {('bystanders', 'responders'),
#   ('destination', 'there'),
#   ('people', 'responders')},
#  {('25-year-old man', 'Andrew Schneck')},
#  {('Ian Hopkins', 'Manchester Chief Constable'), ('attacker', 'maker')},
#  {('Zubeidat', 'mother')},
#  {('boy', 'student'),
#   ('boy', 'teenager'),
#   ('boy', 'the Hurricane teen'),
#   ('boy', 'the youth'),
#   ('student', 'teenager'),
#   ('student', 'the Hurricane teen'),
#   ('student', 'the youth'),
#   ('teenager', 'the Hurricane teen')},
#  {('Aysha Frade', 'administrator'),
#   ('Briton', 'assailant'),
#   ('Briton', 'soldier'),
#   ('Briton', 'teacher'),
#   ('Keith Palmer', 'veteran'),
#   ('Londoners', 'city'),
#   ('assailant', 'soldier'),
#   ('assailant', 'teacher'),
#   ('bodybuilder', 'soldier'),
#   ('bodybuilder', 'teacher'),
#   ('soldier', 'teacher')},
#  {('An Phoblacht', 'Republican News')},
#  {('a Ford car which', 'a hi-jacked bread van')},
#  {('Karl-Heinz Hoffmann', 'descendant'), ('rue Copernic synagogue', 'where')},
#  {('Federal Medical Detention', 'prison medical facility'),
#   ('Federal Medical Detention', 'there'),
#   ('Lindsey Graham', 'Senator'),
#   ('Zubeidat Tsarnaeva', 'person'),
#   ('prison medical facility', 'there')},
#  {('Timothy McVeigh', 'customer'),
#   ('Timothy McVeigh', 'defendant'),
#   ('customer', 'defendant')},
#  {('bomber', 'member')},
#  {('bomber', 'client'), ('bomber', 'student'), ('client', 'student')},
#  {('bomber', 'male'),
#   ('itself', 'symbol'),
#   ('site', 'symbol'),
#   ('structure', 'symbol')},
#  {('country', 'government')},
#  {('Ahmad Khan Rahami', 'Bomber'),
#   ('Ahmad Khan Rahami', 'guy'),
#   ('Bomber', 'citizen'),
#   ('Bomber', 'guy'),
#   ('citizen', 'guy')},
#  {('Belgian international airport', 'town')},
#  {('Martin Coughlan', 'brains')},
#  {('J Peter Donald', 'spokesman')},
#  {('Brazil', 'Colombian'), ('apartment', 'where'), ('building', 'where')},
#  {('Iván Duque', 'President'), ('José Aldemar Rojas Rodríguez', 'driver')},
#  {('Orangetheory Fitness Chelsea', 'center'),
#   ('Orangetheory Fitness Chelsea', 'company')},
#  {('Dzhokhar', 'brother'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Tamerlan Tsarnaev', 'son')},
#  {('Anwar al-Awlaki', 'cleric')},
#  {('Dzhokhar Tsarnaev', 'guy'),
#   ('Krystle Campbell', 'Lingzi Lu'),
#   ('Krystle Campbell', 'manager'),
#   ('Lingzi Lu', 'manager'),
#   ('Marty Walsh', 'Mayor')},
#  {('Sherabat Khan', 'commander'),
#   ('Sherabat Khan', 'lieutenant'),
#   ('people', 'total')},
#  {('Ghazni', 'city'), ('Leandro Jasso', 'Sergeant')},
#  {('itself', 'organization')},
#  {('client', 'defendant'), ('client', 'minor')},
#  {('Tamerlan Tsarnaev', 'brother')},
#  {('Tsarnaev', 'brothers'), ('couple', 'pair')},
#  {('Hassan Diab', 'academic'),
#   ('Hassan Diab', 'father'),
#   ('Hassan Diab', 'member'),
#   ('Hassan Diab', 'professor'),
#   ('Hassan Diab', 'sociologist'),
#   ('academic', 'father'),
#   ('academic', 'member'),
#   ('academic', 'professor'),
#   ('academic', 'sociologist'),
#   ('father', 'member'),
#   ('father', 'sociologist'),
#   ('professor', 'sociologist')},
#  {('Bomber', 'guy')},
#  {('Jonathan J. Dunbar', 'Sgt')},
#  {('citizen', 'person')},
#  {('Palace of Princes restaurant', 'Palace of the Princes')},
#  {('A 20-year-old former teaching student', 'Aydin Sevigin'),
#   ('A 20-year-old former teaching student', 'a martyr'),
#   ('Attunda District Court', 'the court'),
#   ('Aydin Sevigin', 'a martyr'),
#   ('Mikael Swahn', 'chairman'),
#   ('a suicide bomb', 'bombs'),
#   ('ingredients', 'liquids'),
#   ('shrapnel', 'such a bomb')},
#  {('James McDade', 'lieutenant'),
#   ('John Smith', 'pensioner'),
#   ('Kieran Conway', 'chief'),
#   ('Minister', 'Sir'),
#   ('Oliver Heald QC', 'Sir'),
#   ('girl', 'woman')},
#  {('E. Afghan', 'country'), ('improvised explosive devices', 'weapons')},
#  {('Britain', 'government'),
#   ('Emma Webb', 'researcher'),
#   ('Manchester Bomber', 'Salman Abedi'),
#   ('Manchester Bomber', 'dropout'),
#   ('Manchester Bomber', 'enthusiast'),
#   ('Manchester Bomber', 'fan'),
#   ('Manchester Bomber', 'killer'),
#   ('Mohammed Saeed', 'imam'),
#   ('Ramadan Abedi', 'guard'),
#   ('Salman Abedi', 'dropout'),
#   ('Salman Abedi', 'enthusiast'),
#   ('Salman Abedi', 'fan'),
#   ('dropout', 'enthusiast'),
#   ('dropout', 'fan'),
#   ('dropout', 'killer'),
#   ('enthusiast', 'fan')},
#  {('Dzhokhar', 'brother'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Tamerlan Tsarnaev', 'son')},
#  {('Islamic Society of Boston mosque', 'center'),
#   ('contributor', 'journalist')},
#  {('M600 Pros', 'M600 drones'),
#   ('M600 Pros', 'the M600 Pro drones'),
#   ('M600 drones', 'the M600 Pro drones'),
#   ('Matrice M600 Pro c-drones', 'the M600 Pro drones')},
#  {('Dzhokar Tsarnaev', 'student'),
#   ('Federal Medical Center Devens', 'prison medical facility'),
#   ('Tamerlan Tsarnaev', 'co-conspirator')},
#  {('Phantom 2', 'unmanned drone'),
#   ('office', 'roof'),
#   ('office', 'there'),
#   ('roof', 'there')},
#  {('Anwar al-Awlaki', 'piper'), ('Atiyah Abd al-Rahman', 'aide')},
#  {("George O'Toole", 'John Joseph Moakley'), ('Jeff Bauman', 'spectator')},
#  {('Birmingham Six,', 'Six men')},
#  {('Asia Siddiqui', 'client'), ('citizens', 'pair'), ('homeland', 'nation')},
#  {('John Morrow', 'workman'), ("Paddy McGurk's", 'Paddy McManus')},
#  {('Abdifatah W', 'companion')}]

# %%
coref_pairs_non_single_mention_non_empty = [coref_pairs_non_single_mention[i] for i in range(len(coref_pairs)) if
                                            coref_pairs[i]]
coref_pairs_non_single_mention_non_empty
# Out:
# [{('Amin', 'Milton J. Valencia')},
#  {('America', 'American'),
#   ('America', 'Boston'),
#   ('America', 'U.S'),
#   ('America', 'U.S.'),
#   ('America', 'here'),
#   ('American', 'Boston'),
#   ('American', 'U.S'),
#   ('American', 'U.S.'),
#   ('American', 'here'),
#   ('Bomber', 'Tsarnaev'),
#   ('Boston', 'U.S'),
#   ('Boston', 'here'),
#   ('Chechen', 'Tsarnaev'),
#   ('Chechen', 'bomber'),
#   ('Chechen', 'immigrant'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'immigrant'),
#   ('Karen Rand McWatters', 'McWatters'),
#   ('Karen Rand McWatters', 'friend'),
#   ('Krystle Campbell', 'daughter'),
#   ('Martin', 'brother'),
#   ('Martin', 'son'),
#   ('Patricia Campbell', 'mother'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'immigrant'),
#   ('U.S', 'here'),
#   ('U.S.', 'here'),
#   ('bomber', 'immigrant'),
#   ('people', 'victims'),
#   ('person', 'son')},
#  {('Afghan', 'Afghanistan'),
#   ('Afghan', 'country'),
#   ('Afghan', 'where'),
#   ('Afghanistan', 'country'),
#   ('Afghanistan', 'where'),
#   ('Pakistan', 'hub'),
#   ('civilians', 'people'),
#   ('country', 'where'),
#   ('drone', 'drones')},
#  {('Andrew Cuomo', 'Cuomo'),
#   ('Bill de Blasio', 'DeBlasio'),
#   ('Bill de Blasio', 'de Blasio'),
#   ('DeBlasio', 'de Blasio'),
#   ('Donald', 'spokesman'),
#   ('Donald Trump', 'nominee'),
#   ('Keith Salomon', 'Salomon'),
#   ('New York', 'city'),
#   ('New York', 'state'),
#   ('New York Police Department', 'Police'),
#   ('New York Police Department', 'department'),
#   ('New York Police Department', 'police'),
#   ('Police', 'department'),
#   ('Police', 'police'),
#   ('Trump', 'nominee'),
#   ('area', 'neighborhood'),
#   ('area', 'where'),
#   ('attacker', 'man'),
#   ('attacker', 'soldier'),
#   ('department', 'police'),
#   ('man', 'soldier')},
#  {('264', 'wounded'),
#   ('Boylston Street', 'thoroughfare'),
#   ('Dzhokhar', 'brother'),
#   ('Sean Collier', 'policeman'),
#   ('Suspects', 'Tsarnaev'),
#   ('Suspects', 'brothers'),
#   ('Suspects', 'suspects'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'brothers'),
#   ('brothers', 'sons'),
#   ('brothers', 'suspects'),
#   ('sons', 'suspects')},
#  {('19', 'Dzhokhar Tsarnaev'),
#   ('26', 'Tamerlan'),
#   ('26', 'Tamerlan Tsarnaev'),
#   ('26', 'another person'),
#   ('Both brothers', 'Tsarnaevs'),
#   ('Both brothers', 'lifeguards'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Ruger pistol', 'Ruger semi-automatic handgun'),
#   ('Ruger pistol', 'Ruger semi-automatic pistol'),
#   ('Ruger pistol', 'a gun'),
#   ('Ruger pistol', 'gun'),
#   ('Ruger semi-automatic pistol', 'a gun'),
#   ('Ruger semi-automatic pistol', 'gun'),
#   ('Sean Collier', 'officer'),
#   ('Silva', 'Stephen Silva'),
#   ('Silva', 'his close friend'),
#   ('Stephen Silva', 'his close friend'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'another person'),
#   ('Tamerlan Tsarnaev', 'another person'),
#   ('Tsarnaevs', 'lifeguards'),
#   ('Whole Foods', 'store'),
#   ('a gun', 'gun'),
#   ('bombs', 'the bombs'),
#   ('bombs', 'two'),
#   ('handguns', 'two'),
#   ('the bombs', 'two')},
#  {('Bin Laden', 'bin Laden'),
#   ('Bin Laden', 'suspect'),
#   ('Osama bin Laden', 'bin Laden'),
#   ('Osama bin Laden', 'suspect'),
#   ('bin Laden', 'suspect')},
#  {('22', 'people'),
#   ('26', 'people'),
#   ('Ashraf Ghani', 'Ghani'),
#   ('Ashraf Ghani', 'president'),
#   ('Ghani', 'President'),
#   ('Ghani', 'president'),
#   ('President', 'president'),
#   ('dead', 'victims'),
#   ('ground', 'site')},
#  {('Authorities', 'authorities'),
#   ('Bilal', 'Bilal Mohammed'),
#   ('Bilal', 'client'),
#   ('Bilal', 'man'),
#   ('Bilal Mohammed', 'client'),
#   ('Bilal Mohammed', 'man'),
#   ('China', 'Chinese'),
#   ('China', 'where'),
#   ('Chinese', 'where'),
#   ('Chuchart Kanpai', 'lawyer'),
#   ('Erawan Shrine', 'Shrine'),
#   ('Erawan Shrine', 'destination'),
#   ('Erawan Shrine', 'shrine'),
#   ('Mieraili', 'Mieraili Yusufu'),
#   ('Mieraili', 'Yusufu'),
#   ('Mieraili Yusufu', 'Yusufu'),
#   ('National Police', 'Police'),
#   ('National Police', 'police'),
#   ('Police', 'police'),
#   ('Shrine', 'destination'),
#   ('Shrine', 'shrine'),
#   ('Thai', 'Thailand'),
#   ('Thai', 'country'),
#   ('Thailand', 'country'),
#   ('client', 'man'),
#   ('destination', 'shrine'),
#   ('men', 'suspect'),
#   ('men', 'suspects'),
#   ('men', 'two'),
#   ('suspect', 'suspects'),
#   ('suspects', 'two')},
#  {('Maduro', 'Maduro’s'),
#   ('Maduro', 'Nicolás Maduro'),
#   ('Maduro', 'President'),
#   ('Maduro', 'president'),
#   ('Maduro’s', 'President'),
#   ('Maduro’s', 'president'),
#   ('Nestor Reverol', 'Reverol'),
#   ('Nestor Reverol', 'minister'),
#   ('Nicolás Maduro', 'President'),
#   ('Nicolás Maduro', 'president'),
#   ('President', 'president'),
#   ('Reverol', 'minister'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'Venezuela’s'),
#   ('Venezuela', 'government'),
#   ('Venezuela', 'state'),
#   ('Venezuela', 'the'),
#   ('Venezuelan', 'government'),
#   ('Venezuelan', 'state'),
#   ('Venezuela’s', 'government'),
#   ('Venezuela’s', 'state'),
#   ('Venezuela’s', 'the'),
#   ('apartment', 'building'),
#   ('drone', 'drones'),
#   ('government', 'state'),
#   ('government', 'the'),
#   ('vicinity', 'where')},
#  {('21', 'people'),
#   ('Birmingham', 'Town'),
#   ('Birmingham', 'city'),
#   ('Birmingham Mail', 'Birmingham Post & Mail'),
#   ('Brian', 'Brian Hambleton'),
#   ('British', 'England'),
#   ('Conway', 'Fighter'),
#   ('Conway', 'Kieran Conway'),
#   ('Conway', 'head'),
#   ('Fighter', 'head'),
#   ('IRA', 'Irish'),
#   ('IRA', 'organisation'),
#   ('IRA', 'republican'),
#   ('Irish', 'organisation'),
#   ('Irish', 'republican'),
#   ('Irishmen', 'bombers'),
#   ('James McDade', 'McDade'),
#   ('James McDade', 'bomber'),
#   ('James McDade', 'lieutenant'),
#   ('James McDade', 'volunteer'),
#   ('Kieran Conway', 'head'),
#   ('McDade', 'bomber'),
#   ('McDade', 'lieutenant'),
#   ('McDade', 'volunteer'),
#   ('Town', 'city'),
#   ('bomber', 'lieutenant'),
#   ('group', 'organisation'),
#   ('group', 'republican')},
#  {('Badia', 'spot'),
#   ('Badia', 'zone'),
#   ('Badia al-Sukhnah', 'area'),
#   ('Badia al-Sukhnah', 'spot'),
#   ('Badia al-Sukhnah', 'zone'),
#   ('General', 'Vyacheslav Gladkikh'),
#   ('General', 'general'),
#   ('IS', 'Islamic State'),
#   ('Syria', 'Syrian'),
#   ('Syria', 'country'),
#   ('Syria', 'there'),
#   ('Syrian', 'country'),
#   ('Syrian', 'there'),
#   ('Tass', 'agency'),
#   ('Vyacheslav Gladkikh', 'general'),
#   ('area', 'spot'),
#   ('area', 'zone'),
#   ('country', 'there'),
#   ('spot', 'zone')},
#  {('American', 'U.S.'),
#   ('Chávez', 'Hugo Chávez'),
#   ('Gabriela Ramírez', 'Ramírez'),
#   ('Government', 'employer'),
#   ('Government', 'government'),
#   ('Government', 'state'),
#   ('Government', 'the government'),
#   ('U.S. State Department', 'U.S. Treasury Department'),
#   ('employer', 'government'),
#   ('employer', 'state'),
#   ('employer', 'the government'),
#   ('government', 'state'),
#   ('government', 'the government'),
#   ('opposition', 'the opposition'),
#   ('state', 'the government')},
#  {('Christophe Castaner', 'Minister'),
#   ('Islamic State', 'group'),
#   ('Police', 'police'),
#   ('Rue Victor Hugo', 'street')},
#  {('Dagestan', 'Dagestani'),
#   ('Dagestan', 'Republic of Dagestan'),
#   ('Dagestan', 'land'),
#   ('Dagestan', 'place'),
#   ('Dagestan', 'province'),
#   ('Dagestan', 'region'),
#   ('Dagestan', 'republic'),
#   ('Dagestan', 'state'),
#   ('Dagestani', 'place'),
#   ('Dagestani', 'republic'),
#   ('Federal', 'Russia'),
#   ('Federal', 'Russian'),
#   ('Federal', 'Russian Federation'),
#   ('Moscow', 'Russia'),
#   ('Moscow', 'Russian'),
#   ('Moscow', 'Russian Federation'),
#   ('Republic of Dagestan', 'land'),
#   ('Republic of Dagestan', 'place'),
#   ('Republic of Dagestan', 'region'),
#   ('Republic of Dagestan', 'republic'),
#   ('Republic of Dagestan', 'state'),
#   ('Russia', 'Russian'),
#   ('Russia', 'Russian Federation'),
#   ('Russian', 'Russian Federation'),
#   ('land', 'place'),
#   ('land', 'republic'),
#   ('province', 'region'),
#   ('province', 'republic'),
#   ('province', 'state'),
#   ('region', 'republic'),
#   ('region', 'state'),
#   ('republic', 'state')},
#  {('gunmen', 'insurgents')},
#  {('Alejandro Pérez', 'Brayan Oropeza'),
#   ('Juan Requesens', 'lawmaker'),
#   ('Luis Guerra', 'Yanin Pernía')},
#  {('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('people', 'three')},
#  {('Christophe Castaner', 'minister'),
#   ('Chérif Chekatt', 'killer'),
#   ('Lyon', 'city'),
#   ('Police', 'police'),
#   ('Victor Hugo street', 'street'),
#   ('man', 'suspect')},
#  {('British', 'UK'),
#   ('British', 'country'),
#   ('British', 'government'),
#   ('British', 'the'),
#   ('Chinook', 'helicopter'),
#   ('UAVs', 'aircraft'),
#   ('UAVs', 'missiles'),
#   ('UAVs', 'unmanned aerial vehicles'),
#   ('UK', 'country'),
#   ('UK', 'government'),
#   ('UK', 'the'),
#   ('aircraft', 'missiles'),
#   ('aircraft', 'unmanned aerial vehicles'),
#   ('chemicals', 'material'),
#   ('country', 'the'),
#   ('drones', 'weaponised consumer drones'),
#   ('government', 'the'),
#   ('missiles', 'unmanned aerial vehicles'),
#   ('soil', 'the')},
#  {('Ash Carter', 'Secretary'),
#   ('Bagram', 'Bagram Air Base'),
#   ('Bagram', 'Bagram Airfield'),
#   ('Bagram Air Base', 'Bagram Airfield'),
#   ('Zabiullah Mujahid', 'spokesperson'),
#   ('members', 'six'),
#   ('members', 'victims'),
#   ('six', 'victims')},
#  {('Aragua', 's'),
#   ('Aragua', 'state'),
#   ('Central Hospital of Maracay', 'hospital'),
#   ('Central Hospital of Maracay', 'the Maracay Central Hospital'),
#   ('hospital', 'the Maracay Central Hospital')},
#  {('12', 'people'),
#   ('Antonio Durán', 'Vicente Sainz de la Peña'),
#   ('Antonio Durán', 'director'),
#   ('Antonio Durán', 'worker'),
#   ('Bernardo Badell', 'pilot'),
#   ('Carlos Arias Navarro', 'Minister'),
#   ('ETA', 'group'),
#   ('ETA', 'organisation'),
#   ('Eliseo Bayo', 'María Paz Ballesteros'),
#   ('Eliseo Bayo', 'actress'),
#   ('Eliseo Bayo', 'writer'),
#   ('Eva Forest', 'Forest'),
#   ('Eva Forest', 'wife'),
#   ('Forest', 'wife'),
#   ('María Paz Ballesteros', 'actress'),
#   ('María Paz Ballesteros', 'writer'),
#   ('María del Carmen Nadal', 'wife'),
#   ('Rolando', 'Rolando Cafe'),
#   ('Rolando', 'building'),
#   ('Rolando', 'cafe'),
#   ('Rolando Cafe', 'building'),
#   ('Rolando Cafe', 'cafe'),
#   ('Rolando cafe', 'building'),
#   ('Rolando cafe', 'cafe'),
#   ('Two', 'two'),
#   ('Vicente Sainz de la Peña', 'director'),
#   ('Vicente Sainz de la Peña', 'worker'),
#   ('building', 'cafe'),
#   ('customers', 'employees'),
#   ('group', 'organisation')},
#  {('Azamat Tazhayakov', 'Tazhayakov'),
#   ('Azamat Tazhayakov', 'friend'),
#   ('Azamat Tazhayakov', 'friends'),
#   ('Azamat Tazhayakov', 'student'),
#   ('Friend', 'Tazhayakov'),
#   ('Friend', 'friend'),
#   ('Friend', 'friends'),
#   ('Friend', 'student'),
#   ('Tazhayakov', 'friend'),
#   ('Tazhayakov', 'friends'),
#   ('friend', 'friends'),
#   ('friend', 'student')},
#  {("David D'Albini", 'manager'),
#   ('Eldon Elliott', 'Elliott'),
#   ('Eldon Elliott', "Elliott's"),
#   ('Eldon Elliott', 'owner'),
#   ('Elliott', "Elliott's"),
#   ('Elliott', 'owner'),
#   ("Elliott's", 'owner'),
#   ("Elliott's Body Shop", 'shop'),
#   ('Geary Lake', 'there'),
#   ('Junction City', 'where'),
#   ('Kling', 'Robert Kling'),
#   ('Kling', 'caller'),
#   ('McVeigh', 'Timothy McVeigh'),
#   ('McVeigh', 'man'),
#   ('Mendeloff', 'Scott Mendeloff'),
#   ('Mendeloff', 'prosecutor'),
#   ('Murrah Federal Building', 'building'),
#   ('Prosecutors', 'prosecutors'),
#   ('Ryder', 'Ryder truck'),
#   ('Ryder', 'truck'),
#   ('Ryder truck', 'truck'),
#   ('Scott Mendeloff', 'prosecutor'),
#   ('Timothy McVeigh', 'man'),
#   ('Yuhua Bai', 'owner'),
#   ('depot', 'where'),
#   ('jurors', 'jury')},
#  {('Duffield', 'client'),
#   ('Duffield', 'driver'),
#   ('Terry Duffield', 'client'),
#   ('Terry Duffield', 'driver'),
#   ('client', 'driver')},
#  {('Hussein', 'Saddam'),
#   ('Hussein', 'Saddam Hussein'),
#   ('McVeigh', 'Timothy McVeigh'),
#   ('McVeigh', 'bomber'),
#   ('Saddam', 'Saddam Hussein'),
#   ('Terry Nichols', 'co-conspirator'),
#   ('Timothy McVeigh', 'bomber'),
#   ('co-conspirators', 'ilk')},
#  {('center', 'where')},
#  {('Maduro', 'Nicolás Maduro'),
#   ('Maduro', 'palco presidencial'),
#   ('Maduro', 'the president'),
#   ('Pérez', 'Óscar Pérez'),
#   ('Venezuela', 'country'),
#   ('Venezuela', 'nation'),
#   ('Venezuela', 's'),
#   ('Venezuela', 'the government'),
#   ('apartment', 'building'),
#   ('country', 'government'),
#   ('country', 'nation'),
#   ('country', 's'),
#   ('country', 'the government'),
#   ('country', 'where'),
#   ('government', 'nation'),
#   ('government', 's'),
#   ('government', 'the government'),
#   ('government', 'where'),
#   ('nation', 's'),
#   ('nation', 'the government'),
#   ('palco presidencial', 'the president'),
#   ('s', 'the government'),
#   ('the government', 'where')},
#  {('Chao Praya river', 'river'),
#   ('National', 'Royal Thai'),
#   ('National', 'Thai'),
#   ('National', 'Thailand'),
#   ('National', 'government'),
#   ('National', 'kingdom'),
#   ('Police', 'Royal Thai Police'),
#   ('Police', 'national police'),
#   ('Police', 'police'),
#   ('Royal Thai', 'Thai'),
#   ('Royal Thai', 'Thailand'),
#   ('Royal Thai', 'government'),
#   ('Royal Thai', 'kingdom'),
#   ('Royal Thai Police', 'police'),
#   ('Suspect', 'foreigner'),
#   ('Suspect', 'man'),
#   ('Suspect', 'suspect'),
#   ('Thai', 'Thailand'),
#   ('Thai', 'government'),
#   ('Thai', 'kingdom'),
#   ('Thailand', 'government'),
#   ('Thailand', 'kingdom'),
#   ('consulate', 'where'),
#   ('foreigner', 'man'),
#   ('foreigner', 'suspect'),
#   ('government', 'kingdom'),
#   ('man', 'suspect'),
#   ('national police', 'police')},
#  {('bomb', 'ourself'),
#   ('bomber', 'suspect'),
#   ('bomber', 'white'),
#   ('home', 'house')},
#  {('Nicolas Maduro', 'the president'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'country'),
#   ('Venezuela', 'government'),
#   ('Venezuela', 's'),
#   ('Venezuelan', 'country'),
#   ('Venezuelan', 's'),
#   ('country', 's'),
#   ('government', 's')},
#  {('Islamists', 'perpetrators')},
#  {('-year-old', 'man'),
#   ('-year-old', 'refugee'),
#   ('17', 'four'),
#   ('Abdullah Reda al-Hamamy', 'man'),
#   ('British parliament', 'parliament'),
#   ('Frenchman', 'attacker'),
#   ('German', 'Germany'),
#   ('Islamic State', 'Islamist'),
#   ('Mehdi Nemmouche', 'attacker'),
#   ('Mehdi Nemmouche', 'national'),
#   ('Nice', 'city'),
#   ('a heavy truck', 'truck'),
#   ('attacker', 'national'),
#   ('attackers', 'hostage-takers'),
#   ('gunman', 'teenager'),
#   ('man', 'refugee')},
#  {('Boston', 'Massachusetts'),
#   ('Boston', 'South Boston'),
#   ('Boston', 'city'),
#   ('Boston', 'state'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'defendant'),
#   ('Dzhokhar', 'student'),
#   ('Dzhokhar Tsarnaev', 'Suspect'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'defendant'),
#   ('Dzhokhar Tsarnaev', 'student'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Joe Kebartas', 'resident'),
#   ('Jury', 'jury'),
#   ('Lingzi Lu', 'student'),
#   ('Massachusetts', 'South Boston'),
#   ('Massachusetts', 'city'),
#   ('Massachusetts', 'state'),
#   ('Sean Collier', 'officer'),
#   ('Suspect', 'Tsarnaev'),
#   ('Suspect', 'bomber'),
#   ('Suspect', 'defendant'),
#   ('Suspect', 'student'),
#   ('Suspect', 'suspect'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'defendant'),
#   ('Tsarnaev', 'student'),
#   ('Tsarnaev', 'suspect'),
#   ('bomber', 'defendant'),
#   ('bomber', 'student'),
#   ('bomber', 'suspect')},
#  {('Aaron Driver', 'Driver'),
#   ('Aaron Driver', 'Harun Abdurahman'),
#   ('Aaron Driver', 'driver'),
#   ('Aaron Driver', 'man'),
#   ('Driver', 'Harun Abdurahman'),
#   ('Driver', 'driver'),
#   ('Driver', 'man'),
#   ('Harun Abdurahman', 'driver'),
#   ('Harun Abdurahman', 'man'),
#   ('Strathroy', 'town'),
#   ('driver', 'man')},
#  {('191', 'victims'), ('al-Qaeda', 'group'), ('four trains', 'trains')},
#  {('Boston Bomber', 'Dzhokhar'),
#   ('Boston Bomber', 'Dzhokhar Tsarnaev'),
#   ('Boston Bomber', 'Tsarnaev'),
#   ('Boston Bomber', 'bomber'),
#   ('Boston Bomber', 'immigrant'),
#   ('Boston Bomber', 'person'),
#   ('Campbell', 'daughter'),
#   ('Collier', 'Sean Collier'),
#   ('Collier', 'officer'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'immigrant'),
#   ('Dzhokhar Tsarnaev', 'person'),
#   ("George O'Toole", "O'Toole"),
#   ('Krystal Campbell', 'daughter'),
#   ('Lingzi Lu', 'student'),
#   ('Sean Collier', 'officer'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'immigrant'),
#   ('Tsarnaev', 'person'),
#   ('people', 'victims')},
#  {('Brothers', 'pair'),
#   ('Brothers', 'suspects'),
#   ('Khairullozhon Matanov', 'Matanov'),
#   ('Khairullozhon Matanov', 'national'),
#   ('Matanov', 'driver'),
#   ('Matanov', 'national'),
#   ('Matanov', 'person'),
#   ('Tamerlan Tsarnaev', 'left'),
#   ('Tsarnaev', 'bombers'),
#   ('Tsarnaev', 'brothers'),
#   ('Tsarnaev', 'pair'),
#   ('Tsarnaev', 'suspects'),
#   ('bombers', 'brothers'),
#   ('bombers', 'pair'),
#   ('bombers', 'suspects'),
#   ('brothers', 'pair'),
#   ('brothers', 'suspects'),
#   ('driver', 'national'),
#   ('driver', 'person'),
#   ('national', 'person'),
#   ('pair', 'suspects')},
#  {('Andino', 'Centro Andino'),
#   ('Andino', 'mall'),
#   ('Arauca', 'city'),
#   ('Bogotá', 'capital'),
#   ('Bogotá', 'city'),
#   ('Carvajal Salgar', 'Ricardo Carvajal'),
#   ('Centro Andino', 'mall'),
#   ('Chicó', 'Erika Chicó'),
#   ('Chicó', 'cadet'),
#   ('Chicó', 'national'),
#   ('Colombia', 'Colombian'),
#   ('Colombia', 'Government'),
#   ('Colombia', 'country'),
#   ('Colombia', 'government'),
#   ('Colombia', 'nation'),
#   ('Colombian', 'Government'),
#   ('Colombian', 'country'),
#   ('Colombian', 'government'),
#   ('Colombian', 'nation'),
#   ('ELN', 'National Liberation Army'),
#   ('ELN', 'group'),
#   ('ELN', 'movement'),
#   ('ELN', 'organization'),
#   ('Erika Chicó', 'cadet'),
#   ('Erika Chicó', 'national'),
#   ('General Santander National Police Academy', 'academy'),
#   ('General Santander National Police Academy', 'facility'),
#   ('Government', 'country'),
#   ('Government', 'government'),
#   ('Government', 'nation'),
#   ('Iván Márquez', 'commander'),
#   ('José Aldemar Rojas Rodríguez', 'Mocho Kiko'),
#   ('José Aldemar Rojas Rodríguez', 'Rojas'),
#   ('José Aldemar Rojas Rodríguez', 'Rojas Rodríguez'),
#   ('José Aldemar Rojas Rodríguez', 'chief'),
#   ('José Aldemar Rojas Rodríguez', 'expert'),
#   ('José Aldemar Rojas Rodríguez', 'member'),
#   ('José Aldemar Rojas Rodríguez', 'old'),
#   ('José Aldemar Rojas Rodríguez', 'perpetrator'),
#   ('Mocho Kiko', 'Rojas'),
#   ('Mocho Kiko', 'Rojas Rodríguez'),
#   ('Mocho Kiko', 'expert'),
#   ('Mocho Kiko', 'member'),
#   ('Mocho Kiko', 'old'),
#   ('National Liberation Army', 'group'),
#   ('National Liberation Army', 'movement'),
#   ('National Liberation Army', 'organization'),
#   ('Nissan Patrol', 'vehicle'),
#   ('Rojas', 'Rojas Rodríguez'),
#   ('Rojas', 'chief'),
#   ('Rojas', 'expert'),
#   ('Rojas', 'member'),
#   ('Rojas', 'old'),
#   ('Rojas', 'perpetrator'),
#   ('Rojas Rodríguez', 'chief'),
#   ('Rojas Rodríguez', 'expert'),
#   ('Rojas Rodríguez', 'member'),
#   ('Rojas Rodríguez', 'old'),
#   ('Rojas Rodríguez', 'perpetrator'),
#   ('Santander National Police Academy', 'academy'),
#   ('Santander National Police Academy', 'facility'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'government'),
#   ('Venezuelan', 'government'),
#   ('cadet', 'national'),
#   ('capital', 'city'),
#   ('car', 'truck'),
#   ('car', 'vehicle'),
#   ('chief', 'expert'),
#   ('chief', 'member'),
#   ('chief', 'old'),
#   ('country', 'government'),
#   ('country', 'nation'),
#   ('expert', 'member'),
#   ('expert', 'old'),
#   ('government', 'nation'),
#   ('group', 'movement'),
#   ('group', 'organization'),
#   ('member', 'old'),
#   ('member', 'perpetrator'),
#   ('movement', 'organization'),
#   ('truck', 'vehicle')},
#  {('Abdirahman Omar Osman', 'Mayor'),
#   ('al-Shabaab', 'group'),
#   ('bomber', 'herself')},
#  {('15', 'injured'),
#   ('15', 'people'),
#   ('Bombay Bhel', 'restaurant'),
#   ('Mississauga', 'city'),
#   ('Mississauga', 'home'),
#   ('bomb', 'device'),
#   ('city', 'home'),
#   ('injured', 'people'),
#   ('men', 'suspects'),
#   ('paramedics', 'services'),
#   ('plaza', 'where')},
#  {('ISIS', 'group'),
#   ('Teen', 'boy'),
#   ('Teen', 'juvenile'),
#   ('Teen', 'suspect'),
#   ('boy', 'juvenile'),
#   ('boy', 'suspect'),
#   ('juvenile', 'suspect')},
#  {('Armed Forces Recruiting Station', 'building'),
#   ('Armed Forces Recruiting Station', 'station'),
#   ('Gerald Koch', 'Koch'),
#   ('Gerald Koch', 'anarchist'),
#   ('bomb', 'device')},
#  {('Abu Mahdi al-Muhandis', 'chief'),
#   ('Baghdad', 'capital'),
#   ('British Embassy', 'embassy'),
#   ('Embassy', 'embassy'),
#   ('IED', 'device'),
#   ('Rocket', 'rockets'),
#   ('U.S', 'Washington')},
#  {('Azamat Tazhayakov', 'Tazhayakov'),
#   ('Azamat Tazhayakov', 'client'),
#   ('Azamat Tazhayakov', 'first'),
#   ('Azamat Tazhayakov', 'man'),
#   ('Azamat Tazhayakov', 'student'),
#   ('Boston', 'Cambridge'),
#   ('Boston', 'city'),
#   ('Dias Kadyrbayev', 'Kadyrbayev'),
#   ('Dias Kadyrbayev', 'student'),
#   ('Dzhokhar', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Kadyrbayev', 'student'),
#   ('Tamerlan', 'brother'),
#   ('Tazhayakov', 'client'),
#   ('Tazhayakov', 'first'),
#   ('Tazhayakov', 'man'),
#   ('Tazhayakov', 'student'),
#   ('Tsarnaev', 'suspect'),
#   ('client', 'man'),
#   ('client', 'student'),
#   ('first', 'man'),
#   ('first', 'student'),
#   ('man', 'student')},
#  {('McVeigh', 'Timothy McVeigh'),
#   ('McVeigh', 'extremist'),
#   ('McVeigh', 'suspect'),
#   ('McVeigh', 'veteran'),
#   ('Terry Nichols', 'accomplice'),
#   ('Timothy McVeigh', 'extremist'),
#   ('Timothy McVeigh', 'suspect'),
#   ('Timothy McVeigh', 'veteran'),
#   ('extremist', 'suspect'),
#   ('people', 'victims')},
#  {('Colonel', 'Tokhi'),
#   ('Colonel', 'chief'),
#   ('IED', 'Improvised Explosive Device'),
#   ('Mohammad Asif Tokhi', 'Tokhi'),
#   ('Mohammad Asif Tokhi', 'chief'),
#   ('Tokhi', 'chief'),
#   ('officers', 'policemen')},
#  {('Ahmad Khan Rahami', 'Rahami'),
#   ('Ahmad Khan Rahami', 'man'),
#   ('Ahmad Khan Rahami', 'son'),
#   ('Rahami', 'man'),
#   ('Rahami', 'son'),
#   ('man', 'son')},
#  {('Birmingham', 'Town'),
#   ('Birmingham', 'city'),
#   ('Birmingham', 'town'),
#   ('Hayes', 'Michael Christopher Hayes'),
#   ('Hayes', 'maker'),
#   ('Hayes', 'man'),
#   ('Hayes', 'member'),
#   ('Hayes', 'volunteer'),
#   ('Michael Christopher Hayes', 'maker'),
#   ('Michael Christopher Hayes', 'man'),
#   ('Michael Christopher Hayes', 'member'),
#   ('Michael Christopher Hayes', 'volunteer'),
#   ('Town', 'city'),
#   ('Town', 'town'),
#   ('city', 'town'),
#   ('group', 'unit'),
#   ('maker', 'member'),
#   ('maker', 'volunteer'),
#   ('man', 'member'),
#   ('man', 'volunteer'),
#   ('member', 'volunteer')},
#  {('Accused Boston Bomber', 'Dzhokhar'),
#   ('Accused Boston Bomber', 'Tsarnaev'),
#   ('Accused Boston Bomber', 'bomber'),
#   ('Accused Boston Bomber', 'client'),
#   ('Accused Boston Bomber', 'defendant'),
#   ('Boston', 'city'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'bomber'),
#   ('Dzhokhar', 'client'),
#   ('Dzhokhar', 'defendant'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'client'),
#   ('Dzhokhar Tsarnaev', 'defendant'),
#   ('Krystle Campbell', 'manager'),
#   ('Lingzi Lu', 'Lu'),
#   ('Lingzi Lu', 'student'),
#   ('Martin Richard', 'Richard'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'client'),
#   ('Tsarnaev', 'defendant'),
#   ('U.S', 'country'),
#   ('United States', 'country'),
#   ('bomb', 'bombs'),
#   ('client', 'defendant')},
#  {('Ali Khamenei', 'Ayatollah'),
#   ('Barack Obama', 'Obama'),
#   ('Barack Obama', 'president'),
#   ('Boston Police Department', 'enforcement'),
#   ('FBI', 'agency'),
#   ('Investigators', 'investigators'),
#   ('Obama', 'president'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'federal'),
#   ('U.S', 'government'),
#   ('U.S.', 'federal'),
#   ('U.S.', 'government'),
#   ('bombs', 'devices'),
#   ('bombs', 'explosives'),
#   ('federal', 'government'),
#   ('individual', 'perpetrator'),
#   ('public', "public's")},
#  {('a car', 'vehicle'), ('station', 'train')},
#  {('Citi Plaza', 'mall'), ('Driver', 'man')},
#  {('Nohad Machnouk', 'minister'),
#   ('Nusra', 'Nusra Front'),
#   ('Nusra', 'group'),
#   ('Nusra Front', 'group'),
#   ('bombers', 'men')},
#  {('Bomb', 'bomb'),
#   ('IRA', 'Provisional IRA'),
#   ('IRA', 'Provisional Irish Republican Army'),
#   ('IRA', 'organization'),
#   ("King's Cross", "King's Cross railway station"),
#   ("King's Cross", "King's Cross station"),
#   ("King's Cross", 'station'),
#   ("King's Cross railway station", "King's Cross station"),
#   ("King's Cross railway station", 'station'),
#   ("King's Cross station", 'station'),
#   ('London', 'city'),
#   ('Provisional IRA', 'Provisional Irish Republican Army'),
#   ('Provisional IRA', 'organization'),
#   ('Provisional Irish Republican Army', 'organization')},
#  {('Afghanistan', 'government'),
#   ('Bagram Air Base', 'airfield'),
#   ('Bagram Air Base', 'base'),
#   ('Taliban', 'attackers'),
#   ('Taliban', 'insurgents'),
#   ('airfield', 'base'),
#   ('attackers', 'insurgents')},
#  {('Afridi', 'Minister'),
#   ('Afridi', 'Shehryar Khan Afridi'),
#   ('Arif Alvi', 'President'),
#   ('Arif Alvi', 'president'),
#   ('Balochistan', 'Balochistan province'),
#   ('Balochistan', 'government'),
#   ('Balochistan', 'province'),
#   ('Balochistan', 'provincial'),
#   ('Balochistan', 'state'),
#   ('Balochistan province', 'government'),
#   ('Balochistan province', 'province'),
#   ('Balochistan province', 'provincial'),
#   ('Balochistan province', 'state'),
#   ('Bilawal Bhutto Zardari', 'Bilawal Zardari'),
#   ('Bilawal Bhutto Zardari', 'Leader'),
#   ('Bilawal Bhutto Zardari', 'leader'),
#   ('Bilawal Zardari', 'Leader'),
#   ('Bilawal Zardari', 'leader'),
#   ('Commissioner', 'diplomat'),
#   ('Community', 'Hazara'),
#   ('Community', 'community'),
#   ('Embassy of Saudi Arabia', 'Saudi Arabia'),
#   ('Hazara', 'Hazaras'),
#   ('Hazara', 'community'),
#   ('Hazara', 'u'),
#   ('Hazaras', 'community'),
#   ('Hazaras', 'people'),
#   ('Hazaras', 'u'),
#   ('Hazarganji', 'area'),
#   ('Hazarganji', 'where'),
#   ('Imran Khan', 'Khan'),
#   ('Imran Khan', 'Minister'),
#   ('Imran Khan', 'PM'),
#   ('Imran Khan', 'PM Khan'),
#   ('Imran Khan', 'premier'),
#   ('Jam Kamal', 'minister'),
#   ('Jam Kamal Khan', 'Minister'),
#   ('Jam Kamal Khan', 'minister'),
#   ('Karachi', 'Sindh'),
#   ('Khan', 'Minister'),
#   ('Khan', 'premier'),
#   ('Lashkar-e-Jhangvi', 'group'),
#   ('Leader', 'leader'),
#   ('Minister', 'PM'),
#   ('Minister', 'PM Khan'),
#   ('Minister', 'Shehryar Khan Afridi'),
#   ('Minister', 'minister'),
#   ('Minister', 'premier'),
#   ('Muhammad Raza', 'participant'),
#   ('Nation', 'Pak'),
#   ('Nation', 'Pakistan'),
#   ('Nation', 'Pakistani'),
#   ('Nation', 'SMQureshiPTI'),
#   ('Nation', 'country'),
#   ('Nation', 'nation'),
#   ('Nation', 'state'),
#   ('PM', 'premier'),
#   ('PM Khan', 'premier'),
#   ('Pak', 'Pakistan'),
#   ('Pak', 'Pakistani'),
#   ('Pak', 'country'),
#   ('Pak', 'state'),
#   ('Pakistan', 'Pakistani'),
#   ('Pakistan', 'SMQureshiPTI'),
#   ('Pakistan', 'country'),
#   ('Pakistan', 'nation'),
#   ('Pakistan', 'state'),
#   ('Pakistani', 'country'),
#   ('Pakistani', 'state'),
#   ('Qari Saifullah', 'spokesperson'),
#   ('Quetta', 'capital'),
#   ('Quetta', 'city'),
#   ('SMQureshiPTI', 'country'),
#   ('SMQureshiPTI', 'state'),
#   ('Shia', 'Shiite'),
#   ('Thomas Drew CMG', 'diplomat'),
#   ('area', 'where'),
#   ('bomber', 'militant'),
#   ('capital', 'city'),
#   ('community', 'u'),
#   ('extremists', 'target'),
#   ('government', 'province'),
#   ('kafirs', 'people'),
#   ('market', 'stall'),
#   ('marketplace', 'site'),
#   ('marketplace', 'stall'),
#   ('militant', 'perpetrator'),
#   ('nation', 'state'),
#   ('others', 'wounded'),
#   ('protesters', 'protestors'),
#   ('site', 'stall')},
#  {('Bureau', 'Bureau of Investigative Journalism'),
#   ('Bureau', 'organization'),
#   ('Bureau', 's'),
#   ('Bureau of Investigative Journalism', 'organization'),
#   ('Bureau of Investigative Journalism', 's'),
#   ('NYU', 'New York University Law School'),
#   ('New America', 'New America Foundation'),
#   ('New America', 'where'),
#   ('New America Foundation', 'where'),
#   ('Reprieve', 'organization'),
#   ('Stanford', 'Stanford Law School'),
#   ('Stanford', 's'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'government'),
#   ('U.S.', 'government'),
#   ('United States', 'abuser'),
#   ('United States', 'government'),
#   ('abuser', 'government'),
#   ('dead', 'people'),
#   ('dead', 'victims'),
#   ('organization', 's'),
#   ('people', 'victims'),
#   ('researchers', 'team'),
#   ('victim', 'victims')},
#  {('Ernesto Macias', 'president'),
#   ('Julio Borges', 'congressional Speaker'),
#   ('Julio Borges', 'president'),
#   ('Maduro', 'Nicolas Maduro'),
#   ('Maduro', 'President'),
#   ('Maduro', 'leader'),
#   ('Maduro', 's'),
#   ('Maduro', 'the president'),
#   ('Nicolas Maduro', 'President'),
#   ('Nicolas Maduro', 'leader'),
#   ('Nicolas Maduro', 's'),
#   ('Nicolas Maduro', 'the president'),
#   ('Oscar Perez', 'lnspector'),
#   ('Perez', 'lnspector'),
#   ('President', 's'),
#   ('SEBIN', 'police'),
#   ('leader', 's'),
#   ('leader', 'the president')},
#  {('21-year-old', 'Bomber Tsarnaev'),
#   ('21-year-old', 'Dzhokhar'),
#   ('21-year-old', 'Dzhokhar Tsarnaev'),
#   ('21-year-old', 'Tsarnaev'),
#   ('21-year-old', 'bomber'),
#   ('21-year-old', 'citizen'),
#   ('21-year-old', 'immigrant'),
#   ('America', 'U.S.'),
#   ('America', 'government'),
#   ('American', 'U.S.'),
#   ('American', 'government'),
#   ('Attorney', 'Pellegrini'),
#   ('Bomber Tsarnaev', 'Dzhokhar'),
#   ('Bomber Tsarnaev', 'Dzhokhar Tsarnaev'),
#   ('Bomber Tsarnaev', 'Tsarnaev'),
#   ('Bomber Tsarnaev', 'bomber'),
#   ('Bomber Tsarnaev', 'citizen'),
#   ('Bomber Tsarnaev', 'immigrant'),
#   ('Denise Richard', 'parents'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'bomber'),
#   ('Dzhokhar', 'citizen'),
#   ('Dzhokhar', 'immigrant'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'citizen'),
#   ('Dzhokhar Tsarnaev', 'immigrant'),
#   ('Jurors', 'jurors'),
#   ('Jurors', 'jury'),
#   ('Louis Jones', 'kidnapper'),
#   ('Nadine Pellegrini', 'Pellegrini'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Timothy McVeigh', 'bomber'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'brother'),
#   ('Tsarnaev', 'citizen'),
#   ('Tsarnaev', 'immigrant'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'government'),
#   ('U.S.', 'government'),
#   ('bomber', 'immigrant'),
#   ('brothers', 'sibling'),
#   ('citizen', 'immigrant'),
#   ('jurors', 'jury'),
#   ('people', 'victims')},
#  {('Abdul Jabar Naeemi', 'governor'),
#   ('Afghan', 'Afghanistan'),
#   ('Afghan', 'government'),
#   ('Afghanistan', 'country'),
#   ('Afghanistan', 'government'),
#   ('Mahbubullah Sayedi', 'Sayedi'),
#   ('Mahbubullah Sayedi', 'chief'),
#   ('Noor Agha Faizi', 'spokesman'),
#   ('country', 'government')},
#  {('Alan Fry', 'Commissioner'),
#   ('Alan Fry', 'head'),
#   ('Brick Lane', 'area'),
#   ('Brick Lane', 'centre'),
#   ('London', 'capital'),
#   ('Police', 'police'),
#   ('Volvo', 'car'),
#   ('area', 'centre'),
#   ('bomb', 'device')},
#  {('America', 'Americans'),
#   ('America', 'U.S.'),
#   ('America', 'United States'),
#   ('American', 'Americans'),
#   ('American', 'Government'),
#   ('American', 'U.S.'),
#   ('American', 'United States'),
#   ('American', 'government'),
#   ('Americans', 'U.S.'),
#   ('Americans', 'United States'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'boy'),
#   ('Dzhokhar', 'brother'),
#   ('Dzhokhar', 'dealer'),
#   ('Dzhokhar', 'man'),
#   ('Dzhokhar', 'student'),
#   ('Dzhokhar Tsarnaev', 'boy'),
#   ('Dzhokhar Tsarnaev', 'brother'),
#   ('Dzhokhar Tsarnaev', 'dealer'),
#   ('Dzhokhar Tsarnaev', 'man'),
#   ('Dzhokhar Tsarnaev', 'student'),
#   ('FBI', 'Federal Bureau of Investigation'),
#   ('FBI', 'prosecution'),
#   ('FBI', 'prosecutors'),
#   ('Federal Bureau of Investigation', 'prosecutors'),
#   ('Government', 'U.S.'),
#   ('Government', 'United States'),
#   ('Khadzhimuradovs', 'family'),
#   ('Tamerlan', 'Tamerlan (C) Tsarnaev'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'follower'),
#   ('Tamerlan', 'man'),
#   ('Tamerlan', 'mastermind'),
#   ('Tamerlan (C) Tsarnaev', 'man'),
#   ('Tamerlan (C) Tsarnaev', 'mastermind'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Tamerlan Tsarnaev', 'man'),
#   ('Tamerlan Tsarnaev', 'mastermind'),
#   ('Tsarnaev', 'Tsarnaevs'),
#   ('Tsarnaev', 'family'),
#   ('Tsarnaevs', 'bombers'),
#   ('Tsarnaevs', 'boys'),
#   ('Tsarnaevs', 'brothers'),
#   ('Tsarnaevs', 'family'),
#   ('Tsarnaevs', 'sisters'),
#   ('U.S.', 'United States'),
#   ('United States', 'government'),
#   ('United States', 'here'),
#   ('bombers', 'boys'),
#   ('bombers', 'brothers'),
#   ('bombers', 'sisters'),
#   ('boy', 'brother'),
#   ('boy', 'dealer'),
#   ('boy', 'man'),
#   ('boys', 'brothers'),
#   ('boys', 'sisters'),
#   ('boys', 'sons'),
#   ('brother', 'dealer'),
#   ('brother', 'man'),
#   ('brothers', 'siblings'),
#   ('brothers', 'sisters'),
#   ('brothers', 'sons'),
#   ('defense', 'lawyers'),
#   ('follower', 'man'),
#   ('follower', 'mastermind'),
#   ('man', 'mastermind'),
#   ('people', 'three'),
#   ('prosecution', 'prosecutors'),
#   ('siblings', 'sisters'),
#   ('siblings', 'sons')},
#  {('London', 'central London'), ('suspect', 'youth')},
#  {('Colombia', 'Colombian'),
#   ('Colombia', 'government'),
#   ('ELN', 'National Liberation Army'),
#   ('ELN', 'group'),
#   ('Gen. Santander National Police Academy', 'establishment'),
#   ('National Liberation Army', 'group'),
#   ('academy', 'establishment')},
#  {('2,000', 'group'),
#   ('Bogota', 'Bogotá'),
#   ('Bogota', 'capital'),
#   ('Bogotá', 'capital'),
#   ('Bogotá', 'city'),
#   ('El Mocho', 'driver'),
#   ('El Mocho', 'man'),
#   ('El Mocho', 'member'),
#   ('El Mocho', 'suspect'),
#   ('José Aldemar Rojas Rodríguez', 'Kiko'),
#   ('José Aldemar Rojas Rodríguez', 'driver'),
#   ('José Aldemar Rojas Rodríguez', 'man'),
#   ('José Aldemar Rojas Rodríguez', 'member'),
#   ('José Aldemar Rojas Rodríguez', 'suspect'),
#   ('Kiko', 'driver'),
#   ('Kiko', 'man'),
#   ('Kiko', 'member'),
#   ('Kiko', 'suspect'),
#   ('Nissan Patrol', 'car'),
#   ('Nissan Patrol', 'vehicle'),
#   ('academy', 'school'),
#   ('capital', 'city'),
#   ('compound', 'where'),
#   ('driver', 'expert'),
#   ('driver', 'man'),
#   ('driver', 'member'),
#   ('driver', 'suspect'),
#   ('expert', 'man'),
#   ('expert', 'member'),
#   ('expert', 'suspect'),
#   ('explosive', 'explosives'),
#   ('group', 'itself it'),
#   ('group', 'rebels'),
#   ('group', 'terrorists'),
#   ('itself it', 'rebels'),
#   ('itself it', 'terrorists'),
#   ('people', 'victims'),
#   ('rebels', 'terrorists')},
#  {('Jorge Rodríguez', 'Minister'),
#   ('Maduro', 'Maduro’s'),
#   ('Maduro', 'Nicolás Maduro'),
#   ('Maduro', 'President'),
#   ('Maduro', 'driver'),
#   ('Maduro', 'leader'),
#   ('Maduro', 'president'),
#   ('Maduro’s', 'Nicolás Maduro'),
#   ('Maduro’s', 'President'),
#   ('Nicolás Maduro', 'President'),
#   ('Nicolás Maduro', 'driver'),
#   ('Nicolás Maduro', 'leader'),
#   ('Nicolás Maduro', 'president'),
#   ('Soldiers in T-Shirts', 'group'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'country'),
#   ('Venezuela', 'government'),
#   ('Venezuela', 'national'),
#   ('Venezuelan', 'country'),
#   ('Venezuelan', 'government'),
#   ('Venezuelan', 'national'),
#   ('Venezuelan', 'state'),
#   ('country', 'government'),
#   ('country', 'national'),
#   ('country', 'state'),
#   ('government', 'national'),
#   ('leader', 'president')},
#  {('Pakistan', 'country'),
#   ('Pakistan', 'government'),
#   ('country', 'government')},
#  {('Birmingham', 'city'),
#   ('Hambleton', 'Julie Hambleton'),
#   ('Hugh Southey QC', 'Southey'),
#   ('Maxine', 'sister'),
#   ('group', 'group Justice4the21'),
#   ('group', 'supporters'),
#   ('group Justice4the21', 'supporters'),
#   ('people', 'victims'),
#   ('pub', 'pubs')},
#  {('Bahrun Naim', 'Indonesian'),
#   ('Bahrun Naim', 'mastermind'),
#   ('Bali', 'Island'),
#   ('Bali', 'island'),
#   ('Indonesia', 'Indonesian'),
#   ('Indonesia', 'Indonesians'),
#   ('Indonesia', 'country'),
#   ('Indonesia', 'government'),
#   ('Indonesia', 'nation'),
#   ('Indonesian', 'Indonesians'),
#   ('Indonesian', 'country'),
#   ('Indonesian', 'government'),
#   ('Indonesians', 'country'),
#   ('Indonesians', 'government'),
#   ('Island', 'island'),
#   ('JI', 'group'),
#   ('Jakarta', 'capital'),
#   ('Jakarta', 'city'),
#   ('Jemaah Islamiyah', 'group'),
#   ('Muhamad Yunus', 'Yunus'),
#   ('Police', 'police'),
#   ('Starbucks', 'shop'),
#   ('Terrorist', 'terrorist'),
#   ('Yunus', 'hero'),
#   ('assailants', 'attackers'),
#   ('assailants', 'militants'),
#   ('attackers', 'militants'),
#   ('capital', 'city'),
#   ('government', 'nation')},
#  {('$20.99', '$41.28'),
#   ('Amberg', 'Rick Amberg'),
#   ('Bomb', 'bomb'),
#   ('Bomb', 'explosive device'),
#   ('Bomb', 'such a bomb'),
#   ('Bomb', 'that thing'),
#   ('Bomb', 'the bomb'),
#   ('Mohammed A. Salameh', 'Mr.'),
#   ('Mohammed A. Salameh', 'Salameh'),
#   ('Mohammed A. Salameh', 'suspect'),
#   ('Mr.', 'Salameh'),
#   ('Salameh', 'suspect'),
#   ('The bombers', 'The suspects'),
#   ('The bombers', 'the bombers'),
#   ('The suspects', 'the bombers'),
#   ('World Trade Center', 'the trade center'),
#   ('bomb', 'explosive device'),
#   ('bomb', 'such a bomb'),
#   ('bomb', 'that thing'),
#   ('bomb', 'the bomb'),
#   ('concoction', 'material'),
#   ('explosive', 'explosives'),
#   ('explosive device', 'such a bomb'),
#   ('explosives', 'the explosive'),
#   ('investigators', 'the authorities'),
#   ('investigators', 'the investigators'),
#   ('that thing', 'the bomb'),
#   ('the van', 'van'),
#   ('the van', 'vehicle'),
#   ('van', 'vehicle')},
#  {('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'Tsarnaev'),
#   ('Bomber', 'bomber'),
#   ('Collier', 'officer'),
#   ('Dias Kadyrbayev', 'Kadyrbayev'),
#   ('Dias Kadyrbayev', 'defendant'),
#   ('Dias Kadyrbayev', 'friend'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Kadyrbayev', 'defendant'),
#   ('Kadyrbayev', 'friend'),
#   ('Officer', 'officer'),
#   ('Sean Collier', 'officer'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Watertown', 'there'),
#   ('defendant', 'friend')},
#  {('German man', 'Marco G.'),
#   ('German man', 'main suspect'),
#   ('Marco G.', 'main suspect'),
#   ('Markus Beisicht', 'head'),
#   ('Markus Beisicht', 'head of ‘Pro NRW’'),
#   ('Markus Beisicht', 'leader'),
#   ('North Rhine-Westphalia', 'state'),
#   ('Three others', 'defendants'),
#   ('head of ‘Pro NRW’', 'leader')},
#  {('Sean Collier', 'officer'),
#   ('Sean Collier', 'policeman'),
#   ('Suspect', 'Tamerlan'),
#   ('Suspect', 'Tamerlan Tsarnaev'),
#   ('Suspect', 'Tsarnaev'),
#   ('Suspect', 'oldest'),
#   ('Suspects', 'brothers'),
#   ('Suspects', 'suspects'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'oldest'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tamerlan Tsarnaev', 'oldest'),
#   ('Tsarnaev', 'oldest'),
#   ('brothers', 'suspects'),
#   ('officer', 'policeman')},
#  {('Abdo', 'Naser Jason Abdo'),
#   ('Abdo', 'Pfc'),
#   ('Abdo', 'Soldier'),
#   ('Abdo', 'client'),
#   ('Abdo', 'soldier'),
#   ('Abdo', 'suspect'),
#   ('Al-Awlaki', 'cleric'),
#   ('American', 'U.S'),
#   ('American', 'U.S.'),
#   ('American', 'government'),
#   ('Anwar al-Awlaki', 'al-Awlaki'),
#   ('Anwar al-Awlaki', 'cleric'),
#   ('Awlaki', 'al-Awlaki'),
#   ('Awlaki', 'cleric'),
#   ('Greg Ebert', 'owner'),
#   ('Hasan', 'Major'),
#   ('Hasan', 'Nidal Hasan'),
#   ('Hasan', 'shooter'),
#   ('James M. Branum', 'lawyer'),
#   ('Major', 'Nidal Hasan'),
#   ('Major', 'shooter'),
#   ('Military', 'military'),
#   ('Naser Jason Abdo', 'Pfc'),
#   ('Naser Jason Abdo', 'Soldier'),
#   ('Naser Jason Abdo', 'client'),
#   ('Naser Jason Abdo', 'soldier'),
#   ('Naser Jason Abdo', 'suspect'),
#   ('Nidal Hasan', 'shooter'),
#   ('Pfc', 'Soldier'),
#   ('Pfc', 'soldier'),
#   ('Pfc', 'suspect'),
#   ('Soldier', 'client'),
#   ('Soldier', 'soldier'),
#   ('Soldier', 'suspect'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'government'),
#   ('U.S.', 'government'),
#   ('al-Awlaki', 'cleric'),
#   ('bombs', 'dual'),
#   ('bombs', 'two'),
#   ('client', 'soldier'),
#   ('client', 'suspect'),
#   ('court', 'courtroom'),
#   ('soldier', 'suspect')},
#  {('29', 'Requesens'),
#   ('Juan Requesens', 'Requesens'),
#   ('Maduro', 'Nicolas Maduro'),
#   ('Oscar Perez', 'Perez'),
#   ('Oscar Perez', 'officer'),
#   ('Perez', 'officer'),
#   ('Several', 'dozen'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'country'),
#   ('Venezuela', 'nation'),
#   ('Venezuela', 'national'),
#   ('Venezuela', 's'),
#   ('Venezuela', 'state'),
#   ('Venezuela', 'where'),
#   ('Venezuelan', 'country'),
#   ('Venezuelan', 'nation'),
#   ('Venezuelan', 'national'),
#   ('Venezuelan', 's'),
#   ('Venezuelan', 'state'),
#   ('Venezuelan', 'where'),
#   ('attackers', 'group'),
#   ('attackers', 'perpetrators'),
#   ('attackers', 'the alleged conspirators'),
#   ('attackers', 'the people'),
#   ('attackers', 'the perpetrators'),
#   ('country', 'national'),
#   ('government', 's'),
#   ('government', 'the government'),
#   ('group', 'the alleged conspirators'),
#   ('high-ranking', 'two'),
#   ('nation', 'national'),
#   ('nation', 's'),
#   ('nation', 'where'),
#   ('national', 's'),
#   ('national', 'state'),
#   ('national', 'where'),
#   ('perpetrators', 'plotters'),
#   ('perpetrators', 'the alleged conspirators'),
#   ('perpetrators', 'the people'),
#   ('perpetrators', 'the perpetrators'),
#   ('plotters', 'the alleged conspirators'),
#   ('plotters', 'the people'),
#   ('plotters', 'the perpetrators'),
#   ('s', 'the government'),
#   ('state', 'where'),
#   ('the people', 'the perpetrators')},
#  {('Santa Cruz', 'station'),
#   ('Santa Cruz station', 'station'),
#   ('Santacruz', 'station'),
#   ('Western line', 'line'),
#   ('bogey', 'compartment'),
#   ('bogey', 'compartments'),
#   ('compartment', 'compartments')},
#  {('Tokyo District Court', 'court'),
#   ('Yamamoto', 'Yasuo Yamamoto'),
#   ('Yamamoto', 'man'),
#   ('Yamamoto', 'resident'),
#   ('Yasuo Yamamoto', 'man'),
#   ('Yasuo Yamamoto', 'resident'),
#   ('man', 'resident'),
#   ('roof', 'rooftop')},
#  {('Butt', 'Khuram Shazad Butt'),
#   ('Butt', 'ringleader'),
#   ('Khalid Masood', 'militant'),
#   ('Khuram Shazad Butt', 'ringleader'),
#   ('London', 'capital'),
#   ('London Bridge', 'Westminster Bridge'),
#   ('May', 'Minister'),
#   ('May', 'PM'),
#   ('May', 'Theresa May'),
#   ('May', 'architect'),
#   ('May', 'minister'),
#   ('Minister', 'Theresa May'),
#   ('PM', 'Theresa May'),
#   ('PM', 'architect'),
#   ('PM', 'minister'),
#   ('architect', 'minister'),
#   ('home', 'minister'),
#   ('home', 'secretary')},
#  {('Bogota', 'capital'),
#   ('Bogotá', 'capital'),
#   ('Bogotá', 'city'),
#   ('Escuela General Santander', 'academy'),
#   ('Escuela General Santander', 'facility'),
#   ('Escuela General Santander', 'school'),
#   ('Escuela General Santander', 'where'),
#   ('Farc', 'Revolutionary Armed Forces of Colombia'),
#   ('Farc', 'group'),
#   ('General Santander police', 'police'),
#   ('Iván Duque', 'President'),
#   ('Police', 'police'),
#   ('Rafael Trujillo', 'Trujillo'),
#   ('Revolutionary Armed Forces of Colombia', 'group'),
#   ('academy', 'facility'),
#   ('academy', 'school'),
#   ('academy', 'where'),
#   ('capital', 'city'),
#   ('facility', 'school'),
#   ('facility', 'where'),
#   ('school', 'where')},
#  {('Ahmad Khan Rahami', 'Rahami'),
#   ('Ahmad Khan Rahami', 'citizen'),
#   ('Ahmad Khan Rahami', 'son'),
#   ('Ahmad Khan Rahami', 'suspect'),
#   ('Brother', 'Osama Bin Laden'),
#   ('Brother', 'head'),
#   ('Chelsea', 'neighborhood'),
#   ('FBI', 'Federal Bureau of Investigation'),
#   ('NYC', 'New York'),
#   ('Osama Bin Laden', 'head'),
#   ('Rahami', 'citizen'),
#   ('Rahami', 'son'),
#   ('Rahami', 'suspect'),
#   ('bearings', 'components'),
#   ('business', 'place'),
#   ('cell phones', 'phones'),
#   ('citizen', 'son'),
#   ('citizen', 'suspect'),
#   ('components', 'items'),
#   ('place', 'store'),
#   ('place', 'where'),
#   ('store', 'where')},
#  {('28', 'Ahmad Khan Rahami'),
#   ('28', 'Rahami'),
#   ('28', 'Suspect'),
#   ('28', 'son'),
#   ('Ahmad Khan Rahami', 'Rahami'),
#   ('Ahmad Khan Rahami', 'Suspect'),
#   ('Ahmad Khan Rahami', 'son'),
#   ('Ahmad Khan Rahami', 'suspect'),
#   ('Anwar al-Awlaki', 'cleric'),
#   ('Chelsea', 'neighborhood'),
#   ('Rahami', 'Suspect'),
#   ('Rahami', 'son'),
#   ('Rahami', 'suspect'),
#   ('business', 'place'),
#   ('business', 'store'),
#   ('business', 'where'),
#   ('components', 'items'),
#   ('place', 'store'),
#   ('place', 'where'),
#   ('store', 'where')},
#  {('260', 'more'),
#   ('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'Tsarnaev'),
#   ('Bomber', 'defendant'),
#   ('Bomber', 'suspect'),
#   ('Chechnya', 'region'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'defendant'),
#   ('Dzhokhar', 'son'),
#   ('Dzhokhar', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'defendant'),
#   ('Dzhokhar Tsarnaev', 'son'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Ibragim Todashev', 'son-in-law'),
#   ('James "Whitey" Bulger', 'James Whitey Bulger'),
#   ('James "Whitey" Bulger', 'boss'),
#   ('James Whitey Bulger', 'boss'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'defendant'),
#   ('Tsarnaev', 'son'),
#   ('Tsarnaev', 'suspect'),
#   ('U.S. District Court', 'court'),
#   ('court', 'where'),
#   ('son', 'suspect')},
#  {('CENTCOM', 'Joint Chiefs'),
#   ('CENTCOM', 'Joint Chiefs of Staff'),
#   ('Carter', 'Secretary'),
#   ('Cruz', 'Republican'),
#   ('Cruz', 'Sen'),
#   ('Cruz', 'Senator'),
#   ('Cruz', 'Ted Cruz'),
#   ('David', 'Genieve David'),
#   ('David', 'Maj'),
#   ('David', 'spokeswoman'),
#   ('Dunford', 'Gen'),
#   ('Dunford', 'Joseph Dunford'),
#   ('Dunford', 'chairman'),
#   ('EFP', 'EFPs'),
#   ('EFP', 'IEDs'),
#   ('EFP', 'bombs'),
#   ('EFP', 'device'),
#   ('EFP', 'penetrators'),
#   ('EFPs', 'IEDs'),
#   ('EFPs', 'bombs'),
#   ('EFPs', 'device'),
#   ('EFPs', 'penetrators'),
#   ('Gen', 'Joseph Dunford'),
#   ('Gen', 'Martin Dempsey'),
#   ('General', 'Soleimani'),
#   ('General', 'man'),
#   ('Genieve David', 'Maj'),
#   ('IEDs', 'bombs'),
#   ('IRAM', 'weapon'),
#   ('Iran', 'Iranian'),
#   ('Iran', 'Tehran'),
#   ('Iranian', 'Tehran'),
#   ('Iraq', 'Iraqi'),
#   ('Novack', 'Phil Novack'),
#   ('Novack', 'spokesman'),
#   ('Phil Novack', 'spokesman'),
#   ('Republican', 'Sen'),
#   ('Republican', 'Senator'),
#   ('Republican', 'Ted Cruz'),
#   ('Sen', 'Senator'),
#   ('Sen', 'Ted Cruz'),
#   ('Senator', 'Ted Cruz'),
#   ('device', 'munition'),
#   ('device', 'penetrators'),
#   ('device', 'weapon'),
#   ('lives', 'members'),
#   ('lives', 'soldiers'),
#   ('members', 'soldiers'),
#   ('munition', 'weapon'),
#   ('soldiers', 'troops')},
#  {('Bombs', 'The bombs'),
#   ('Bombs', 'the bombs'),
#   ('Deval Patrick', 'Governor'),
#   ('The bombs', 'the bombs'),
#   ('a "person of interest', 'suspect'),
#   ('a circuit board', 'object'),
#   ('any other bombs', 'five'),
#   ('any other bombs', 'no unexploded bombs'),
#   ('any other bombs', 'there'),
#   ('bomb', 'the bomb'),
#   ('bombs', 'the bombs'),
#   ('bombs', 'the exploded bombs'),
#   ('devices', 'the devices'),
#   ('expert', 'the expert'),
#   ('five', 'no unexploded bombs'),
#   ('man', 'suspect'),
#   ('terrorist', 'terrorists'),
#   ('the bombs', 'the exploded bombs')},
#  {('Campbell', 'Robert Campbell'),
#   ('Campbell', 'bomber'),
#   ('Campbell', 'member'),
#   ('Campbell', 'person'),
#   ('IRA', 'Irish Republican Army'),
#   ('IRA', 'Official IRA'),
#   ('IRA', 'Officials'),
#   ('IRA', 'Provisional IRA'),
#   ('Irish Republican Army', 'Official IRA'),
#   ('Irish Republican Army', 'Provisional IRA'),
#   ('Jeremy Snow', 'Major'),
#   ('Jeremy Snow', 'officer'),
#   ('Major', 'officer'),
#   ("McGurk's", "McGurk's Bar"),
#   ("McGurk's", 'Tramore Bar'),
#   ("McGurk's", 'building'),
#   ("McGurk's", 'house'),
#   ("McGurk's", 'premises'),
#   ("McGurk's", 'pub'),
#   ("McGurk's", 'there'),
#   ("McGurk's Bar", 'Tramore Bar'),
#   ("McGurk's Bar", 'building'),
#   ("McGurk's Bar", 'house'),
#   ("McGurk's Bar", 'premises'),
#   ("McGurk's Bar", 'pub'),
#   ("McGurk's Bar", 'there'),
#   ('New Lodge', 'New Lodge Road'),
#   ('New Lodge', 'area'),
#   ('New Lodge', 'community'),
#   ('New Lodge', 'district'),
#   ('New Lodge', 'neighbourhood'),
#   ('New Lodge Road', 'area'),
#   ('New Lodge Road', 'community'),
#   ('New Lodge Road', 'district'),
#   ('New Lodge Road', 'neighbourhood'),
#   ('Officials', 'Provisional IRA'),
#   ('Patrick McGurk', 'owner'),
#   ('RUC', 'Royal Ulster Constabulary'),
#   ('Robert Campbell', 'bomber'),
#   ('Robert Campbell', 'member'),
#   ('Robert Campbell', 'person'),
#   ('Shankill', 'area'),
#   ('Tramore Bar', 'pub'),
#   ('UVF', 'Ulster Volunteer Force'),
#   ('UVF', 'group'),
#   ('area', 'community'),
#   ('area', 'district'),
#   ('area', 'neighbourhood'),
#   ('bomb', 'package'),
#   ('bomber', 'member'),
#   ('bomber', 'person'),
#   ('bombers', 'men'),
#   ('boy', 'witness'),
#   ('building', 'house'),
#   ('building', 'premises'),
#   ('building', 'pub'),
#   ('building', 'there'),
#   ('civilians', 'members'),
#   ('civilians', 'victim'),
# ...
#   ('aircraft', 'drone'),
#   ('airplane', 'drone'),
#   ('drone', 'what'),
#   ('drones', 'small drones'),
#   ('itself', 'organization')},
#  {('Pine View High', 'school'),
#   ('Utah high school', 'school'),
#   ('boy', 'client'),
#   ('boy', 'defendant'),
#   ('boy', 'minor'),
#   ('boy', 'teenager'),
#   ('client', 'defendant'),
#   ('client', 'minor'),
#   ('client', 'teenager'),
#   ('defendant', 'teenager'),
#   ('minor', 'teenager')},
#  {('Azamat Tazhayakov', 'Tazhayakov'),
#   ('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'Tsarnaev'),
#   ('Dias Kadyrbayev', 'Kadyrbayev'),
#   ('Dias Kadyrbayev', 'friend'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Friend', 'Phillipos'),
#   ('Friend', 'Robel Phillipos'),
#   ('Friend', 'friend'),
#   ('Kadyrbayev', 'friend'),
#   ('Phillipos', 'Robel Phillipos'),
#   ('Phillipos', 'friend'),
#   ('Robel Phillipos', 'friend'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('room', 'there')},
#  {('Police', 'police'), ('Tsarnaev', 'brothers'), ('couple', 'pair')},
#  {('Diab', 'Hassan Diab'),
#   ('Diab', 'academic'),
#   ('Diab', 'father'),
#   ('Diab', 'man'),
#   ('Diab', 'member'),
#   ('Diab', 'professor'),
#   ('Diab', 's'),
#   ('Diab', 'sociologist'),
#   ('Hassan Diab', 'academic'),
#   ('Hassan Diab', 'father'),
#   ('Hassan Diab', 'man'),
#   ('Hassan Diab', 'member'),
#   ('Hassan Diab', 'professor'),
#   ('Hassan Diab', 's'),
#   ('Hassan Diab', 'sociologist'),
#   ('Synagogue', 'synagogue'),
#   ('academic', 'father'),
#   ('academic', 'man'),
#   ('academic', 'member'),
#   ('academic', 'professor'),
#   ('academic', 's'),
#   ('academic', 'sociologist'),
#   ('father', 'man'),
#   ('father', 'member'),
#   ('father', 's'),
#   ('father', 'sociologist'),
#   ('professor', 's'),
#   ('professor', 'sociologist')},
#  {('1', 'Tamerlan Tsarnaev'),
#   ('1', 'follower'),
#   ('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'Suspect'),
#   ('Bomber', 'Tsarnaev'),
#   ('Bomber', 'brother'),
#   ('Bomber', 'guy'),
#   ('Bomber', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Suspect', 'Tamerlan Tsarnaev'),
#   ('Suspect', 'Tsarnaev'),
#   ('Suspect', 'follower'),
#   ('Suspect', 'guy'),
#   ('Suspect', 'suspect'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Watertown', 'town'),
#   ('brother', 'guy'),
#   ('brother', 'suspect')},
#  {('Jonathan J. Dunbar', 'Sgt'), ('Syria', 'Syrian')},
#  {('Adams', 'Angela Adams'),
#   ('Adams', 'Attorney'),
#   ('Angela Adams', 'Attorney'),
#   ('Edward Flint', 'Flint'),
#   ('Edward Flint', 'attorney'),
#   ('Edward Flint', 'defender'),
#   ('Farnsworth', 'Farnsworth’s'),
#   ('Farnsworth', 'Martin'),
#   ('Farnsworth', 'Martin Farnsworth'),
#   ('Farnsworth', 'Teen'),
#   ('Farnsworth', 'citizen'),
#   ('Farnsworth', 'client'),
#   ('Farnsworth', 'person'),
#   ('Farnsworth', 'teen'),
#   ('Farnsworth’s', 'Martin'),
#   ('Farnsworth’s', 'Martin Farnsworth'),
#   ('Farnsworth’s', 'Teen'),
#   ('Farnsworth’s', 'citizen'),
#   ('Farnsworth’s', 'client'),
#   ('Farnsworth’s', 'person'),
#   ('Farnsworth’s', 'teen'),
#   ('Flint', 'attorney'),
#   ('Flint', 'defender'),
#   ('Judge', 'Michael Westfall'),
#   ('Judge', 'Westfall'),
#   ('Judge', 'judge'),
#   ('Martin', 'Martin Farnsworth'),
#   ('Martin', 'Teen'),
#   ('Martin', 'client'),
#   ('Martin', 'person'),
#   ('Martin', 'teen'),
#   ('Martin Farnsworth', 'Teen'),
#   ('Martin Farnsworth', 'citizen'),
#   ('Martin Farnsworth', 'client'),
#   ('Martin Farnsworth', 'person'),
#   ('Martin Farnsworth', 'teen'),
#   ('Michael Westfall', 'Westfall'),
#   ('Michael Westfall', 'judge'),
#   ('Pine View High', 'Pine View High School'),
#   ('Pine View High', 'high school'),
#   ('Pine View High', 'school'),
#   ('Pine View High School', 'high school'),
#   ('Pine View High School', 'school'),
#   ('Students', 'students'),
#   ('Teen', 'citizen'),
#   ('Teen', 'client'),
#   ('Teen', 'person'),
#   ('Teen', 'teen'),
#   ('Westfall', 'judge'),
#   ('attorney', 'defender'),
#   ('bomb', 'device'),
#   ('bomb', 'explosive'),
#   ('bomb', 'incendiary device'),
#   ('citizen', 'client'),
#   ('citizen', 'person'),
#   ('citizen', 'teen'),
#   ('client', 'person'),
#   ('client', 'teen'),
#   ('device', 'explosive'),
#   ('device', 'incendiary device'),
#   ('explosive', 'incendiary device'),
#   ('high school', 'school'),
#   ('person', 'teen')},
#  {('DOD', 'Defense'),
#   ('Donald Trump', 'President'),
#   ('Manbij', 'city'),
#   ('Mike Pompeo', 'Secretary'),
#   ('Palace of Princes restaurant', 'Palace of the Princes'),
#   ('Palace of Princes restaurant', 'restaurant'),
#   ('Palace of Princes restaurant', 'there'),
#   ('Palace of the Princes', 'restaurant'),
#   ('Palace of the Princes', 'there'),
#   ('Patrick Shanahan', 'Secretary'),
#   ('Syria', 'Syrian'),
#   ('restaurant', 'there')},
#  {('A 20-year-old former teaching student', 'Aydin Sevigin'),
#   ('A 20-year-old former teaching student', 'Sevigin'),
#   ('A 20-year-old former teaching student', 'Teaching student'),
#   ('A 20-year-old former teaching student', 'a martyr'),
#   ('Attunda District Court', 'the court'),
#   ('Aydin Sevigin', 'Sevigin'),
#   ('Aydin Sevigin', 'Teaching student'),
#   ('Aydin Sevigin', 'a martyr'),
#   ('Istanbul', 'Stockholm'),
#   ('Mikael Swahn', 'chairman'),
#   ('Police', 'the police'),
#   ('Sevigin', 'Teaching student'),
#   ('Sevigin', 'a martyr'),
#   ('Teaching student', 'a martyr'),
#   ('a bomb', 'a suicide bomb'),
#   ('a bomb', 'bomb'),
#   ('a bomb', 'bombs'),
#   ('a suicide bomb', 'bomb'),
#   ('a suicide bomb', 'bombs'),
#   ('bomb', 'bombs'),
#   ('ingredients', 'liquids'),
#   ('members', 'relatives'),
#   ('shrapnel', 'such a bomb')},
#  {('Birmingham', 'city'),
#   ('Bombers', 'bombers'),
#   ('Conway', 'Kieran Conway'),
#   ('Conway', 'chief'),
#   ('Conway', 'head'),
#   ('James McDade', 'lieutenant'),
#   ('John', 'John Smith'),
#   ('John', 'pensioner'),
#   ('John', 'resident'),
#   ('John', 'worker'),
#   ('John Smith', 'pensioner'),
#   ('John Smith', 'resident'),
#   ('Kieran Conway', 'chief'),
#   ('Kieran Conway', 'head'),
#   ('Marilyn', 'Marilyn Paula Nash'),
#   ('Marilyn', 'Paula'),
#   ('Marilyn', 'daughter'),
#   ('Marilyn', 'girl'),
#   ('Marilyn', 'neighbour'),
#   ('Marilyn', 's'),
#   ('Marilyn', 'victim'),
#   ('Marilyn', 'woman'),
#   ('Marilyn', 'worker'),
#   ('Marilyn Paula Nash', 'Paula'),
#   ('Marilyn Paula Nash', 'daughter'),
#   ('Marilyn Paula Nash', 'girl'),
#   ('Marilyn Paula Nash', 'neighbour'),
#   ('Marilyn Paula Nash', 's'),
#   ('Marilyn Paula Nash', 'victim'),
#   ('Marilyn Paula Nash', 'woman'),
#   ('Marilyn Paula Nash', 'worker'),
#   ('Minister', 'Sir'),
#   ('Nash', 'man'),
#   ('Nash', 'neighbour'),
#   ('Oliver Heald QC', 'Sir'),
#   ('Paula', 'daughter'),
#   ('Paula', 'woman'),
#   ('Pub', 'pub'),
#   ('chief', 'head'),
#   ('daughter', 'woman'),
#   ('girl', 'neighbour'),
#   ('girl', 's'),
#   ('girl', 'victim'),
#   ('girl', 'woman'),
#   ('girl', 'worker'),
#   ('man', 'neighbour'),
#   ('neighbour', 's'),
#   ('neighbour', 'woman'),
#   ('neighbour', 'worker'),
#   ('s', 'woman'),
#   ('s', 'worker'),
#   ('several', 'two'),
#   ('victim', 'woman'),
#   ('victim', 'worker')},
#  {('Afghanistan', 'E. Afghan'),
#   ('Afghanistan', 'country'),
#   ('E. Afghan', 'country'),
#   ('IED', 'explosive device'),
#   ('civilians', 'victims'),
#   ('improvised explosive devices', 'weapons'),
#   ('others', 'wounded')},
#  {('Abedi', 'Manchester Bomber'),
#   ('Abedi', 'Salman'),
#   ('Abedi', 'Salman Abedi'),
#   ('Abedi', 'Son'),
#   ('Abedi', 'bomber'),
#   ('Abedi', 'dropout'),
#   ('Abedi', 'enthusiast'),
#   ('Abedi', 'fan'),
#   ('Abedi', 'jihadist'),
#   ('Abedi', 'killer'),
#   ('Abedi', 'man'),
#   ('Abedi', 'part'),
#   ('Abedi', 'third'),
#   ('Abu Qaqa al-Britani', 'Hostey'),
#   ('Britain', 'British'),
#   ('Britain', 'government'),
#   ('British', 'government'),
#   ('Emma Webb', 'researcher'),
#   ('Ismail', 'brother'),
#   ('Libya', 'Libyan'),
#   ('Libya', 'country'),
#   ('Libyan', 'country'),
#   ('Manchester Bomber', 'Salman'),
#   ('Manchester Bomber', 'Salman Abedi'),
#   ('Manchester Bomber', 'bomber'),
#   ('Manchester Bomber', 'dropout'),
#   ('Manchester Bomber', 'enthusiast'),
#   ('Manchester Bomber', 'fan'),
#   ('Manchester Bomber', 'jihadist'),
#   ('Manchester Bomber', 'killer'),
#   ('Manchester Bomber', 'man'),
#   ('Mohammed Saeed', 'imam'),
#   ('Police', 'police'),
#   ('Ramadan Abedi', 'father'),
#   ('Ramadan Abedi', 'guard'),
#   ('Salman', 'dropout'),
#   ('Salman', 'enthusiast'),
#   ('Salman', 'fan'),
#   ('Salman', 'jihadist'),
#   ('Salman Abedi', 'dropout'),
#   ('Salman Abedi', 'enthusiast'),
#   ('Salman Abedi', 'fan'),
#   ('Salman Abedi', 'jihadist'),
#   ('bomb', 'device'),
#   ('bomber', 'dropout'),
#   ('bomber', 'enthusiast'),
#   ('bomber', 'fan'),
#   ('bomber', 'jihadist'),
#   ('bomber', 'man'),
#   ('bomber', 'third'),
#   ('brothers', 'parents'),
#   ('dropout', 'enthusiast'),
#   ('dropout', 'fan'),
#   ('dropout', 'jihadist'),
#   ('dropout', 'killer'),
#   ('dropout', 'man'),
#   ('enthusiast', 'fan'),
#   ('enthusiast', 'jihadist'),
#   ('father', 'guard'),
#   ('killer', 'man'),
#   ('part', 'third')},
#  {('Dzhokhar', 'brother'),
#   ('Russia', 'Russian'),
#   ('Russia', 'Russians'),
#   ('Russian', 'Russians'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'follower'),
#   ('Tamerlan', 'son'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Tamerlan Tsarnaev', 'son'),
#   ('Tsarnaev', 'follower'),
#   ('Tsarnaev', 'son')},
#  {('I.S.B', 'Islamic Society of Boston'),
#   ('Islamic Society of Boston', 'organization'),
#   ('Islamic Society of Boston mosque', 'center'),
#   ('Islamic Society of Boston mosque', 'congregation'),
#   ('Islamic Society of Boston mosque', 'mosque'),
#   ('Islamic Society of Boston mosque', 'there'),
#   ('Muhammad', 'Prophet'),
#   ('Steve Annear', 'contributor'),
#   ('Steve Annear', 'journalist'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'suspect'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tamerlan Tsarnaev', 'suspect'),
#   ('Tsarnaev', 'suspect'),
#   ('Vali', 'Yusufi Vali'),
#   ('Vali', 'spokesman'),
#   ('brothers', 'suspects'),
#   ('center', 'congregation'),
#   ('center', 'mosque'),
#   ('center', 'there'),
#   ('congregation', 'there'),
#   ('contributor', 'journalist'),
#   ('guest', 'suspects'),
#   ('mosque', 'there'),
#   ('s', 'suspects')},
#  {('A3 Pro positioning system', 'three'),
#   ('A3 Pro positioning system', 'three-sensor system'),
#   ('CNN', 'Cable News Network'),
#   ('M600', 'M600 Pro model'),
#   ('M600', 'model'),
#   ('M600 Pro model', 'model'),
#   ('M600 Pros', 'M600 drones'),
#   ('M600 Pros', 'drones'),
#   ('M600 Pros', 'the M600 Pro drones'),
#   ('M600 Pros', 'the drones'),
#   ('M600 Pros', 'two'),
#   ('M600 drones', 'the M600 Pro drones'),
#   ('M600 drones', 'the drones'),
#   ('Maduro', 'President'),
#   ('Maduro', 'president'),
#   ('Matrice M600 Pro', 'model'),
#   ('Matrice M600 Pro c-drones', 'drones'),
#   ('Matrice M600 Pro c-drones', 'the M600 Pro drones'),
#   ('Matrice M600 Pro c-drones', 'the drones'),
#   ('Matrice M600 Pro c-drones', 'the drones used in the attack'),
#   ('Matrice M600 Pro c-drones', 'two'),
#   ('Nicolás Maduro', 'President'),
#   ('Nicolás Maduro', 'president'),
#   ('Phantom', 'Phantom models'),
#   ('President', 'president'),
#   ('The man interviewed', 'man'),
#   ('The man interviewed', 'organizer'),
#   ('drones', 'the M600 Pro drones'),
#   ('drones', 'the drones'),
#   ('drones', 'the drones used in the attack'),
#   ('drones', 'two'),
#   ('man', 'organizer'),
#   ('the M600 Pro drones', 'the drones'),
#   ('the drones used in the attack', 'two')},
#  {('19-year-old', 'Dzhokar'),
#   ('19-year-old', 'Dzhokhar Tsarnaev'),
#   ('19-year-old', 'student'),
#   ('Dzhokar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokar', 'student'),
#   ('Dzhokar Tsarnaev', 'Dzhokhar Tsarnaev'),
#   ('Dzhokar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokar Tsarnaev', 'student'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'student'),
#   ('Dzhokhar', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'student'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Federal Medical Center Devens', 'prison medical facility'),
#   ('Russia', 'Russian'),
#   ('Tamerlan', 'co-conspirator'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tamerlan Tsarnaev', 'co-conspirator'),
#   ('Tsarnaev', 'student'),
#   ('Tsarnaev', 'suspect'),
#   ('brother', 'co-conspirator'),
#   ('hospital', 'where')},
#  {('40', 'Yasuo Yamamoto'),
#   ('Phantom 2', 'drone'),
#   ('Phantom 2', 'unmanned drone'),
#   ('drone', 'unmanned drone'),
#   ('man', 'operator'),
#   ('office', 'roof'),
#   ('office', 'there'),
#   ('roof', 'there')},
#  {('American', 'U.S'),
#   ('American', 'U.S.'),
#   ('American', 'United States'),
#   ('American', 'Washington'),
#   ('American', 'enemy'),
#   ('American', 'government'),
#   ('American', 'here'),
#   ('American', 'itself'),
#   ('Anwar al-Awlaki', 'Awlaki'),
#   ('Anwar al-Awlaki', 'citizen'),
#   ('Anwar al-Awlaki', 'piper'),
#   ('Atiyah Abd al-Rahman', 'aide'),
#   ('Awlaki', 'citizen'),
#   ('Awlaki', 'piper'),
#   ('Baitullah Mehsud', 'leader'),
#   ('Pakistan', 'Pakistani'),
#   ('Pakistan', 'country'),
#   ('Pakistan', 'government'),
#   ('Pakistan', 'own'),
#   ('Pakistani', 'country'),
#   ('Pakistani', 'government'),
#   ('Pakistani', 'own'),
#   ('Tomahawks', 'missile'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'United States'),
#   ('U.S', 'Washington'),
#   ('U.S', 'enemy'),
#   ('U.S', 'government'),
#   ('U.S', 'here'),
#   ('U.S', 'itself'),
#   ('U.S', 'people'),
#   ('U.S.', 'United States'),
#   ('U.S.', 'Washington'),
#   ('U.S.', 'enemy'),
#   ('U.S.', 'government'),
#   ('U.S.', 'here'),
#   ('U.S.', 'itself'),
#   ('United States', 'Washington'),
#   ('United States', 'enemy'),
#   ('United States', 'government'),
#   ('United States', 'here'),
#   ('United States', 'itself'),
#   ('United States', 'people'),
#   ('Washington', 'enemy'),
#   ('Washington', 'government'),
#   ('Washington', 'here'),
#   ('Washington', 'itself'),
#   ('Yemen', 'Yemeni'),
#   ('Yemen', 'Yemenis'),
#   ('Yemen', 'country'),
#   ('Yemeni', 'Yemenis'),
#   ('Yemeni', 'country'),
#   ('citizen', 'piper'),
#   ('country', 'government'),
#   ('country', 'own'),
#   ('drone', 'drones'),
#   ('government', 'here'),
#   ('government', 'itself'),
#   ('government', 'own')},
#  {('Bauman', 'Jeff Bauman'),
#   ('Bauman', 'spectator'),
#   ('Bauman', 'survivor'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'brother'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ("George O'Toole", 'John Joseph Moakley'),
#   ('Jeff Bauman', 'spectator'),
#   ('Jeff Bauman', 'survivor'),
#   ('Judy Clarke', 'lawyer'),
#   ('Rebekah Gregory', 'survivor'),
#   ('Rebekah Gregory', 'two'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'brother'),
#   ('Tsarnaev', 'suspect'),
#   ('Tsarnaevs', 'brothers'),
#   ('Tsarnaevs', 'suspects'),
#   ('U.S.', 'home'),
#   ('brother', 'suspect'),
#   ('brothers', 'suspects'),
#   ('courthouse', 'where'),
#   ('spectator', 'survivor')},
#  {('Birmingham Six,', 'Six'),
#   ('Birmingham Six,', 'Six men'),
#   ('Birmingham Six,', 'people'),
#   ('Brother', 'Julie'),
#   ('Kevin Winters', 'Winters'),
#   ('Kevin Winters', 'lawyer'),
#   ('Maxine', 'sister'),
#   ('Six men', 'people'),
#   ('Winters', 'lawyer')},
#  {('28', 'Velentzas'),
#   ('31', 'Asia Siddiqui'),
#   ('31', 'Siddiqui'),
#   ('Al Farekh', 'Muhanad Mahmoud Al Farekh'),
#   ('American', 'homeland'),
#   ('American', 'nation'),
#   ('Asia Siddiqui', 'Siddiqui'),
#   ('Asia Siddiqui', 'client'),
#   ('New York', 'New York City'),
#   ('Noelle Velentzas', 'Velentzas'),
#   ('Siddiqui', 'client'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'homeland'),
#   ('U.S', 'nation'),
#   ('U.S.', 'homeland'),
#   ('U.S.', 'nation'),
#   ('agent', 'officer'),
#   ('agent', 'undercover'),
#   ('citizens', 'pair'),
#   ('citizens', 'women'),
#   ('court', 'federal court'),
#   ('homeland', 'nation'),
#   ('officer', 'undercover'),
#   ('officers', 'two'),
#   ('pair', 'women')},
#  {('John Morrow', 'workman'),
#   ("McGurk's bar", 'bar'),
#   ("McGurk's bar", 'building'),
#   ('North Queens Street', 'area'),
#   ("Paddy McGurk's", 'Paddy McManus'),
#   ('Robert Campbell', 'member'),
#   ('bar', 'building'),
#   ('loyalist', 'loyalists'),
#   ('people', 'victims')},
#  {('Abdifatah W', 'companion'),
#   ('Omar D', 'Omar D.'),
#   ('Omar D', 'suspect'),
#   ('Omar D.', 'suspect')}]

# %%
list(filter(None,
            [x.difference(coref_pairs_nonempty[i]) for i, x in enumerate(coref_pairs_non_single_mention_non_empty)]))
# Out:
# [{('America', 'American'),
#   ('America', 'Boston'),
#   ('America', 'U.S'),
#   ('America', 'U.S.'),
#   ('America', 'here'),
#   ('American', 'Boston'),
#   ('American', 'U.S'),
#   ('American', 'U.S.'),
#   ('American', 'here'),
#   ('Bomber', 'Tsarnaev'),
#   ('Boston', 'U.S'),
#   ('Boston', 'here'),
#   ('Chechen', 'Tsarnaev'),
#   ('Chechen', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Karen Rand McWatters', 'McWatters'),
#   ('Krystle Campbell', 'daughter'),
#   ('Martin', 'brother'),
#   ('Martin', 'son'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'immigrant'),
#   ('U.S', 'here'),
#   ('U.S.', 'here'),
#   ('bomber', 'immigrant'),
#   ('people', 'victims'),
#   ('person', 'son')},
#  {('Afghan', 'Afghanistan'),
#   ('Afghan', 'country'),
#   ('Afghan', 'where'),
#   ('Afghanistan', 'country'),
#   ('Afghanistan', 'where'),
#   ('Pakistan', 'hub'),
#   ('civilians', 'people'),
#   ('drone', 'drones')},
#  {('Andrew Cuomo', 'Cuomo'),
#   ('Bill de Blasio', 'DeBlasio'),
#   ('Bill de Blasio', 'de Blasio'),
#   ('DeBlasio', 'de Blasio'),
#   ('Donald', 'spokesman'),
#   ('Donald Trump', 'nominee'),
#   ('Keith Salomon', 'Salomon'),
#   ('New York', 'city'),
#   ('New York', 'state'),
#   ('New York Police Department', 'Police'),
#   ('New York Police Department', 'department'),
#   ('New York Police Department', 'police'),
#   ('Police', 'department'),
#   ('Police', 'police'),
#   ('Trump', 'nominee'),
#   ('area', 'neighborhood'),
#   ('area', 'where'),
#   ('attacker', 'man'),
#   ('department', 'police'),
#   ('man', 'soldier')},
#  {('264', 'wounded'),
#   ('Dzhokhar', 'brother'),
#   ('Suspects', 'Tsarnaev'),
#   ('Suspects', 'brothers'),
#   ('Suspects', 'suspects'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'brothers'),
#   ('brothers', 'sons'),
#   ('brothers', 'suspects'),
#   ('sons', 'suspects')},
#  {('19', 'Dzhokhar Tsarnaev'),
#   ('26', 'Tamerlan'),
#   ('26', 'Tamerlan Tsarnaev'),
#   ('26', 'another person'),
#   ('Both brothers', 'Tsarnaevs'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Ruger pistol', 'gun'),
#   ('Ruger semi-automatic pistol', 'gun'),
#   ('Silva', 'Stephen Silva'),
#   ('Silva', 'his close friend'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'another person'),
#   ('Tamerlan Tsarnaev', 'another person'),
#   ('Tsarnaevs', 'lifeguards'),
#   ('Whole Foods', 'store'),
#   ('a gun', 'gun'),
#   ('bombs', 'the bombs'),
#   ('bombs', 'two'),
#   ('handguns', 'two'),
#   ('the bombs', 'two')},
#  {('Bin Laden', 'bin Laden'),
#   ('Bin Laden', 'suspect'),
#   ('Osama bin Laden', 'bin Laden'),
#   ('bin Laden', 'suspect')},
#  {('22', 'people'),
#   ('26', 'people'),
#   ('Ashraf Ghani', 'Ghani'),
#   ('Ashraf Ghani', 'president'),
#   ('Ghani', 'President'),
#   ('Ghani', 'president'),
#   ('President', 'president'),
#   ('ground', 'site')},
#  {('Authorities', 'authorities'),
#   ('Bilal', 'Bilal Mohammed'),
#   ('Bilal', 'client'),
#   ('Bilal', 'man'),
#   ('Bilal Mohammed', 'man'),
#   ('China', 'Chinese'),
#   ('China', 'where'),
#   ('Chinese', 'where'),
#   ('Chuchart Kanpai', 'lawyer'),
#   ('Erawan Shrine', 'Shrine'),
#   ('Erawan Shrine', 'destination'),
#   ('Erawan Shrine', 'shrine'),
#   ('Mieraili', 'Mieraili Yusufu'),
#   ('Mieraili', 'Yusufu'),
#   ('Mieraili Yusufu', 'Yusufu'),
#   ('National Police', 'Police'),
#   ('National Police', 'police'),
#   ('Police', 'police'),
#   ('Shrine', 'destination'),
#   ('Shrine', 'shrine'),
#   ('Thai', 'Thailand'),
#   ('Thai', 'country'),
#   ('Thailand', 'country'),
#   ('client', 'man'),
#   ('destination', 'shrine'),
#   ('men', 'suspect'),
#   ('men', 'suspects'),
#   ('men', 'two'),
#   ('suspect', 'suspects'),
#   ('suspects', 'two')},
#  {('Maduro', 'Maduro’s'),
#   ('Maduro', 'Nicolás Maduro'),
#   ('Maduro', 'President'),
#   ('Maduro', 'president'),
#   ('Maduro’s', 'President'),
#   ('Maduro’s', 'president'),
#   ('Nestor Reverol', 'Reverol'),
#   ('Nicolás Maduro', 'President'),
#   ('Nicolás Maduro', 'president'),
#   ('President', 'president'),
#   ('Reverol', 'minister'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'Venezuela’s'),
#   ('Venezuela', 'government'),
#   ('Venezuela', 'state'),
#   ('Venezuela', 'the'),
#   ('Venezuelan', 'government'),
#   ('Venezuelan', 'state'),
#   ('Venezuela’s', 'government'),
#   ('Venezuela’s', 'state'),
#   ('Venezuela’s', 'the'),
#   ('apartment', 'building'),
#   ('drone', 'drones'),
#   ('government', 'state'),
#   ('government', 'the'),
#   ('vicinity', 'where')},
#  {('21', 'people'),
#   ('Birmingham', 'Town'),
#   ('Birmingham', 'city'),
#   ('Brian', 'Brian Hambleton'),
#   ('British', 'England'),
#   ('Conway', 'Fighter'),
#   ('Conway', 'Kieran Conway'),
#   ('Conway', 'head'),
#   ('Fighter', 'head'),
#   ('IRA', 'Irish'),
#   ('IRA', 'organisation'),
#   ('IRA', 'republican'),
#   ('Irish', 'organisation'),
#   ('Irish', 'republican'),
#   ('James McDade', 'McDade'),
#   ('James McDade', 'bomber'),
#   ('James McDade', 'lieutenant'),
#   ('James McDade', 'volunteer'),
#   ('Kieran Conway', 'head'),
#   ('McDade', 'bomber'),
#   ('McDade', 'lieutenant'),
#   ('McDade', 'volunteer'),
#   ('Town', 'city'),
#   ('bomber', 'lieutenant'),
#   ('group', 'republican')},
#  {('Badia', 'spot'),
#   ('Badia', 'zone'),
#   ('Badia al-Sukhnah', 'area'),
#   ('General', 'Vyacheslav Gladkikh'),
#   ('General', 'general'),
#   ('IS', 'Islamic State'),
#   ('Syria', 'Syrian'),
#   ('Syria', 'country'),
#   ('Syria', 'there'),
#   ('Syrian', 'country'),
#   ('Syrian', 'there'),
#   ('Vyacheslav Gladkikh', 'general'),
#   ('area', 'spot'),
#   ('area', 'zone'),
#   ('country', 'there')},
#  {('American', 'U.S.'),
#   ('Chávez', 'Hugo Chávez'),
#   ('Gabriela Ramírez', 'Ramírez'),
#   ('Government', 'employer'),
#   ('Government', 'government'),
#   ('Government', 'state'),
#   ('Government', 'the government'),
#   ('employer', 'government'),
#   ('employer', 'state'),
#   ('employer', 'the government'),
#   ('government', 'state'),
#   ('government', 'the government'),
#   ('opposition', 'the opposition'),
#   ('state', 'the government')},
#  {('Police', 'police')},
#  {('Dagestan', 'Dagestani'),
#   ('Dagestan', 'Republic of Dagestan'),
#   ('Dagestan', 'land'),
#   ('Dagestan', 'place'),
#   ('Dagestan', 'province'),
#   ('Dagestan', 'region'),
#   ('Dagestan', 'republic'),
#   ('Dagestan', 'state'),
#   ('Dagestani', 'place'),
#   ('Dagestani', 'republic'),
#   ('Federal', 'Russia'),
#   ('Federal', 'Russian'),
#   ('Moscow', 'Russia'),
#   ('Moscow', 'Russian'),
#   ('Republic of Dagestan', 'land'),
#   ('Republic of Dagestan', 'place'),
#   ('Republic of Dagestan', 'region'),
#   ('Republic of Dagestan', 'republic'),
#   ('Russia', 'Russian'),
#   ('Russia', 'Russian Federation'),
#   ('Russian', 'Russian Federation'),
#   ('land', 'place'),
#   ('land', 'republic'),
#   ('province', 'region'),
#   ('province', 'republic'),
#   ('region', 'republic'),
#   ('region', 'state'),
#   ('republic', 'state')},
#  {('Juan Requesens', 'lawmaker')},
#  {('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('people', 'three')},
#  {('Lyon', 'city'),
#   ('Police', 'police'),
#   ('Victor Hugo street', 'street'),
#   ('man', 'suspect')},
#  {('British', 'UK'),
#   ('British', 'country'),
#   ('British', 'government'),
#   ('British', 'the'),
#   ('UAVs', 'aircraft'),
#   ('UAVs', 'missiles'),
#   ('UAVs', 'unmanned aerial vehicles'),
#   ('UK', 'country'),
#   ('UK', 'government'),
#   ('UK', 'the'),
#   ('country', 'the'),
#   ('drones', 'weaponised consumer drones'),
#   ('government', 'the'),
#   ('soil', 'the')},
#  {('Ash Carter', 'Secretary'),
#   ('Bagram', 'Bagram Air Base'),
#   ('Bagram', 'Bagram Airfield'),
#   ('Bagram Air Base', 'Bagram Airfield'),
#   ('members', 'six'),
#   ('members', 'victims'),
#   ('six', 'victims')},
#  {('Aragua', 's'),
#   ('Aragua', 'state'),
#   ('Central Hospital of Maracay', 'hospital'),
#   ('hospital', 'the Maracay Central Hospital')},
#  {('12', 'people'),
#   ('Antonio Durán', 'director'),
#   ('ETA', 'group'),
#   ('ETA', 'organisation'),
#   ('Eva Forest', 'Forest'),
#   ('Eva Forest', 'wife'),
#   ('Forest', 'wife'),
#   ('María del Carmen Nadal', 'wife'),
#   ('Rolando', 'Rolando Cafe'),
#   ('Rolando', 'building'),
#   ('Rolando', 'cafe'),
#   ('Rolando Cafe', 'building'),
#   ('Rolando Cafe', 'cafe'),
#   ('Rolando cafe', 'building'),
#   ('Rolando cafe', 'cafe'),
#   ('Two', 'two'),
#   ('Vicente Sainz de la Peña', 'director'),
#   ('building', 'cafe'),
#   ('group', 'organisation')},
#  {('Azamat Tazhayakov', 'Tazhayakov'),
#   ('Azamat Tazhayakov', 'friend'),
#   ('Friend', 'Tazhayakov'),
#   ('Friend', 'friend'),
#   ('Friend', 'friends'),
#   ('Friend', 'student'),
#   ('Tazhayakov', 'friend'),
#   ('Tazhayakov', 'friends'),
#   ('friend', 'friends'),
#   ('friend', 'student')},
#  {('Eldon Elliott', 'Elliott'),
#   ('Eldon Elliott', "Elliott's"),
#   ('Eldon Elliott', 'owner'),
#   ('Elliott', "Elliott's"),
#   ('Elliott', 'owner'),
#   ("Elliott's", 'owner'),
#   ("Elliott's Body Shop", 'shop'),
#   ('Geary Lake', 'there'),
#   ('Junction City', 'where'),
#   ('Kling', 'Robert Kling'),
#   ('Kling', 'caller'),
#   ('McVeigh', 'Timothy McVeigh'),
#   ('McVeigh', 'man'),
#   ('Mendeloff', 'Scott Mendeloff'),
#   ('Mendeloff', 'prosecutor'),
#   ('Murrah Federal Building', 'building'),
#   ('Prosecutors', 'prosecutors'),
#   ('Ryder', 'Ryder truck'),
#   ('Ryder', 'truck'),
#   ('Ryder truck', 'truck'),
#   ('Scott Mendeloff', 'prosecutor'),
#   ('Timothy McVeigh', 'man'),
#   ('Yuhua Bai', 'owner'),
#   ('depot', 'where'),
#   ('jurors', 'jury')},
#  {('Duffield', 'client'),
#   ('Duffield', 'driver'),
#   ('Terry Duffield', 'driver'),
#   ('client', 'driver')},
#  {('Hussein', 'Saddam'),
#   ('Hussein', 'Saddam Hussein'),
#   ('McVeigh', 'Timothy McVeigh'),
#   ('McVeigh', 'bomber'),
#   ('Saddam', 'Saddam Hussein'),
#   ('Terry Nichols', 'co-conspirator')},
#  {('Maduro', 'Nicolás Maduro'),
#   ('Maduro', 'palco presidencial'),
#   ('Maduro', 'the president'),
#   ('Pérez', 'Óscar Pérez'),
#   ('Venezuela', 'country'),
#   ('Venezuela', 'nation'),
#   ('Venezuela', 's'),
#   ('Venezuela', 'the government'),
#   ('apartment', 'building'),
#   ('country', 'government'),
#   ('country', 'nation'),
#   ('country', 's'),
#   ('country', 'the government'),
#   ('country', 'where'),
#   ('government', 'nation'),
#   ('government', 's'),
#   ('government', 'the government'),
#   ('government', 'where'),
#   ('nation', 's'),
#   ('nation', 'the government'),
#   ('s', 'the government'),
#   ('the government', 'where')},
#  {('Chao Praya river', 'river'),
#   ('National', 'Royal Thai'),
#   ('National', 'Thai'),
#   ('National', 'Thailand'),
#   ('National', 'government'),
#   ('National', 'kingdom'),
#   ('Police', 'Royal Thai Police'),
#   ('Police', 'national police'),
#   ('Police', 'police'),
#   ('Royal Thai', 'Thai'),
#   ('Royal Thai', 'Thailand'),
#   ('Royal Thai', 'government'),
#   ('Royal Thai', 'kingdom'),
#   ('Royal Thai Police', 'police'),
#   ('Suspect', 'foreigner'),
#   ('Suspect', 'man'),
#   ('Suspect', 'suspect'),
#   ('Thai', 'Thailand'),
#   ('Thai', 'government'),
#   ('Thai', 'kingdom'),
#   ('Thailand', 'government'),
#   ('Thailand', 'kingdom'),
#   ('consulate', 'where'),
#   ('foreigner', 'man'),
#   ('foreigner', 'suspect'),
#   ('man', 'suspect'),
#   ('national police', 'police')},
#  {('bomb', 'ourself'), ('bomber', 'suspect'), ('bomber', 'white')},
#  {('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'country'),
#   ('Venezuela', 'government'),
#   ('Venezuela', 's'),
#   ('Venezuelan', 'country'),
#   ('Venezuelan', 's'),
#   ('country', 's'),
#   ('government', 's')},
#  {('-year-old', 'man'),
#   ('-year-old', 'refugee'),
#   ('17', 'four'),
#   ('Abdullah Reda al-Hamamy', 'man'),
#   ('British parliament', 'parliament'),
#   ('Frenchman', 'attacker'),
#   ('German', 'Germany'),
#   ('Islamic State', 'Islamist'),
#   ('Mehdi Nemmouche', 'attacker'),
#   ('Mehdi Nemmouche', 'national'),
#   ('Nice', 'city'),
#   ('a heavy truck', 'truck'),
#   ('attacker', 'national'),
#   ('gunman', 'teenager'),
#   ('man', 'refugee')},
#  {('Boston', 'Massachusetts'),
#   ('Boston', 'South Boston'),
#   ('Boston', 'city'),
#   ('Boston', 'state'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'defendant'),
#   ('Dzhokhar', 'student'),
#   ('Dzhokhar Tsarnaev', 'Suspect'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'defendant'),
#   ('Dzhokhar Tsarnaev', 'student'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Jury', 'jury'),
#   ('Lingzi Lu', 'student'),
#   ('Massachusetts', 'South Boston'),
#   ('Massachusetts', 'city'),
#   ('Massachusetts', 'state'),
#   ('Suspect', 'Tsarnaev'),
#   ('Suspect', 'bomber'),
#   ('Suspect', 'defendant'),
#   ('Suspect', 'student'),
#   ('Suspect', 'suspect'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'defendant'),
#   ('Tsarnaev', 'student'),
#   ('Tsarnaev', 'suspect'),
#   ('bomber', 'defendant'),
#   ('bomber', 'student'),
#   ('bomber', 'suspect')},
#  {('Aaron Driver', 'Driver'),
#   ('Aaron Driver', 'driver'),
#   ('Aaron Driver', 'man'),
#   ('Driver', 'Harun Abdurahman'),
#   ('Driver', 'driver'),
#   ('Driver', 'man'),
#   ('Harun Abdurahman', 'driver'),
#   ('Harun Abdurahman', 'man'),
#   ('driver', 'man')},
#  {('191', 'victims'), ('four trains', 'trains')},
#  {('Boston Bomber', 'Dzhokhar'),
#   ('Boston Bomber', 'Dzhokhar Tsarnaev'),
#   ('Boston Bomber', 'Tsarnaev'),
#   ('Boston Bomber', 'bomber'),
#   ('Boston Bomber', 'person'),
#   ('Campbell', 'daughter'),
#   ('Collier', 'Sean Collier'),
#   ('Collier', 'officer'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'immigrant'),
#   ('Dzhokhar Tsarnaev', 'person'),
#   ("George O'Toole", "O'Toole"),
#   ('Sean Collier', 'officer'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'immigrant'),
#   ('Tsarnaev', 'person'),
#   ('people', 'victims')},
#  {('Brothers', 'pair'),
#   ('Brothers', 'suspects'),
#   ('Khairullozhon Matanov', 'Matanov'),
#   ('Khairullozhon Matanov', 'national'),
#   ('Matanov', 'driver'),
#   ('Matanov', 'national'),
#   ('Matanov', 'person'),
#   ('Tamerlan Tsarnaev', 'left'),
#   ('Tsarnaev', 'bombers'),
#   ('Tsarnaev', 'brothers'),
#   ('Tsarnaev', 'pair'),
#   ('Tsarnaev', 'suspects'),
#   ('bombers', 'brothers'),
#   ('bombers', 'pair'),
#   ('bombers', 'suspects'),
#   ('brothers', 'pair'),
#   ('brothers', 'suspects'),
#   ('driver', 'national'),
#   ('national', 'person'),
#   ('pair', 'suspects')},
#  {('Andino', 'Centro Andino'),
#   ('Andino', 'mall'),
#   ('Arauca', 'city'),
#   ('Bogotá', 'capital'),
#   ('Bogotá', 'city'),
#   ('Carvajal Salgar', 'Ricardo Carvajal'),
#   ('Chicó', 'Erika Chicó'),
#   ('Chicó', 'cadet'),
#   ('Chicó', 'national'),
#   ('Colombia', 'Colombian'),
#   ('Colombia', 'Government'),
#   ('Colombia', 'country'),
#   ('Colombia', 'government'),
#   ('Colombia', 'nation'),
#   ('Colombian', 'Government'),
#   ('Colombian', 'country'),
#   ('Colombian', 'government'),
#   ('Colombian', 'nation'),
#   ('ELN', 'National Liberation Army'),
#   ('ELN', 'group'),
#   ('ELN', 'movement'),
#   ('ELN', 'organization'),
#   ('Erika Chicó', 'cadet'),
#   ('Erika Chicó', 'national'),
#   ('General Santander National Police Academy', 'academy'),
#   ('General Santander National Police Academy', 'facility'),
#   ('Government', 'country'),
#   ('Government', 'government'),
#   ('Government', 'nation'),
#   ('José Aldemar Rojas Rodríguez', 'Rojas'),
#   ('José Aldemar Rojas Rodríguez', 'Rojas Rodríguez'),
#   ('José Aldemar Rojas Rodríguez', 'member'),
#   ('José Aldemar Rojas Rodríguez', 'perpetrator'),
#   ('Mocho Kiko', 'Rojas'),
#   ('Mocho Kiko', 'Rojas Rodríguez'),
#   ('Mocho Kiko', 'member'),
#   ('National Liberation Army', 'group'),
#   ('National Liberation Army', 'movement'),
#   ('National Liberation Army', 'organization'),
#   ('Nissan Patrol', 'vehicle'),
#   ('Rojas', 'Rojas Rodríguez'),
#   ('Rojas', 'chief'),
#   ('Rojas', 'expert'),
#   ('Rojas', 'member'),
#   ('Rojas', 'old'),
#   ('Rojas', 'perpetrator'),
#   ('Rojas Rodríguez', 'chief'),
#   ('Rojas Rodríguez', 'expert'),
#   ('Rojas Rodríguez', 'member'),
#   ('Rojas Rodríguez', 'old'),
#   ('Rojas Rodríguez', 'perpetrator'),
#   ('Santander National Police Academy', 'academy'),
#   ('Santander National Police Academy', 'facility'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'government'),
#   ('Venezuelan', 'government'),
#   ('cadet', 'national'),
#   ('capital', 'city'),
#   ('car', 'truck'),
#   ('car', 'vehicle'),
#   ('chief', 'member'),
#   ('country', 'government'),
#   ('country', 'nation'),
#   ('expert', 'member'),
#   ('government', 'nation'),
#   ('group', 'movement'),
#   ('group', 'organization'),
#   ('member', 'old'),
#   ('member', 'perpetrator'),
#   ('movement', 'organization'),
#   ('truck', 'vehicle')},
#  {('15', 'injured'),
#   ('15', 'people'),
#   ('Bombay Bhel', 'restaurant'),
#   ('Mississauga', 'city'),
#   ('Mississauga', 'home'),
#   ('bomb', 'device'),
#   ('city', 'home'),
#   ('injured', 'people'),
#   ('men', 'suspects')},
#  {('ISIS', 'group'),
#   ('Teen', 'juvenile'),
#   ('boy', 'juvenile'),
#   ('juvenile', 'suspect')},
#  {('Armed Forces Recruiting Station', 'station'),
#   ('Gerald Koch', 'Koch'),
#   ('bomb', 'device')},
#  {('Baghdad', 'capital'),
#   ('British Embassy', 'embassy'),
#   ('Embassy', 'embassy'),
#   ('IED', 'device'),
#   ('Rocket', 'rockets'),
#   ('U.S', 'Washington')},
#  {('Azamat Tazhayakov', 'Tazhayakov'),
#   ('Azamat Tazhayakov', 'student'),
#   ('Boston', 'Cambridge'),
#   ('Boston', 'city'),
#   ('Dias Kadyrbayev', 'Kadyrbayev'),
#   ('Dias Kadyrbayev', 'student'),
#   ('Dzhokhar', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Kadyrbayev', 'student'),
#   ('Tamerlan', 'brother'),
#   ('Tazhayakov', 'client'),
#   ('Tazhayakov', 'first'),
#   ('Tazhayakov', 'man'),
#   ('Tazhayakov', 'student'),
#   ('Tsarnaev', 'suspect'),
#   ('client', 'student'),
#   ('first', 'student'),
#   ('man', 'student')},
#  {('McVeigh', 'Timothy McVeigh'),
#   ('McVeigh', 'extremist'),
#   ('McVeigh', 'suspect'),
#   ('McVeigh', 'veteran'),
#   ('Timothy McVeigh', 'extremist'),
#   ('Timothy McVeigh', 'suspect'),
#   ('Timothy McVeigh', 'veteran'),
#   ('extremist', 'suspect'),
#   ('people', 'victims')},
#  {('Colonel', 'Tokhi'),
#   ('Colonel', 'chief'),
#   ('Mohammad Asif Tokhi', 'Tokhi'),
#   ('Mohammad Asif Tokhi', 'chief'),
#   ('Tokhi', 'chief')},
#  {('Ahmad Khan Rahami', 'Rahami'),
#   ('Ahmad Khan Rahami', 'man'),
#   ('Rahami', 'man'),
#   ('Rahami', 'son'),
#   ('man', 'son')},
#  {('Birmingham', 'Town'),
#   ('Birmingham', 'city'),
#   ('Birmingham', 'town'),
#   ('Hayes', 'Michael Christopher Hayes'),
#   ('Hayes', 'maker'),
#   ('Hayes', 'man'),
#   ('Hayes', 'member'),
#   ('Hayes', 'volunteer'),
#   ('Michael Christopher Hayes', 'man'),
#   ('Michael Christopher Hayes', 'member'),
#   ('Town', 'city'),
#   ('Town', 'town'),
#   ('city', 'town'),
#   ('group', 'unit'),
#   ('maker', 'member'),
#   ('man', 'member'),
#   ('man', 'volunteer'),
#   ('member', 'volunteer')},
#  {('Accused Boston Bomber', 'Dzhokhar'),
#   ('Accused Boston Bomber', 'Tsarnaev'),
#   ('Accused Boston Bomber', 'bomber'),
#   ('Accused Boston Bomber', 'defendant'),
#   ('Boston', 'city'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'bomber'),
#   ('Dzhokhar', 'client'),
#   ('Dzhokhar', 'defendant'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'defendant'),
#   ('Lingzi Lu', 'Lu'),
#   ('Martin Richard', 'Richard'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'client'),
#   ('Tsarnaev', 'defendant'),
#   ('U.S', 'country'),
#   ('bomb', 'bombs'),
#   ('client', 'defendant')},
#  {('Barack Obama', 'Obama'),
#   ('Barack Obama', 'president'),
#   ('Boston Police Department', 'enforcement'),
#   ('FBI', 'agency'),
#   ('Investigators', 'investigators'),
#   ('Obama', 'president'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'federal'),
#   ('U.S', 'government'),
#   ('U.S.', 'federal'),
#   ('U.S.', 'government'),
#   ('bombs', 'devices'),
#   ('bombs', 'explosives'),
#   ('federal', 'government'),
#   ('individual', 'perpetrator'),
#   ('public', "public's")},
#  {('Driver', 'man')},
#  {('Nusra', 'Nusra Front'),
#   ('Nusra', 'group'),
#   ('Nusra Front', 'group'),
#   ('bombers', 'men')},
#  {('Bomb', 'bomb'),
#   ('IRA', 'Provisional IRA'),
#   ('IRA', 'Provisional Irish Republican Army'),
#   ('IRA', 'organization'),
#   ("King's Cross", "King's Cross railway station"),
#   ("King's Cross", "King's Cross station"),
#   ("King's Cross", 'station'),
#   ("King's Cross railway station", 'station'),
#   ("King's Cross station", 'station'),
#   ('London', 'city'),
#   ('Provisional IRA', 'Provisional Irish Republican Army'),
#   ('Provisional Irish Republican Army', 'organization')},
#  {('Bagram Air Base', 'base'),
#   ('Taliban', 'attackers'),
#   ('Taliban', 'insurgents'),
#   ('airfield', 'base')},
#  {('Afridi', 'Minister'),
#   ('Afridi', 'Shehryar Khan Afridi'),
#   ('Arif Alvi', 'President'),
#   ('Arif Alvi', 'president'),
#   ('Balochistan', 'Balochistan province'),
#   ('Balochistan', 'government'),
#   ('Balochistan', 'province'),
#   ('Balochistan', 'provincial'),
#   ('Balochistan', 'state'),
#   ('Balochistan province', 'government'),
#   ('Balochistan province', 'province'),
#   ('Balochistan province', 'provincial'),
#   ('Balochistan province', 'state'),
#   ('Bilawal Bhutto Zardari', 'Bilawal Zardari'),
#   ('Bilawal Bhutto Zardari', 'Leader'),
#   ('Bilawal Bhutto Zardari', 'leader'),
#   ('Bilawal Zardari', 'Leader'),
#   ('Bilawal Zardari', 'leader'),
#   ('Community', 'Hazara'),
#   ('Community', 'community'),
#   ('Embassy of Saudi Arabia', 'Saudi Arabia'),
#   ('Hazara', 'Hazaras'),
#   ('Hazara', 'community'),
#   ('Hazara', 'u'),
#   ('Hazaras', 'community'),
#   ('Hazaras', 'people'),
#   ('Hazaras', 'u'),
#   ('Hazarganji', 'area'),
#   ('Hazarganji', 'where'),
#   ('Imran Khan', 'Khan'),
#   ('Imran Khan', 'Minister'),
#   ('Imran Khan', 'PM'),
#   ('Imran Khan', 'PM Khan'),
#   ('Imran Khan', 'premier'),
#   ('Jam Kamal', 'minister'),
#   ('Jam Kamal Khan', 'Minister'),
#   ('Jam Kamal Khan', 'minister'),
#   ('Khan', 'Minister'),
#   ('Khan', 'premier'),
#   ('Lashkar-e-Jhangvi', 'group'),
#   ('Leader', 'leader'),
#   ('Minister', 'PM'),
#   ('Minister', 'PM Khan'),
#   ('Minister', 'Shehryar Khan Afridi'),
#   ('Minister', 'minister'),
#   ('Minister', 'premier'),
#   ('Nation', 'Pak'),
#   ('Nation', 'Pakistan'),
#   ('Nation', 'Pakistani'),
#   ('Nation', 'SMQureshiPTI'),
#   ('Nation', 'country'),
#   ('Nation', 'nation'),
#   ('Nation', 'state'),
#   ('PM', 'premier'),
#   ('PM Khan', 'premier'),
#   ('Pak', 'Pakistan'),
#   ('Pak', 'Pakistani'),
#   ('Pak', 'country'),
#   ('Pak', 'state'),
#   ('Pakistan', 'Pakistani'),
#   ('Pakistan', 'SMQureshiPTI'),
#   ('Pakistan', 'country'),
#   ('Pakistan', 'nation'),
#   ('Pakistan', 'state'),
#   ('Pakistani', 'country'),
#   ('Pakistani', 'state'),
#   ('Quetta', 'capital'),
#   ('Quetta', 'city'),
#   ('SMQureshiPTI', 'state'),
#   ('Shia', 'Shiite'),
#   ('area', 'where'),
#   ('bomber', 'militant'),
#   ('capital', 'city'),
#   ('community', 'u'),
#   ('extremists', 'target'),
#   ('government', 'province'),
#   ('kafirs', 'people'),
#   ('market', 'stall'),
#   ('marketplace', 'site'),
#   ('marketplace', 'stall'),
#   ('militant', 'perpetrator'),
#   ('nation', 'state'),
#   ('others', 'wounded'),
#   ('protesters', 'protestors'),
#   ('site', 'stall')},
#  {('Bureau', 'Bureau of Investigative Journalism'),
#   ('Bureau', 'organization'),
#   ('Bureau', 's'),
#   ('Bureau of Investigative Journalism', 'organization'),
#   ('Bureau of Investigative Journalism', 's'),
#   ('NYU', 'New York University Law School'),
#   ('New America', 'New America Foundation'),
#   ('New America', 'where'),
#   ('New America Foundation', 'where'),
#   ('Reprieve', 'organization'),
#   ('Stanford', 'Stanford Law School'),
#   ('Stanford', 's'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'government'),
#   ('U.S.', 'government'),
#   ('United States', 'government'),
#   ('abuser', 'government'),
#   ('dead', 'people'),
#   ('dead', 'victims'),
#   ('organization', 's'),
#   ('people', 'victims'),
#   ('researchers', 'team'),
#   ('victim', 'victims')},
#  {('Ernesto Macias', 'president'),
#   ('Julio Borges', 'congressional Speaker'),
#   ('Julio Borges', 'president'),
#   ('Maduro', 'Nicolas Maduro'),
#   ('Maduro', 'President'),
#   ('Maduro', 'leader'),
#   ('Maduro', 's'),
#   ('Maduro', 'the president'),
#   ('Nicolas Maduro', 'President'),
#   ('Nicolas Maduro', 'leader'),
#   ('Nicolas Maduro', 's'),
#   ('Nicolas Maduro', 'the president'),
#   ('Perez', 'lnspector'),
#   ('President', 's'),
#   ('SEBIN', 'police'),
#   ('leader', 's'),
#   ('leader', 'the president')},
#  {('21-year-old', 'Bomber Tsarnaev'),
#   ('21-year-old', 'Dzhokhar'),
#   ('21-year-old', 'Dzhokhar Tsarnaev'),
#   ('21-year-old', 'Tsarnaev'),
#   ('21-year-old', 'bomber'),
#   ('21-year-old', 'citizen'),
#   ('21-year-old', 'immigrant'),
#   ('America', 'U.S.'),
#   ('America', 'government'),
#   ('American', 'U.S.'),
#   ('American', 'government'),
#   ('Attorney', 'Pellegrini'),
#   ('Bomber Tsarnaev', 'Dzhokhar'),
#   ('Bomber Tsarnaev', 'Dzhokhar Tsarnaev'),
#   ('Bomber Tsarnaev', 'Tsarnaev'),
#   ('Bomber Tsarnaev', 'bomber'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'bomber'),
#   ('Dzhokhar', 'citizen'),
#   ('Dzhokhar', 'immigrant'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'citizen'),
#   ('Dzhokhar Tsarnaev', 'immigrant'),
#   ('Jurors', 'jurors'),
#   ('Jurors', 'jury'),
#   ('Nadine Pellegrini', 'Pellegrini'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Timothy McVeigh', 'bomber'),
#   ('Tsarnaev', 'bomber'),
#   ('Tsarnaev', 'brother'),
#   ('Tsarnaev', 'citizen'),
#   ('Tsarnaev', 'immigrant'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'government'),
#   ('U.S.', 'government'),
#   ('bomber', 'immigrant'),
#   ('brothers', 'sibling'),
#   ('jurors', 'jury'),
#   ('people', 'victims')},
#  {('Afghan', 'Afghanistan'),
#   ('Afghan', 'government'),
#   ('Afghanistan', 'country'),
#   ('Afghanistan', 'government'),
#   ('Mahbubullah Sayedi', 'Sayedi'),
#   ('country', 'government')},
#  {('Brick Lane', 'area'),
#   ('Brick Lane', 'centre'),
#   ('London', 'capital'),
#   ('Police', 'police'),
#   ('Volvo', 'car'),
#   ('area', 'centre'),
#   ('bomb', 'device')},
#  {('America', 'Americans'),
#   ('America', 'U.S.'),
#   ('America', 'United States'),
#   ('American', 'Americans'),
#   ('American', 'Government'),
#   ('American', 'U.S.'),
#   ('American', 'United States'),
#   ('American', 'government'),
#   ('Americans', 'U.S.'),
#   ('Americans', 'United States'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'boy'),
#   ('Dzhokhar', 'brother'),
#   ('Dzhokhar', 'dealer'),
#   ('Dzhokhar', 'man'),
#   ('Dzhokhar', 'student'),
#   ('Dzhokhar Tsarnaev', 'boy'),
#   ('Dzhokhar Tsarnaev', 'brother'),
#   ('Dzhokhar Tsarnaev', 'dealer'),
#   ('Dzhokhar Tsarnaev', 'man'),
#   ('Dzhokhar Tsarnaev', 'student'),
#   ('FBI', 'Federal Bureau of Investigation'),
#   ('FBI', 'prosecution'),
#   ('FBI', 'prosecutors'),
#   ('Federal Bureau of Investigation', 'prosecutors'),
#   ('Government', 'U.S.'),
#   ('Government', 'United States'),
#   ('Khadzhimuradovs', 'family'),
#   ('Tamerlan', 'Tamerlan (C) Tsarnaev'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'follower'),
#   ('Tamerlan', 'man'),
#   ('Tamerlan', 'mastermind'),
#   ('Tamerlan (C) Tsarnaev', 'man'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Tamerlan Tsarnaev', 'man'),
#   ('Tamerlan Tsarnaev', 'mastermind'),
#   ('Tsarnaev', 'Tsarnaevs'),
#   ('Tsarnaev', 'family'),
#   ('Tsarnaevs', 'bombers'),
#   ('Tsarnaevs', 'boys'),
#   ('Tsarnaevs', 'brothers'),
#   ('Tsarnaevs', 'family'),
#   ('Tsarnaevs', 'sisters'),
#   ('U.S.', 'United States'),
#   ('United States', 'government'),
#   ('United States', 'here'),
#   ('bombers', 'boys'),
#   ('bombers', 'brothers'),
#   ('bombers', 'sisters'),
#   ('boy', 'brother'),
#   ('boy', 'dealer'),
#   ('boy', 'man'),
#   ('boys', 'brothers'),
#   ('boys', 'sisters'),
#   ('boys', 'sons'),
#   ('brother', 'dealer'),
#   ('brother', 'man'),
#   ('brothers', 'siblings'),
#   ('brothers', 'sisters'),
#   ('brothers', 'sons'),
#   ('defense', 'lawyers'),
#   ('follower', 'man'),
#   ('man', 'mastermind'),
#   ('people', 'three'),
#   ('prosecution', 'prosecutors'),
#   ('siblings', 'sisters'),
#   ('siblings', 'sons')},
#  {('London', 'central London')},
#  {('Colombia', 'Colombian'),
#   ('Colombia', 'government'),
#   ('ELN', 'National Liberation Army'),
#   ('ELN', 'group'),
#   ('National Liberation Army', 'group'),
#   ('academy', 'establishment')},
#  {('2,000', 'group'),
#   ('Bogota', 'Bogotá'),
#   ('Bogota', 'capital'),
#   ('Bogotá', 'capital'),
#   ('Bogotá', 'city'),
#   ('El Mocho', 'driver'),
#   ('El Mocho', 'man'),
#   ('José Aldemar Rojas Rodríguez', 'driver'),
#   ('José Aldemar Rojas Rodríguez', 'man'),
#   ('Kiko', 'driver'),
#   ('Kiko', 'man'),
#   ('Nissan Patrol', 'car'),
#   ('Nissan Patrol', 'vehicle'),
#   ('academy', 'school'),
#   ('capital', 'city'),
#   ('compound', 'where'),
#   ('driver', 'expert'),
#   ('driver', 'man'),
#   ('driver', 'member'),
#   ('driver', 'suspect'),
#   ('expert', 'man'),
#   ('explosive', 'explosives'),
#   ('group', 'itself it'),
#   ('group', 'rebels'),
#   ('group', 'terrorists'),
#   ('itself it', 'rebels'),
#   ('people', 'victims'),
#   ('rebels', 'terrorists')},
#  {('Maduro', 'Maduro’s'),
#   ('Maduro', 'Nicolás Maduro'),
#   ('Maduro', 'President'),
#   ('Maduro', 'driver'),
#   ('Maduro', 'leader'),
#   ('Maduro', 'president'),
#   ('Maduro’s', 'Nicolás Maduro'),
#   ('Maduro’s', 'President'),
#   ('Nicolás Maduro', 'President'),
#   ('Nicolás Maduro', 'driver'),
#   ('Nicolás Maduro', 'leader'),
#   ('Nicolás Maduro', 'president'),
#   ('Soldiers in T-Shirts', 'group'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'country'),
#   ('Venezuela', 'government'),
#   ('Venezuela', 'national'),
#   ('Venezuelan', 'country'),
#   ('Venezuelan', 'government'),
#   ('Venezuelan', 'national'),
#   ('Venezuelan', 'state'),
#   ('country', 'government'),
#   ('country', 'national'),
#   ('country', 'state'),
#   ('government', 'national'),
#   ('leader', 'president')},
#  {('Pakistan', 'country'), ('Pakistan', 'government')},
#  {('Birmingham', 'city'),
#   ('Hambleton', 'Julie Hambleton'),
#   ('Hugh Southey QC', 'Southey'),
#   ('group', 'group Justice4the21'),
#   ('group', 'supporters'),
#   ('people', 'victims'),
#   ('pub', 'pubs')},
#  {('Bahrun Naim', 'Indonesian'),
#   ('Bali', 'Island'),
#   ('Bali', 'island'),
#   ('Indonesia', 'Indonesian'),
#   ('Indonesia', 'Indonesians'),
#   ('Indonesia', 'country'),
#   ('Indonesia', 'government'),
#   ('Indonesia', 'nation'),
#   ('Indonesian', 'Indonesians'),
#   ('Indonesian', 'country'),
#   ('Indonesian', 'government'),
#   ('Indonesians', 'country'),
#   ('Indonesians', 'government'),
#   ('Island', 'island'),
#   ('JI', 'group'),
#   ('Jakarta', 'capital'),
#   ('Jakarta', 'city'),
#   ('Jemaah Islamiyah', 'group'),
#   ('Muhamad Yunus', 'Yunus'),
#   ('Police', 'police'),
#   ('Starbucks', 'shop'),
#   ('Terrorist', 'terrorist'),
#   ('Yunus', 'hero'),
#   ('assailants', 'militants'),
#   ('attackers', 'militants')},
#  {('$20.99', '$41.28'),
#   ('Amberg', 'Rick Amberg'),
#   ('Bomb', 'bomb'),
#   ('Bomb', 'explosive device'),
#   ('Bomb', 'such a bomb'),
#   ('Bomb', 'that thing'),
#   ('Bomb', 'the bomb'),
#   ('Mohammed A. Salameh', 'Mr.'),
#   ('Mohammed A. Salameh', 'Salameh'),
#   ('Mohammed A. Salameh', 'suspect'),
#   ('Mr.', 'Salameh'),
#   ('Salameh', 'suspect'),
#   ('The bombers', 'The suspects'),
#   ('The bombers', 'the bombers'),
#   ('The suspects', 'the bombers'),
#   ('World Trade Center', 'the trade center'),
#   ('bomb', 'explosive device'),
#   ('bomb', 'such a bomb'),
#   ('bomb', 'that thing'),
#   ('bomb', 'the bomb'),
#   ('concoction', 'material'),
#   ('explosive', 'explosives'),
#   ('explosives', 'the explosive'),
#   ('investigators', 'the authorities'),
#   ('investigators', 'the investigators'),
#   ('that thing', 'the bomb'),
#   ('the van', 'van'),
#   ('van', 'vehicle')},
#  {('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'Tsarnaev'),
#   ('Bomber', 'bomber'),
#   ('Collier', 'officer'),
#   ('Dias Kadyrbayev', 'Kadyrbayev'),
#   ('Dias Kadyrbayev', 'friend'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Kadyrbayev', 'defendant'),
#   ('Kadyrbayev', 'friend'),
#   ('Officer', 'officer'),
#   ('Sean Collier', 'officer'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('Watertown', 'there'),
#   ('defendant', 'friend')},
#  {('German man', 'Marco G.'),
#   ('Marco G.', 'main suspect'),
#   ('Markus Beisicht', 'head'),
#   ('Markus Beisicht', 'head of ‘Pro NRW’'),
#   ('North Rhine-Westphalia', 'state'),
#   ('Three others', 'defendants'),
#   ('head of ‘Pro NRW’', 'leader')},
#  {('Suspect', 'Tamerlan'),
#   ('Suspect', 'Tamerlan Tsarnaev'),
#   ('Suspect', 'Tsarnaev'),
#   ('Suspect', 'oldest'),
#   ('Suspects', 'brothers'),
#   ('Suspects', 'suspects'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'oldest'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tamerlan Tsarnaev', 'oldest'),
#   ('Tsarnaev', 'oldest'),
#   ('brothers', 'suspects')},
#  {('Abdo', 'Naser Jason Abdo'),
#   ('Abdo', 'Pfc'),
#   ('Abdo', 'Soldier'),
#   ('Abdo', 'client'),
#   ('Abdo', 'soldier'),
#   ('Abdo', 'suspect'),
#   ('Al-Awlaki', 'cleric'),
#   ('American', 'U.S'),
#   ('American', 'U.S.'),
#   ('Anwar al-Awlaki', 'al-Awlaki'),
#   ('Awlaki', 'al-Awlaki'),
#   ('Awlaki', 'cleric'),
#   ('Greg Ebert', 'owner'),
#   ('Hasan', 'Major'),
#   ('Hasan', 'Nidal Hasan'),
#   ('Hasan', 'shooter'),
#   ('Major', 'Nidal Hasan'),
#   ('Military', 'military'),
#   ('Naser Jason Abdo', 'Soldier'),
#   ('Naser Jason Abdo', 'soldier'),
#   ('Naser Jason Abdo', 'suspect'),
#   ('Nidal Hasan', 'shooter'),
#   ('Pfc', 'Soldier'),
#   ('Pfc', 'soldier'),
#   ('Pfc', 'suspect'),
#   ('Soldier', 'client'),
#   ('Soldier', 'soldier'),
#   ('Soldier', 'suspect'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'government'),
#   ('U.S.', 'government'),
#   ('al-Awlaki', 'cleric'),
#   ('bombs', 'two'),
#   ('client', 'soldier'),
#   ('client', 'suspect'),
#   ('court', 'courtroom'),
#   ('soldier', 'suspect')},
#  {('29', 'Requesens'),
#   ('Juan Requesens', 'Requesens'),
#   ('Maduro', 'Nicolas Maduro'),
#   ('Oscar Perez', 'Perez'),
#   ('Perez', 'officer'),
#   ('Several', 'dozen'),
#   ('Venezuela', 'Venezuelan'),
#   ('Venezuela', 'country'),
#   ('Venezuela', 'nation'),
#   ('Venezuela', 'national'),
#   ('Venezuela', 's'),
#   ('Venezuela', 'state'),
#   ('Venezuela', 'where'),
#   ('Venezuelan', 'country'),
#   ('Venezuelan', 'nation'),
#   ('Venezuelan', 'national'),
#   ('Venezuelan', 's'),
#   ('Venezuelan', 'state'),
#   ('Venezuelan', 'where'),
#   ('attackers', 'group'),
#   ('attackers', 'perpetrators'),
#   ('attackers', 'the people'),
#   ('attackers', 'the perpetrators'),
#   ('country', 'national'),
#   ('government', 's'),
#   ('government', 'the government'),
#   ('group', 'the alleged conspirators'),
#   ('high-ranking', 'two'),
#   ('nation', 'national'),
#   ('nation', 's'),
#   ('nation', 'where'),
#   ('national', 's'),
#   ('national', 'state'),
#   ('national', 'where'),
#   ('perpetrators', 'plotters'),
#   ('perpetrators', 'the alleged conspirators'),
#   ('perpetrators', 'the people'),
#   ('perpetrators', 'the perpetrators'),
#   ('plotters', 'the people'),
#   ('plotters', 'the perpetrators'),
#   ('s', 'the government'),
#   ('state', 'where'),
#   ('the people', 'the perpetrators')},
#  {('Santa Cruz', 'station'),
#   ('Santa Cruz station', 'station'),
#   ('Santacruz', 'station'),
#   ('Western line', 'line'),
#   ('bogey', 'compartment'),
#   ('compartment', 'compartments')},
#  {('Tokyo District Court', 'court'),
#   ('Yamamoto', 'Yasuo Yamamoto'),
#   ('Yamamoto', 'man'),
#   ('Yamamoto', 'resident'),
#   ('Yasuo Yamamoto', 'man'),
#   ('man', 'resident'),
#   ('roof', 'rooftop')},
#  {('Butt', 'Khuram Shazad Butt'),
#   ('Butt', 'ringleader'),
#   ('Khalid Masood', 'militant'),
#   ('Khuram Shazad Butt', 'ringleader'),
#   ('London', 'capital'),
#   ('London Bridge', 'Westminster Bridge'),
#   ('May', 'Minister'),
#   ('May', 'PM'),
#   ('May', 'Theresa May'),
#   ('May', 'architect'),
#   ('May', 'minister'),
#   ('Minister', 'Theresa May'),
#   ('PM', 'Theresa May'),
#   ('PM', 'architect'),
#   ('PM', 'minister'),
#   ('architect', 'minister'),
#   ('home', 'minister')},
#  {('Bogota', 'capital'),
#   ('Bogotá', 'capital'),
#   ('Bogotá', 'city'),
#   ('Escuela General Santander', 'academy'),
#   ('Escuela General Santander', 'facility'),
#   ('Escuela General Santander', 'school'),
#   ('Escuela General Santander', 'where'),
#   ('Farc', 'group'),
#   ('General Santander police', 'police'),
#   ('Police', 'police'),
#   ('Rafael Trujillo', 'Trujillo'),
#   ('Revolutionary Armed Forces of Colombia', 'group'),
#   ('academy', 'facility'),
#   ('academy', 'school'),
#   ('academy', 'where'),
#   ('capital', 'city'),
#   ('facility', 'school'),
#   ('facility', 'where'),
#   ('school', 'where')},
#  {('Ahmad Khan Rahami', 'Rahami'),
#   ('Ahmad Khan Rahami', 'citizen'),
#   ('Ahmad Khan Rahami', 'son'),
#   ('Ahmad Khan Rahami', 'suspect'),
#   ('Brother', 'head'),
#   ('Chelsea', 'neighborhood'),
#   ('FBI', 'Federal Bureau of Investigation'),
#   ('NYC', 'New York'),
#   ('Osama Bin Laden', 'head'),
#   ('Rahami', 'citizen'),
#   ('Rahami', 'son'),
#   ('Rahami', 'suspect'),
#   ('bearings', 'components'),
#   ('business', 'place'),
#   ('cell phones', 'phones'),
#   ('citizen', 'son'),
#   ('citizen', 'suspect'),
#   ('components', 'items'),
#   ('place', 'store'),
#   ('place', 'where'),
#   ('store', 'where')},
#  {('28', 'Ahmad Khan Rahami'),
#   ('28', 'Rahami'),
#   ('28', 'Suspect'),
#   ('28', 'son'),
#   ('Ahmad Khan Rahami', 'Rahami'),
#   ('Ahmad Khan Rahami', 'Suspect'),
#   ('Ahmad Khan Rahami', 'son'),
#   ('Ahmad Khan Rahami', 'suspect'),
#   ('Chelsea', 'neighborhood'),
#   ('Rahami', 'Suspect'),
#   ('Rahami', 'son'),
#   ('Rahami', 'suspect'),
#   ('business', 'place'),
#   ('business', 'store'),
#   ('business', 'where'),
#   ('components', 'items'),
#   ('place', 'store'),
#   ('place', 'where'),
#   ('store', 'where')},
#  {('260', 'more'),
#   ('Bomber', 'Tsarnaev'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'defendant'),
#   ('Dzhokhar', 'son'),
#   ('Dzhokhar', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'son'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'defendant'),
#   ('Tsarnaev', 'son'),
#   ('Tsarnaev', 'suspect'),
#   ('U.S. District Court', 'court'),
#   ('court', 'where'),
#   ('son', 'suspect')},
#  {('CENTCOM', 'Joint Chiefs'),
#   ('CENTCOM', 'Joint Chiefs of Staff'),
#   ('Cruz', 'Republican'),
#   ('Cruz', 'Sen'),
#   ('Cruz', 'Senator'),
#   ('Cruz', 'Ted Cruz'),
#   ('David', 'Genieve David'),
#   ('David', 'Maj'),
#   ('David', 'spokeswoman'),
#   ('Dunford', 'Gen'),
#   ('Dunford', 'Joseph Dunford'),
#   ('Dunford', 'chairman'),
#   ('EFP', 'EFPs'),
#   ('EFP', 'IEDs'),
#   ('EFP', 'bombs'),
#   ('EFP', 'device'),
#   ('EFP', 'penetrators'),
#   ('EFPs', 'IEDs'),
#   ('EFPs', 'bombs'),
#   ('EFPs', 'device'),
#   ('EFPs', 'penetrators'),
#   ('Gen', 'Joseph Dunford'),
#   ('Gen', 'Martin Dempsey'),
#   ('General', 'Soleimani'),
#   ('General', 'man'),
#   ('IEDs', 'bombs'),
#   ('IRAM', 'weapon'),
#   ('Iran', 'Iranian'),
#   ('Iran', 'Tehran'),
#   ('Iranian', 'Tehran'),
#   ('Iraq', 'Iraqi'),
#   ('Novack', 'Phil Novack'),
#   ('Novack', 'spokesman'),
#   ('Republican', 'Sen'),
#   ('Sen', 'Senator'),
#   ('Sen', 'Ted Cruz'),
#   ('device', 'munition'),
#   ('device', 'penetrators'),
#   ('device', 'weapon'),
#   ('lives', 'members'),
#   ('lives', 'soldiers'),
#   ('members', 'soldiers'),
#   ('munition', 'weapon'),
#   ('soldiers', 'troops')},
#  {('Bombs', 'The bombs'),
#   ('Bombs', 'the bombs'),
#   ('The bombs', 'the bombs'),
#   ('a circuit board', 'object'),
#   ('any other bombs', 'five'),
#   ('any other bombs', 'there'),
#   ('bomb', 'the bomb'),
#   ('bombs', 'the bombs'),
#   ('bombs', 'the exploded bombs'),
#   ('devices', 'the devices'),
#   ('expert', 'the expert'),
#   ('five', 'no unexploded bombs'),
#   ('man', 'suspect'),
#   ('terrorist', 'terrorists'),
#   ('the bombs', 'the exploded bombs')},
#  {('Campbell', 'Robert Campbell'),
#   ('Campbell', 'bomber'),
#   ('Campbell', 'member'),
#   ('Campbell', 'person'),
#   ('IRA', 'Irish Republican Army'),
#   ('IRA', 'Official IRA'),
#   ('IRA', 'Officials'),
#   ('IRA', 'Provisional IRA'),
#   ('Irish Republican Army', 'Official IRA'),
#   ('Irish Republican Army', 'Provisional IRA'),
#   ('Jeremy Snow', 'officer'),
#   ('Major', 'officer'),
#   ("McGurk's", "McGurk's Bar"),
#   ("McGurk's", 'Tramore Bar'),
#   ("McGurk's", 'building'),
#   ("McGurk's", 'house'),
#   ("McGurk's", 'premises'),
#   ("McGurk's", 'pub'),
#   ("McGurk's", 'there'),
#   ("McGurk's Bar", 'Tramore Bar'),
#   ("McGurk's Bar", 'building'),
#   ("McGurk's Bar", 'house'),
#   ("McGurk's Bar", 'premises'),
#   ("McGurk's Bar", 'pub'),
#   ("McGurk's Bar", 'there'),
#   ('New Lodge', 'New Lodge Road'),
#   ('New Lodge', 'area'),
#   ('New Lodge', 'community'),
#   ('New Lodge', 'district'),
#   ('New Lodge', 'neighbourhood'),
#   ('New Lodge Road', 'area'),
#   ('New Lodge Road', 'community'),
#   ('Officials', 'Provisional IRA'),
#   ('Patrick McGurk', 'owner'),
#   ('RUC', 'Royal Ulster Constabulary'),
#   ('Robert Campbell', 'bomber'),
#   ('Robert Campbell', 'member'),
#   ('Robert Campbell', 'person'),
#   ('Shankill', 'area'),
#   ('Tramore Bar', 'pub'),
#   ('UVF', 'Ulster Volunteer Force'),
#   ('UVF', 'group'),
#   ('area', 'community'),
#   ('area', 'district'),
#   ('area', 'neighbourhood'),
#   ('bomb', 'package'),
#   ('bomber', 'member'),
#   ('bomber', 'person'),
#   ('bombers', 'men'),
#   ('boy', 'witness'),
#   ('building', 'house'),
#   ('building', 'premises'),
#   ('building', 'pub'),
#   ('building', 'there'),
#   ('civilians', 'members'),
#   ('civilians', 'victim'),
#   ('civilians', 'victims'),
#   ('house', 'premises'),
#   ('house', 'pub'),
#   ('house', 'there'),
#   ('member', 'person'),
#   ('members', 'victim'),
#   ('members', 'victims'),
#   ('point', 'where'),
#   ('premises', 'pub'),
#   ('premises', 'there'),
#   ('pub', 'there'),
#   ('victim', 'victims')},
#  {('1', 'Tamerlan Tsarnaev'),
#   ('1', 'Tsarnaev'),
#   ('1', 'suspect'),
#   ('America', 'American'),
#   ('America', 'U.S'),
#   ('America', 'nation'),
#   ('American', 'U.S'),
#   ('American', 'U.S.'),
#   ('American', 'nation'),
#   ('Bomber', 'Dzhokhar'),
#   ('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'Suspect'),
#   ('Bomber', 'Tsarnaev'),
#   ('Bomber', 'guy'),
#   ('Bomber', 'man'),
#   ('Bomber', 'person'),
#   ('Bomber', 'student'),
#   ('Bomber', 'suspect'),
#   ('Bomber', 'terrorist'),
#   ('Boston', 'city'),
#   ('Boston', 'here'),
#   ('Boston', 'hometown'),
#   ('Boston', 'where'),
#   ('Boston Police', 'MIT police'),
#   ('Boston Police', 'Massachusetts State Police'),
#   ('Boston Police', 'Police'),
#   ('Boston Police', 'police'),
#   ('Cambridge', 'town'),
#   ('Campus', 'campus'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Suspect'),
#   ('Dzhokhar', 'Suspect Two'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'kid'),
#   ('Dzhokhar', 'man'),
#   ('Dzhokhar', 'person'),
#   ('Dzhokhar', 'suspect'),
#   ('Dzhokhar', 'terrorist'),
#   ('Dzhokhar Tsarnaev', 'Suspect'),
#   ('Dzhokhar Tsarnaev', 'Suspect Two'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'Tsnarnaev'),
#   ('Dzhokhar Tsarnaev', 'boy'),
#   ('Dzhokhar Tsarnaev', 'brother'),
#   ('Dzhokhar Tsarnaev', 'djohar tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'guy'),
#   ('Dzhokhar Tsarnaev', 'kid'),
#   ('Dzhokhar Tsarnaev', 'man'),
#   ('Dzhokhar Tsarnaev', 'nephew'),
#   ('Dzhokhar Tsarnaev', 'person'),
#   ('Dzhokhar Tsarnaev', 'student'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'terrorist'),
#   ('Dzokhar', 'brother'),
#   ('John Kerry', 'Secretary'),
#   ('John Kerry', 'father'),
#   ('MIT police', 'Police'),
#   ('MIT police', 'police'),
#   ('Maret Tsarnaeva', 'Tsarnaeva'),
#   ('Maret Tsarnaeva', 'aunt'),
#   ('Massachusetts State Police', 'Police'),
#   ('Massachusetts State Police', 'police'),
#   ('Police', 'police'),
#   ('Ruslan Tsarni', 'brother'),
#   ('Ruslan Tsarni', 'uncle'),
#   ('SUV', 'car'),
#   ('SUV', 'carjacked Mercedes SUV'),
#   ('SUV', 'vehicle'),
#   ('Sean Collier', 'man'),
#   ('Sean Collier', 'officer'),
#   ('Secretary', 'father'),
#   ('Suspect', 'Suspect Two'),
#   ('Suspect', 'Tsarnaev'),
#   ('Suspect', 'Tsnarnaev'),
#   ('Suspect', 'boy'),
#   ('Suspect', 'brother'),
#   ('Suspect', 'guy'),
#   ('Suspect', 'kid'),
#   ('Suspect', 'man'),
#   ('Suspect', 'nephew'),
#   ('Suspect', 'person'),
#   ('Suspect', 'student'),
#   ('Suspect', 'suspect'),
#   ('Suspect', 'terrorist'),
#   ('Suspect Two', 'Tsarnaev'),
#   ('Suspect Two', 'man'),
#   ('Suspect Two', 'person'),
#   ('Suspect Two', 'suspect'),
#   ('Suspect Two', 'terrorist'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'boxer'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan', 'suspect'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tamerlan Tsarnaev', 'boxer'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tamerlan Tsarnaev', 'man'),
#   ('Tamerlan Tsarnaev', 'suspect'),
#   ('Tsarnaev', 'guy'),
#   ('Tsarnaev', 'kid'),
#   ('Tsarnaev', 'man'),
#   ('Tsarnaev', 'person'),
#   ('Tsarnaev', 'student'),
#   ('Tsarnaev', 'suspect'),
#   ('Tsarnaev', 'terrorist'),
#   ('Tsarnaevs', 'boys'),
#   ('Tsarnaevs', 'brothers'),
#   ('Tsarnaevs', 'people'),
#   ('Tsarnaevs', 'sons'),
#   ('Tsarnaevs', 'suspects'),
#   ('Tsnarnaev', 'boy'),
#   ('Tsnarnaev', 'brother'),
#   ('Tsnarnaev', 'guy'),
#   ('Tsnarnaev', 'man'),
#   ('Tsnarnaev', 'nephew'),
#   ('Tsnarnaev', 'person'),
#   ('Tsnarnaev', 'student'),
#   ('Tsnarnaev', 'suspect'),
#   ('Tsnarnaev', 'terrorist'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'nation'),
#   ('U.S.', 'United States'),
#   ('U.S.', 'nation'),
#   ('United States', 'nation'),
#   ('boat', 'trailer'),
#   ('boat', 'where'),
#   ('boxer', 'brother'),
#   ('boxer', 'suspect'),
#   ('boy', 'guy'),
#   ('boy', 'kid'),
#   ('boy', 'man'),
#   ('boy', 'nephew'),
#   ('boy', 'person'),
#   ('boy', 'son'),
#   ('boy', 'student'),
#   ('boy', 'suspect'),
#   ('boy', 'terrorist'),
#   ('boys', 'brothers'),
#   ('boys', 'people'),
#   ('boys', 'sons'),
#   ('boys', 'suspects'),
#   ('brother', 'djohar tsarnaev'),
#   ('brother', 'guy'),
#   ('brother', 'kid'),
#   ('brother', 'man'),
#   ('brother', 'nephew'),
#   ('brother', 'person'),
#   ('brother', 'student'),
#   ('brother', 'suspect'),
#   ('brother', 'terrorist'),
#   ('brother', 'uncle'),
#   ('brothers', 'men'),
#   ('brothers', 'nephews'),
#   ('brothers', 'people'),
#   ('brothers', 'residents'),
#   ('brothers', 'sons'),
#   ('brothers', 'suspects'),
#   ('car', 'carjacked Mercedes SUV'),
#   ('car', 'vehicle'),
#   ('city', 'here'),
#   ('city', 'hometown'),
#   ('guy', 'kid'),
#   ('guy', 'man'),
#   ('guy', 'nephew'),
#   ('guy', 'person'),
#   ('guy', 'student'),
#   ('guy', 'suspect'),
#   ('guy', 'terrorist'),
#   ('here', 'hometown'),
#   ('kid', 'man'),
#   ('kid', 'person'),
#   ('kid', 'suspect'),
#   ('kid', 'terrorist'),
#   ('man', 'officer'),
#   ('man', 'person'),
#   ('man', 'suspect'),
#   ('man', 'terrorist'),
#   ('men', 'nephews'),
#   ('men', 'people'),
#   ('men', 'residents'),
#   ('men', 'sons'),
#   ('men', 'suspects'),
#   ('nephew', 'person'),
#   ('nephew', 'student'),
#   ('nephew', 'suspect'),
#   ('nephew', 'terrorist'),
#   ('nephews', 'people'),
#   ('nephews', 'sons'),
#   ('nephews', 'suspects'),
#   ('people', 'sons'),
#   ('people', 'suspects'),
#   ('people', 'three'),
#   ('person', 'student'),
#   ('person', 'suspect'),
#   ('person', 'terrorist'),
#   ('residents', 'sons'),
#   ('residents', 'suspects'),
#   ('sons', 'suspects'),
#   ('student', 'suspect'),
#   ('student', 'terrorist'),
#   ('suspect', 'terrorist')},
#  {('26', 'Schneck'),
#   ('Andrew Schneck', 'Schneck'),
#   ('Andrew Schneck', 'man'),
#   ('HPD', 'Houston Police Department'),
#   ('Nitroglycerin', 'nitroglycerin'),
#   ('Schneck', 'man')},
#  {('Boston', 'city'),
#   ('Boston', 'town'),
#   ('Boston Marathon', 'Marathon'),
#   ('Boston PD', 'Boston Police'),
#   ('Boston PD', 'Police'),
#   ('Boston PD', 'police'),
#   ('Boston Police', 'police'),
#   ('CNN', 'NBC News'),
#   ('Davis', 'Ed Davis'),
#   ('Davis', 'commissioner'),
#   ('DeLaurio', 'agent'),
#   ('Deval Patrick', 'Patrick'),
#   ('Ed Davis', 'commissioner'),
#   ('Governor', 'Patrick'),
#   ('JFK Library', 'library'),
#   ('Obama', 'President'),
#   ('Police', 'police'),
#   ('Richard DesLauriers', 'agent'),
#   ('city', 'town'),
#   ('footage', 'images'),
#   ('no one', 'suspect'),
#   ('people', 'three'),
#   ('people', 'two'),
#   ('people', 'victims'),
#   ('person', 'suspect'),
#   ('three', 'two'),
#   ('three', 'victims')},
#  {('Austin', 'capital'), ('V', 'bomber'), ('bomber', 'suspect')},
#  {('Flight 63', 'aircraft'),
#   ('Flight 63', 'airplane'),
#   ('Flight 63', 'flight'),
#   ('Flight 63', 'plane'),
#   ('Hermis Moutardier', 'Moutardier'),
#   ('Hermis Moutardier', 'attendant'),
#   ('Jabarah', 'Mohammed Mansour Jabarah'),
#   ('Jabarah', 'colleague'),
#   ('Logan Airport', 'Logan International Airport'),
#   ('Moutardier', 'attendant'),
#   ('Passengers', 'passengers'),
#   ('Reid', 'Richard Reid'),
#   ('Reid', 'fundamentalist'),
#   ('Reid', 'operative'),
#   ('Reid', 'perpetrator'),
#   ('Richard Reid', 'fundamentalist'),
#   ('Richard Reid', 'operative'),
#   ('Richard Reid', 'perpetrator'),
#   ('aircraft', 'airplane'),
#   ('aircraft', 'flight'),
#   ('aircraft', 'plane'),
# ...
#   ('Venezuelan', 'the government'),
#   ('country', 'government'),
#   ('country', 'the government'),
#   ('drone', 'drones'),
#   ('government', 'state'),
#   ('government', 'the government'),
#   ('s', 'state'),
#   ('state', 'the government')},
#  {('Bogota', 'Bogotá'),
#   ('Bogota', 'capital'),
#   ('Bogotá', 'capital'),
#   ('Bogotá', 'city'),
#   ('Duque', 'President'),
#   ('Escuela General Santander', 'academy'),
#   ('Escuela General Santander', 'school'),
#   ('General Santander police', 'Police'),
#   ('General Santander police', 'police'),
#   ('Police', 'police'),
#   ('SUV', 'car'),
#   ('SUV', 'vehicle'),
#   ('academy', 'facility'),
#   ('academy', 'school'),
#   ('academy', 'where'),
#   ('capital', 'city'),
#   ('car', 'vehicle'),
#   ('facility', 'school'),
#   ('facility', 'where')},
#  {('Orangetheory', 'Orangetheory Fitness Chelsea'),
#   ('Orangetheory', 'center'),
#   ('Orangetheory', 'company')},
#  {('Russia', 'Russian'),
#   ('Russia', 'Russians'),
#   ('Russian', 'Russians'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'follower'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tsarnaev', 'follower'),
#   ('Tsarnaev', 'son')},
#  {('Anwar al-Awlaki', 'Awlaki'),
#   ('Awlaki', 'cleric'),
#   ('Boston', 'city'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'his younger brother'),
#   ('Dzhokhar', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'his younger brother'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Kazakhs', 'three'),
#   ('Kazakhs', 'two'),
#   ('Suspects', 'brothers'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('his younger brother', 'suspect')},
#  {('Campbell', 'Krystle Campbell'),
#   ('Campbell', 'Lingzi Lu'),
#   ('Campbell', 'manager'),
#   ('Court', 'court'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'defendant'),
#   ('Dzhokhar', 'guy'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'defendant'),
#   ('Lu', 'student'),
#   ('Martin', 'Martin Richard'),
#   ('Martin', 'Richard'),
#   ('Martin Richard', 'Richard'),
#   ('Sean Collier', 'officer'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'defendant'),
#   ('Tsarnaev', 'guy'),
#   ('brothers', 'two'),
#   ('defendant', 'guy'),
#   ('family', 'parents')},
#  {('40', 'men'),
#   ('40', 'so'),
#   ('Ashfaq Kayani', 'chief'),
#   ('Khan', 'commander'),
#   ('Khan', 'lieutenant')},
#  {('Afghanistan', 'country'), ('Members', 'members')},
#  {('2', 'drone'),
#   ('Drones', 'drones'),
#   ('Drones', 'small drones'),
#   ('Explosives', 'explosives'),
#   ('ISIL', 'ISIS'),
#   ('ISIL', 'itself'),
#   ('ISIL', 'organization'),
#   ('ISIS', 'itself'),
#   ('ISIS', 'organization'),
#   ('Talon', 'drone'),
#   ('aircraft', 'airplane'),
#   ('aircraft', 'drone'),
#   ('airplane', 'drone'),
#   ('drone', 'what'),
#   ('drones', 'small drones')},
#  {('Pine View High', 'school'),
#   ('Utah high school', 'school'),
#   ('boy', 'client'),
#   ('boy', 'defendant'),
#   ('boy', 'minor'),
#   ('boy', 'teenager'),
#   ('client', 'teenager'),
#   ('defendant', 'teenager'),
#   ('minor', 'teenager')},
#  {('Azamat Tazhayakov', 'Tazhayakov'),
#   ('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'Tsarnaev'),
#   ('Dias Kadyrbayev', 'Kadyrbayev'),
#   ('Dias Kadyrbayev', 'friend'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'bomber'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'bomber'),
#   ('Friend', 'Phillipos'),
#   ('Friend', 'Robel Phillipos'),
#   ('Friend', 'friend'),
#   ('Kadyrbayev', 'friend'),
#   ('Phillipos', 'Robel Phillipos'),
#   ('Phillipos', 'friend'),
#   ('Robel Phillipos', 'friend'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tsarnaev', 'bomber'),
#   ('room', 'there')},
#  {('Police', 'police')},
#  {('Diab', 'Hassan Diab'),
#   ('Diab', 'academic'),
#   ('Diab', 'father'),
#   ('Diab', 'man'),
#   ('Diab', 'member'),
#   ('Diab', 'professor'),
#   ('Diab', 's'),
#   ('Diab', 'sociologist'),
#   ('Hassan Diab', 'man'),
#   ('Hassan Diab', 's'),
#   ('Synagogue', 'synagogue'),
#   ('academic', 'man'),
#   ('academic', 's'),
#   ('father', 'man'),
#   ('father', 's'),
#   ('professor', 's')},
#  {('1', 'Tamerlan Tsarnaev'),
#   ('1', 'follower'),
#   ('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'Suspect'),
#   ('Bomber', 'Tsarnaev'),
#   ('Bomber', 'brother'),
#   ('Bomber', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Suspect', 'Tamerlan Tsarnaev'),
#   ('Suspect', 'Tsarnaev'),
#   ('Suspect', 'follower'),
#   ('Suspect', 'guy'),
#   ('Suspect', 'suspect'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Watertown', 'town'),
#   ('brother', 'guy'),
#   ('brother', 'suspect')},
#  {('Syria', 'Syrian')},
#  {('Adams', 'Angela Adams'),
#   ('Adams', 'Attorney'),
#   ('Angela Adams', 'Attorney'),
#   ('Edward Flint', 'Flint'),
#   ('Edward Flint', 'attorney'),
#   ('Edward Flint', 'defender'),
#   ('Farnsworth', 'Farnsworth’s'),
#   ('Farnsworth', 'Martin'),
#   ('Farnsworth', 'Martin Farnsworth'),
#   ('Farnsworth', 'Teen'),
#   ('Farnsworth', 'citizen'),
#   ('Farnsworth', 'client'),
#   ('Farnsworth', 'person'),
#   ('Farnsworth', 'teen'),
#   ('Farnsworth’s', 'Martin'),
#   ('Farnsworth’s', 'Martin Farnsworth'),
#   ('Farnsworth’s', 'Teen'),
#   ('Farnsworth’s', 'citizen'),
#   ('Farnsworth’s', 'client'),
#   ('Farnsworth’s', 'person'),
#   ('Farnsworth’s', 'teen'),
#   ('Flint', 'attorney'),
#   ('Flint', 'defender'),
#   ('Judge', 'Michael Westfall'),
#   ('Judge', 'Westfall'),
#   ('Judge', 'judge'),
#   ('Martin', 'Martin Farnsworth'),
#   ('Martin', 'Teen'),
#   ('Martin', 'client'),
#   ('Martin', 'person'),
#   ('Martin', 'teen'),
#   ('Martin Farnsworth', 'Teen'),
#   ('Martin Farnsworth', 'citizen'),
#   ('Martin Farnsworth', 'client'),
#   ('Martin Farnsworth', 'person'),
#   ('Martin Farnsworth', 'teen'),
#   ('Michael Westfall', 'Westfall'),
#   ('Michael Westfall', 'judge'),
#   ('Pine View High', 'Pine View High School'),
#   ('Pine View High', 'high school'),
#   ('Pine View High', 'school'),
#   ('Pine View High School', 'high school'),
#   ('Pine View High School', 'school'),
#   ('Students', 'students'),
#   ('Teen', 'citizen'),
#   ('Teen', 'client'),
#   ('Teen', 'person'),
#   ('Teen', 'teen'),
#   ('Westfall', 'judge'),
#   ('attorney', 'defender'),
#   ('bomb', 'device'),
#   ('bomb', 'explosive'),
#   ('bomb', 'incendiary device'),
#   ('citizen', 'client'),
#   ('citizen', 'teen'),
#   ('client', 'person'),
#   ('client', 'teen'),
#   ('device', 'explosive'),
#   ('device', 'incendiary device'),
#   ('explosive', 'incendiary device'),
#   ('high school', 'school'),
#   ('person', 'teen')},
#  {('DOD', 'Defense'),
#   ('Donald Trump', 'President'),
#   ('Manbij', 'city'),
#   ('Mike Pompeo', 'Secretary'),
#   ('Palace of Princes restaurant', 'restaurant'),
#   ('Palace of Princes restaurant', 'there'),
#   ('Palace of the Princes', 'restaurant'),
#   ('Palace of the Princes', 'there'),
#   ('Patrick Shanahan', 'Secretary'),
#   ('Syria', 'Syrian'),
#   ('restaurant', 'there')},
#  {('A 20-year-old former teaching student', 'Sevigin'),
#   ('A 20-year-old former teaching student', 'Teaching student'),
#   ('Aydin Sevigin', 'Sevigin'),
#   ('Aydin Sevigin', 'Teaching student'),
#   ('Istanbul', 'Stockholm'),
#   ('Police', 'the police'),
#   ('Sevigin', 'Teaching student'),
#   ('Sevigin', 'a martyr'),
#   ('Teaching student', 'a martyr'),
#   ('a bomb', 'a suicide bomb'),
#   ('a bomb', 'bomb'),
#   ('a bomb', 'bombs'),
#   ('a suicide bomb', 'bomb'),
#   ('bomb', 'bombs'),
#   ('members', 'relatives')},
#  {('Birmingham', 'city'),
#   ('Bombers', 'bombers'),
#   ('Conway', 'Kieran Conway'),
#   ('Conway', 'chief'),
#   ('Conway', 'head'),
#   ('John', 'John Smith'),
#   ('John', 'pensioner'),
#   ('John', 'resident'),
#   ('John', 'worker'),
#   ('John Smith', 'resident'),
#   ('Kieran Conway', 'head'),
#   ('Marilyn', 'Marilyn Paula Nash'),
#   ('Marilyn', 'Paula'),
#   ('Marilyn', 'daughter'),
#   ('Marilyn', 'girl'),
#   ('Marilyn', 'neighbour'),
#   ('Marilyn', 's'),
#   ('Marilyn', 'victim'),
#   ('Marilyn', 'woman'),
#   ('Marilyn', 'worker'),
#   ('Marilyn Paula Nash', 'Paula'),
#   ('Marilyn Paula Nash', 'daughter'),
#   ('Marilyn Paula Nash', 'girl'),
#   ('Marilyn Paula Nash', 'neighbour'),
#   ('Marilyn Paula Nash', 's'),
#   ('Marilyn Paula Nash', 'victim'),
#   ('Marilyn Paula Nash', 'woman'),
#   ('Marilyn Paula Nash', 'worker'),
#   ('Nash', 'man'),
#   ('Nash', 'neighbour'),
#   ('Paula', 'daughter'),
#   ('Paula', 'woman'),
#   ('Pub', 'pub'),
#   ('chief', 'head'),
#   ('daughter', 'woman'),
#   ('girl', 'neighbour'),
#   ('girl', 's'),
#   ('girl', 'victim'),
#   ('girl', 'worker'),
#   ('man', 'neighbour'),
#   ('neighbour', 's'),
#   ('neighbour', 'woman'),
#   ('neighbour', 'worker'),
#   ('s', 'woman'),
#   ('s', 'worker'),
#   ('several', 'two'),
#   ('victim', 'woman'),
#   ('victim', 'worker')},
#  {('Afghanistan', 'E. Afghan'),
#   ('Afghanistan', 'country'),
#   ('IED', 'explosive device'),
#   ('civilians', 'victims'),
#   ('others', 'wounded')},
#  {('Abedi', 'Manchester Bomber'),
#   ('Abedi', 'Salman'),
#   ('Abedi', 'Salman Abedi'),
#   ('Abedi', 'Son'),
#   ('Abedi', 'bomber'),
#   ('Abedi', 'dropout'),
#   ('Abedi', 'enthusiast'),
#   ('Abedi', 'fan'),
#   ('Abedi', 'jihadist'),
#   ('Abedi', 'killer'),
#   ('Abedi', 'man'),
#   ('Abedi', 'part'),
#   ('Abedi', 'third'),
#   ('Abu Qaqa al-Britani', 'Hostey'),
#   ('Britain', 'British'),
#   ('British', 'government'),
#   ('Ismail', 'brother'),
#   ('Libya', 'Libyan'),
#   ('Libya', 'country'),
#   ('Libyan', 'country'),
#   ('Manchester Bomber', 'Salman'),
#   ('Manchester Bomber', 'bomber'),
#   ('Manchester Bomber', 'jihadist'),
#   ('Manchester Bomber', 'man'),
#   ('Police', 'police'),
#   ('Ramadan Abedi', 'father'),
#   ('Salman', 'dropout'),
#   ('Salman', 'enthusiast'),
#   ('Salman', 'fan'),
#   ('Salman', 'jihadist'),
#   ('Salman Abedi', 'jihadist'),
#   ('bomb', 'device'),
#   ('bomber', 'dropout'),
#   ('bomber', 'enthusiast'),
#   ('bomber', 'fan'),
#   ('bomber', 'jihadist'),
#   ('bomber', 'man'),
#   ('bomber', 'third'),
#   ('brothers', 'parents'),
#   ('dropout', 'jihadist'),
#   ('dropout', 'man'),
#   ('enthusiast', 'jihadist'),
#   ('father', 'guard'),
#   ('killer', 'man'),
#   ('part', 'third')},
#  {('Russia', 'Russian'),
#   ('Russia', 'Russians'),
#   ('Russian', 'Russians'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'follower'),
#   ('Tamerlan', 'son'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tsarnaev', 'follower'),
#   ('Tsarnaev', 'son')},
#  {('I.S.B', 'Islamic Society of Boston'),
#   ('Islamic Society of Boston', 'organization'),
#   ('Islamic Society of Boston mosque', 'congregation'),
#   ('Islamic Society of Boston mosque', 'mosque'),
#   ('Islamic Society of Boston mosque', 'there'),
#   ('Muhammad', 'Prophet'),
#   ('Steve Annear', 'contributor'),
#   ('Steve Annear', 'journalist'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'Tsarnaev'),
#   ('Tamerlan', 'suspect'),
#   ('Tamerlan Tsarnaev', 'Tsarnaev'),
#   ('Tamerlan Tsarnaev', 'suspect'),
#   ('Tsarnaev', 'suspect'),
#   ('Vali', 'Yusufi Vali'),
#   ('Vali', 'spokesman'),
#   ('brothers', 'suspects'),
#   ('center', 'congregation'),
#   ('center', 'mosque'),
#   ('center', 'there'),
#   ('congregation', 'there'),
#   ('guest', 'suspects'),
#   ('mosque', 'there'),
#   ('s', 'suspects')},
#  {('A3 Pro positioning system', 'three'),
#   ('A3 Pro positioning system', 'three-sensor system'),
#   ('CNN', 'Cable News Network'),
#   ('M600', 'M600 Pro model'),
#   ('M600', 'model'),
#   ('M600 Pro model', 'model'),
#   ('M600 Pros', 'drones'),
#   ('M600 Pros', 'the drones'),
#   ('M600 Pros', 'two'),
#   ('M600 drones', 'the drones'),
#   ('Maduro', 'President'),
#   ('Maduro', 'president'),
#   ('Matrice M600 Pro', 'model'),
#   ('Matrice M600 Pro c-drones', 'drones'),
#   ('Matrice M600 Pro c-drones', 'the drones'),
#   ('Matrice M600 Pro c-drones', 'the drones used in the attack'),
#   ('Matrice M600 Pro c-drones', 'two'),
#   ('Nicolás Maduro', 'President'),
#   ('Nicolás Maduro', 'president'),
#   ('Phantom', 'Phantom models'),
#   ('President', 'president'),
#   ('The man interviewed', 'man'),
#   ('The man interviewed', 'organizer'),
#   ('drones', 'the M600 Pro drones'),
#   ('drones', 'the drones'),
#   ('drones', 'the drones used in the attack'),
#   ('drones', 'two'),
#   ('man', 'organizer'),
#   ('the M600 Pro drones', 'the drones'),
#   ('the drones used in the attack', 'two')},
#  {('19-year-old', 'Dzhokar'),
#   ('19-year-old', 'Dzhokhar Tsarnaev'),
#   ('19-year-old', 'student'),
#   ('Dzhokar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokar', 'student'),
#   ('Dzhokar Tsarnaev', 'Dzhokhar Tsarnaev'),
#   ('Dzhokar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar', 'Dzhokhar Tsarnaev'),
#   ('Dzhokhar', 'Tsarnaev'),
#   ('Dzhokhar', 'student'),
#   ('Dzhokhar', 'suspect'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'student'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Russia', 'Russian'),
#   ('Tamerlan', 'co-conspirator'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'student'),
#   ('Tsarnaev', 'suspect'),
#   ('brother', 'co-conspirator'),
#   ('hospital', 'where')},
#  {('40', 'Yasuo Yamamoto'),
#   ('Phantom 2', 'drone'),
#   ('drone', 'unmanned drone'),
#   ('man', 'operator')},
#  {('American', 'U.S'),
#   ('American', 'U.S.'),
#   ('American', 'United States'),
#   ('American', 'Washington'),
#   ('American', 'enemy'),
#   ('American', 'government'),
#   ('American', 'here'),
#   ('American', 'itself'),
#   ('Anwar al-Awlaki', 'Awlaki'),
#   ('Anwar al-Awlaki', 'citizen'),
#   ('Awlaki', 'citizen'),
#   ('Awlaki', 'piper'),
#   ('Baitullah Mehsud', 'leader'),
#   ('Pakistan', 'Pakistani'),
#   ('Pakistan', 'country'),
#   ('Pakistan', 'government'),
#   ('Pakistan', 'own'),
#   ('Pakistani', 'country'),
#   ('Pakistani', 'government'),
#   ('Pakistani', 'own'),
#   ('Tomahawks', 'missile'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'United States'),
#   ('U.S', 'Washington'),
#   ('U.S', 'enemy'),
#   ('U.S', 'government'),
#   ('U.S', 'here'),
#   ('U.S', 'itself'),
#   ('U.S', 'people'),
#   ('U.S.', 'United States'),
#   ('U.S.', 'Washington'),
#   ('U.S.', 'enemy'),
#   ('U.S.', 'government'),
#   ('U.S.', 'here'),
#   ('U.S.', 'itself'),
#   ('United States', 'Washington'),
#   ('United States', 'enemy'),
#   ('United States', 'government'),
#   ('United States', 'here'),
#   ('United States', 'itself'),
#   ('United States', 'people'),
#   ('Washington', 'enemy'),
#   ('Washington', 'government'),
#   ('Washington', 'here'),
#   ('Washington', 'itself'),
#   ('Yemen', 'Yemeni'),
#   ('Yemen', 'Yemenis'),
#   ('Yemen', 'country'),
#   ('Yemeni', 'Yemenis'),
#   ('Yemeni', 'country'),
#   ('citizen', 'piper'),
#   ('country', 'government'),
#   ('country', 'own'),
#   ('drone', 'drones'),
#   ('government', 'here'),
#   ('government', 'itself'),
#   ('government', 'own')},
#  {('Bauman', 'Jeff Bauman'),
#   ('Bauman', 'spectator'),
#   ('Bauman', 'survivor'),
#   ('Dzhokhar Tsarnaev', 'Tsarnaev'),
#   ('Dzhokhar Tsarnaev', 'brother'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Jeff Bauman', 'survivor'),
#   ('Judy Clarke', 'lawyer'),
#   ('Rebekah Gregory', 'survivor'),
#   ('Rebekah Gregory', 'two'),
#   ('Tamerlan', 'Tamerlan Tsarnaev'),
#   ('Tamerlan', 'brother'),
#   ('Tamerlan Tsarnaev', 'brother'),
#   ('Tsarnaev', 'brother'),
#   ('Tsarnaev', 'suspect'),
#   ('Tsarnaevs', 'brothers'),
#   ('Tsarnaevs', 'suspects'),
#   ('U.S.', 'home'),
#   ('brother', 'suspect'),
#   ('brothers', 'suspects'),
#   ('courthouse', 'where'),
#   ('spectator', 'survivor')},
#  {('Birmingham Six,', 'Six'),
#   ('Birmingham Six,', 'people'),
#   ('Brother', 'Julie'),
#   ('Kevin Winters', 'Winters'),
#   ('Kevin Winters', 'lawyer'),
#   ('Maxine', 'sister'),
#   ('Six men', 'people'),
#   ('Winters', 'lawyer')},
#  {('28', 'Velentzas'),
#   ('31', 'Asia Siddiqui'),
#   ('31', 'Siddiqui'),
#   ('Al Farekh', 'Muhanad Mahmoud Al Farekh'),
#   ('American', 'homeland'),
#   ('American', 'nation'),
#   ('Asia Siddiqui', 'Siddiqui'),
#   ('New York', 'New York City'),
#   ('Noelle Velentzas', 'Velentzas'),
#   ('Siddiqui', 'client'),
#   ('U.S', 'U.S.'),
#   ('U.S', 'homeland'),
#   ('U.S', 'nation'),
#   ('U.S.', 'homeland'),
#   ('U.S.', 'nation'),
#   ('agent', 'officer'),
#   ('agent', 'undercover'),
#   ('citizens', 'women'),
#   ('court', 'federal court'),
#   ('officer', 'undercover'),
#   ('officers', 'two'),
#   ('pair', 'women')},
#  {("McGurk's bar", 'bar'),
#   ("McGurk's bar", 'building'),
#   ('North Queens Street', 'area'),
#   ('Robert Campbell', 'member'),
#   ('bar', 'building'),
#   ('loyalist', 'loyalists'),
#   ('people', 'victims')},
#  {('Omar D', 'Omar D.'), ('Omar D', 'suspect'), ('Omar D.', 'suspect')}]

# %%
example_template_entity_mentions[1]
# Out:
# [[['Amin', 'Milton J. Valencia']]]

# %%
coref_pairs
# Out:
# [set(),
#  {('Amin', 'Milton J. Valencia')},
#  {('Chechen', 'immigrant'),
#   ('Dzhokhar Tsarnaev', 'immigrant'),
#   ('Karen Rand McWatters', 'friend'),
#   ('Patricia Campbell', 'mother')},
#  {('country', 'where')},
#  set(),
#  {('attacker', 'soldier')},
#  set(),
#  set(),
#  set(),
#  {('Boylston Street', 'thoroughfare'), ('Sean Collier', 'policeman')},
#  {('Both brothers', 'lifeguards'),
#   ('Ruger pistol', 'Ruger semi-automatic handgun'),
#   ('Ruger pistol', 'Ruger semi-automatic pistol'),
#   ('Ruger pistol', 'a gun'),
#   ('Ruger semi-automatic pistol', 'a gun'),
#   ('Sean Collier', 'officer'),
#   ('Stephen Silva', 'his close friend')},
#  {('Osama bin Laden', 'suspect')},
#  {('dead', 'victims')},
#  {('Bilal Mohammed', 'client')},
#  {('Nestor Reverol', 'minister')},
#  set(),
#  set(),
#  {('Birmingham Mail', 'Birmingham Post & Mail'),
#   ('Irishmen', 'bombers'),
#   ('group', 'organisation')},
#  set(),
#  set(),
#  {('Badia al-Sukhnah', 'spot'),
#   ('Badia al-Sukhnah', 'zone'),
#   ('Tass', 'agency'),
#   ('spot', 'zone')},
#  {('U.S. State Department', 'U.S. Treasury Department')},
#  {('Christophe Castaner', 'Minister'),
#   ('Islamic State', 'group'),
#   ('Rue Victor Hugo', 'street')},
#  {('Federal', 'Russian Federation'),
#   ('Moscow', 'Russian Federation'),
#   ('Republic of Dagestan', 'state'),
#   ('province', 'state')},
#  set(),
#  {('gunmen', 'insurgents')},
#  set(),
#  set(),
#  {('Alejandro Pérez', 'Brayan Oropeza'), ('Luis Guerra', 'Yanin Pernía')},
#  {('Tamerlan Tsarnaev', 'brother')},
#  set(),
#  set(),
#  {('Christophe Castaner', 'minister'), ('Chérif Chekatt', 'killer')},
#  {('Chinook', 'helicopter'),
#   ('aircraft', 'missiles'),
#   ('aircraft', 'unmanned aerial vehicles'),
#   ('chemicals', 'material'),
#   ('missiles', 'unmanned aerial vehicles')},
#  {('Zabiullah Mujahid', 'spokesperson')},
#  set(),
#  {('Central Hospital of Maracay', 'the Maracay Central Hospital')},
#  {('Antonio Durán', 'Vicente Sainz de la Peña'),
#   ('Antonio Durán', 'worker'),
#   ('Bernardo Badell', 'pilot'),
#   ('Carlos Arias Navarro', 'Minister'),
#   ('Eliseo Bayo', 'María Paz Ballesteros'),
#   ('Eliseo Bayo', 'actress'),
#   ('Eliseo Bayo', 'writer'),
#   ('María Paz Ballesteros', 'actress'),
#   ('María Paz Ballesteros', 'writer'),
#   ('Vicente Sainz de la Peña', 'worker'),
#   ('customers', 'employees')},
#  {('Azamat Tazhayakov', 'friends'), ('Azamat Tazhayakov', 'student')},
#  {("David D'Albini", 'manager')},
#  set(),
#  {('Terry Duffield', 'client')},
#  set(),
#  {('Timothy McVeigh', 'bomber'), ('co-conspirators', 'ilk')},
#  {('center', 'where')},
#  {('palco presidencial', 'the president')},
#  {('government', 'kingdom')},
#  {('home', 'house')},
#  set(),
#  {('Nicolas Maduro', 'the president')},
#  {('Islamists', 'perpetrators')},
#  {('attackers', 'hostage-takers')},
#  {('Joe Kebartas', 'resident'), ('Sean Collier', 'officer')},
#  {('Aaron Driver', 'Harun Abdurahman'), ('Strathroy', 'town')},
#  {('al-Qaeda', 'group')},
#  set(),
#  {('Boston Bomber', 'immigrant'),
#   ('Krystal Campbell', 'daughter'),
#   ('Lingzi Lu', 'student')},
#  {('driver', 'person')},
#  set(),
#  {('Centro Andino', 'mall'),
#   ('Iván Márquez', 'commander'),
#   ('José Aldemar Rojas Rodríguez', 'Mocho Kiko'),
#   ('José Aldemar Rojas Rodríguez', 'chief'),
#   ('José Aldemar Rojas Rodríguez', 'expert'),
#   ('José Aldemar Rojas Rodríguez', 'old'),
#   ('Mocho Kiko', 'expert'),
#   ('Mocho Kiko', 'old'),
#   ('chief', 'expert'),
#   ('chief', 'old'),
#   ('expert', 'old')},
#  {('Abdirahman Omar Osman', 'Mayor'),
#   ('al-Shabaab', 'group'),
#   ('bomber', 'herself')},
#  {('paramedics', 'services'), ('plaza', 'where')},
#  set(),
#  {('Teen', 'boy'), ('Teen', 'suspect'), ('boy', 'suspect')},
#  {('Armed Forces Recruiting Station', 'building'),
#   ('Gerald Koch', 'anarchist')},
#  {('Abu Mahdi al-Muhandis', 'chief')},
#  set(),
#  {('Azamat Tazhayakov', 'client'),
#   ('Azamat Tazhayakov', 'first'),
#   ('Azamat Tazhayakov', 'man'),
#   ('client', 'man'),
#   ('first', 'man')},
#  {('Terry Nichols', 'accomplice')},
#  {('IED', 'Improvised Explosive Device'), ('officers', 'policemen')},
#  {('Ahmad Khan Rahami', 'son')},
#  {('Michael Christopher Hayes', 'maker'),
#   ('Michael Christopher Hayes', 'volunteer'),
#   ('maker', 'volunteer')},
#  set(),
#  {('Accused Boston Bomber', 'client'),
#   ('Dzhokhar Tsarnaev', 'client'),
#   ('Krystle Campbell', 'manager'),
#   ('Lingzi Lu', 'student'),
#   ('United States', 'country')},
#  {('Ali Khamenei', 'Ayatollah')},
#  {('a car', 'vehicle'), ('station', 'train')},
#  {('Citi Plaza', 'mall')},
#  set(),
#  {('Nohad Machnouk', 'minister')},
#  {("King's Cross railway station", "King's Cross station"),
#   ('Provisional IRA', 'organization')},
#  {('Afghanistan', 'government'),
#   ('Bagram Air Base', 'airfield'),
#   ('attackers', 'insurgents')},
#  set(),
#  {('Commissioner', 'diplomat'),
#   ('Karachi', 'Sindh'),
#   ('Muhammad Raza', 'participant'),
#   ('Qari Saifullah', 'spokesperson'),
#   ('SMQureshiPTI', 'country'),
#   ('Thomas Drew CMG', 'diplomat')},
#  {('United States', 'abuser')},
#  {('Oscar Perez', 'lnspector')},
#  set(),
#  {('Bomber Tsarnaev', 'citizen'),
#   ('Bomber Tsarnaev', 'immigrant'),
#   ('Denise Richard', 'parents'),
#   ('Louis Jones', 'kidnapper'),
#   ('citizen', 'immigrant')},
#  set(),
#  set(),
#  {('Abdul Jabar Naeemi', 'governor'),
#   ('Mahbubullah Sayedi', 'chief'),
#   ('Noor Agha Faizi', 'spokesman')},
#  {('Alan Fry', 'Commissioner'), ('Alan Fry', 'head')},
#  {('Tamerlan (C) Tsarnaev', 'mastermind'), ('follower', 'mastermind')},
#  set(),
#  {('suspect', 'youth')},
#  set(),
#  set(),
#  set(),
#  {('Gen. Santander National Police Academy', 'establishment')},
#  {('El Mocho', 'member'),
#   ('El Mocho', 'suspect'),
#   ('José Aldemar Rojas Rodríguez', 'Kiko'),
#   ('José Aldemar Rojas Rodríguez', 'member'),
#   ('José Aldemar Rojas Rodríguez', 'suspect'),
#   ('Kiko', 'member'),
#   ('Kiko', 'suspect'),
#   ('expert', 'member'),
#   ('expert', 'suspect'),
#   ('itself it', 'terrorists')},
#  set(),
#  {('Jorge Rodríguez', 'Minister')},
#  set(),
#  set(),
#  set(),
#  {('country', 'government')},
#  set(),
#  {('Maxine', 'sister'), ('group Justice4the21', 'supporters')},
#  {('Bahrun Naim', 'mastermind'),
#   ('assailants', 'attackers'),
#   ('capital', 'city'),
#   ('government', 'nation')},
#  {('explosive device', 'such a bomb'), ('the van', 'vehicle')},
#  set(),
#  {('Dias Kadyrbayev', 'defendant')},
#  {('German man', 'main suspect'), ('Markus Beisicht', 'leader')},
#  {('Sean Collier', 'officer'),
#   ('Sean Collier', 'policeman'),
#   ('officer', 'policeman')},
#  {('American', 'government'),
#   ('Anwar al-Awlaki', 'cleric'),
#   ('James M. Branum', 'lawyer'),
#   ('Major', 'shooter'),
#   ('Naser Jason Abdo', 'Pfc'),
#   ('Naser Jason Abdo', 'client'),
#   ('bombs', 'dual')},
#  {('Oscar Perez', 'officer'),
#   ('attackers', 'the alleged conspirators'),
#   ('plotters', 'the alleged conspirators')},
#  set(),
#  {('bogey', 'compartments')},
#  set(),
#  set(),
#  {('Yasuo Yamamoto', 'resident')},
#  {('home', 'secretary')},
#  set(),
#  {('Farc', 'Revolutionary Armed Forces of Colombia'),
#   ('Iván Duque', 'President')},
#  set(),
#  {('Brother', 'Osama Bin Laden')},
#  set(),
#  set(),
#  set(),
#  {('Anwar al-Awlaki', 'cleric')},
#  {('Bomber', 'Dzhokhar Tsarnaev'),
#   ('Bomber', 'defendant'),
#   ('Bomber', 'suspect'),
#   ('Chechnya', 'region'),
#   ('Dzhokhar Tsarnaev', 'defendant'),
#   ('Dzhokhar Tsarnaev', 'suspect'),
#   ('Ibragim Todashev', 'son-in-law'),
#   ('James "Whitey" Bulger', 'James Whitey Bulger'),
#   ('James "Whitey" Bulger', 'boss'),
#   ('James Whitey Bulger', 'boss')},
#  {('Carter', 'Secretary'),
#   ('Genieve David', 'Maj'),
#   ('Phil Novack', 'spokesman'),
#   ('Republican', 'Senator'),
#   ('Republican', 'Ted Cruz'),
#   ('Senator', 'Ted Cruz')},
#  {('Deval Patrick', 'Governor'),
#   ('a "person of interest', 'suspect'),
#   ('any other bombs', 'no unexploded bombs')},
#  {('Jeremy Snow', 'Major'),
#   ('New Lodge Road', 'district'),
#   ('New Lodge Road', 'neighbourhood'),
#   ('companies', 'troops'),
#   ('district', 'neighbourhood'),
#   ('someone', 'spokesman')},
#  {('Bomber', 'Suspect Two'),
#   ('Bomber', 'kid'),
#   ('Dzokhar', 'djohar tsarnaev'),
#   ('Suspect Two', 'kid'),
#   ('Tsnarnaev', 'kid')},
#  {('Ewing Werlein Jr.', 'Judge'),
#   ('Ewing Werlein Jr.', 'court'),
#   ('Judge', 'court')},
#  {('Chuck Hagel', 'Secretary'), ('Deval Patrick', 'Governor')},
#  {('people', 'victims')},
#  set(),
#  {('Mohammed Mansour Jabarah', 'colleague'), ('fundamentalist', 'operative')},
#  {('Aaron Driver', 'supporter'),
#   ('Aaron Driver', 'suspect'),
#   ('supporter', 'suspect')},
#  set(),
#  {('Army Pfc', 'native'),
#   ('US soldier', 'convert'),
#   ('US soldier', 'native'),
#   ('convert', 'native')},
#  set(),
#  {('Maithripala Sirisena', 'President')},
#  {('Abu Anas al-Libi', 'operative')},
#  {('Olivia Jones', 'senior')},
#  {('Samuel', 'son'), ('Timothy McVeigh', 'bomber'), ('Vicki Weaver', 'wife')},
#  {('Joe Kebartas', 'resident'),
#   ('charmer', 'nephew'),
#   ('charmer', 'slacker'),
#   ('nephew', 'slacker')},
#  {('Alfred P. Murrah Federal Building', 'Murrah Building'),
#   ('culprits', 'defendants'),
#   ('culprits', 'individuals')},
#  set(),
#  set(),
#  {('18-year-old', 'activist'),
#   ('Dolours', 'student'),
#   ('Dolours', 'teachers'),
#   ('Dolours', 'three')},
#  {('bystanders', 'responders'),
#   ('destination', 'there'),
#   ('people', 'responders')},
#  {('25-year-old man', 'Andrew Schneck')},
#  {('Ian Hopkins', 'Manchester Chief Constable'), ('attacker', 'maker')},
#  set(),
#  {('Zubeidat', 'mother')},
#  {('boy', 'student'),
#   ('boy', 'teenager'),
#   ('boy', 'the Hurricane teen'),
#   ('boy', 'the youth'),
#   ('student', 'teenager'),
#   ('student', 'the Hurricane teen'),
#   ('student', 'the youth'),
#   ('teenager', 'the Hurricane teen')},
#  {('Aysha Frade', 'administrator'),
#   ('Briton', 'assailant'),
#   ('Briton', 'soldier'),
#   ('Briton', 'teacher'),
#   ('Keith Palmer', 'veteran'),
#   ('Londoners', 'city'),
#   ('assailant', 'soldier'),
#   ('assailant', 'teacher'),
#   ('bodybuilder', 'soldier'),
#   ('bodybuilder', 'teacher'),
#   ('soldier', 'teacher')},
#  {('An Phoblacht', 'Republican News')},
#  set(),
#  {('a Ford car which', 'a hi-jacked bread van')},
#  set(),
#  set(),
#  set(),
#  {('Karl-Heinz Hoffmann', 'descendant'), ('rue Copernic synagogue', 'where')},
#  set(),
#  set(),
#  {('Federal Medical Detention', 'prison medical facility'),
#   ('Federal Medical Detention', 'there'),
#   ('Lindsey Graham', 'Senator'),
#   ('Zubeidat Tsarnaeva', 'person'),
#   ('prison medical facility', 'there')},
#  set(),
#  {('Timothy McVeigh', 'customer'),
#   ('Timothy McVeigh', 'defendant'),
#   ('customer', 'defendant')},
#  {('bomber', 'member')},
#  {('bomber', 'client'), ('bomber', 'student'), ('client', 'student')},
#  {('bomber', 'male'),
#   ('itself', 'symbol'),
#   ('site', 'symbol'),
#   ('structure', 'symbol')},
#  {('country', 'government')},
#  set(),
#  {('Ahmad Khan Rahami', 'Bomber'),
#   ('Ahmad Khan Rahami', 'guy'),
#   ('Bomber', 'citizen'),
#   ('Bomber', 'guy'),
#   ('citizen', 'guy')},
#  {('Belgian international airport', 'town')},
#  {('Martin Coughlan', 'brains')},
#  set(),
#  set(),
#  {('J Peter Donald', 'spokesman')},
#  {('Brazil', 'Colombian'), ('apartment', 'where'), ('building', 'where')},
#  {('Iván Duque', 'President'), ('José Aldemar Rojas Rodríguez', 'driver')},
#  set(),
#  {('Orangetheory Fitness Chelsea', 'center'),
#   ('Orangetheory Fitness Chelsea', 'company')},
#  set(),
#  set(),
#  set(),
#  {('Dzhokhar', 'brother'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Tamerlan Tsarnaev', 'son')},
#  set(),
#  {('Anwar al-Awlaki', 'cleric')},
#  {('Dzhokhar Tsarnaev', 'guy'),
#   ('Krystle Campbell', 'Lingzi Lu'),
#   ('Krystle Campbell', 'manager'),
#   ('Lingzi Lu', 'manager'),
#   ('Marty Walsh', 'Mayor')},
#  {('Sherabat Khan', 'commander'),
#   ('Sherabat Khan', 'lieutenant'),
#   ('people', 'total')},
#  {('Ghazni', 'city'), ('Leandro Jasso', 'Sergeant')},
#  set(),
#  set(),
#  set(),
#  {('itself', 'organization')},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {('client', 'defendant'), ('client', 'minor')},
#  set(),
#  set(),
#  set(),
#  set(),
#  set(),
#  {('Tamerlan Tsarnaev', 'brother')},
#  {('Tsarnaev', 'brothers'), ('couple', 'pair')},
#  set(),
#  {('Hassan Diab', 'academic'),
#   ('Hassan Diab', 'father'),
#   ('Hassan Diab', 'member'),
#   ('Hassan Diab', 'professor'),
#   ('Hassan Diab', 'sociologist'),
#   ('academic', 'father'),
#   ('academic', 'member'),
#   ('academic', 'professor'),
#   ('academic', 'sociologist'),
#   ('father', 'member'),
#   ('father', 'sociologist'),
#   ('professor', 'sociologist')},
#  {('Bomber', 'guy')},
#  {('Jonathan J. Dunbar', 'Sgt')},
#  set(),
#  set(),
#  set(),
#  {('citizen', 'person')},
#  {('Palace of Princes restaurant', 'Palace of the Princes')},
#  set(),
#  {('A 20-year-old former teaching student', 'Aydin Sevigin'),
#   ('A 20-year-old former teaching student', 'a martyr'),
#   ('Attunda District Court', 'the court'),
#   ('Aydin Sevigin', 'a martyr'),
#   ('Mikael Swahn', 'chairman'),
#   ('a suicide bomb', 'bombs'),
#   ('ingredients', 'liquids'),
#   ('shrapnel', 'such a bomb')},
#  set(),
#  set(),
#  {('James McDade', 'lieutenant'),
#   ('John Smith', 'pensioner'),
#   ('Kieran Conway', 'chief'),
#   ('Minister', 'Sir'),
#   ('Oliver Heald QC', 'Sir'),
#   ('girl', 'woman')},
#  {('E. Afghan', 'country'), ('improvised explosive devices', 'weapons')},
#  {('Britain', 'government'),
#   ('Emma Webb', 'researcher'),
#   ('Manchester Bomber', 'Salman Abedi'),
#   ('Manchester Bomber', 'dropout'),
#   ('Manchester Bomber', 'enthusiast'),
#   ('Manchester Bomber', 'fan'),
#   ('Manchester Bomber', 'killer'),
#   ('Mohammed Saeed', 'imam'),
#   ('Ramadan Abedi', 'guard'),
#   ('Salman Abedi', 'dropout'),
#   ('Salman Abedi', 'enthusiast'),
#   ('Salman Abedi', 'fan'),
#   ('dropout', 'enthusiast'),
#   ('dropout', 'fan'),
#   ('dropout', 'killer'),
#   ('enthusiast', 'fan')},
#  {('Dzhokhar', 'brother'),
#   ('Tamerlan Tsarnaev', 'follower'),
#   ('Tamerlan Tsarnaev', 'son')},
#  {('Islamic Society of Boston mosque', 'center'),
#   ('contributor', 'journalist')},
#  set(),
#  set(),
#  {('M600 Pros', 'M600 drones'),
#   ('M600 Pros', 'the M600 Pro drones'),
#   ('M600 drones', 'the M600 Pro drones'),
#   ('Matrice M600 Pro c-drones', 'the M600 Pro drones')},
#  {('Dzhokar Tsarnaev', 'student'),
#   ('Federal Medical Center Devens', 'prison medical facility'),
#   ('Tamerlan Tsarnaev', 'co-conspirator')},
#  set(),
#  set(),
#  {('Phantom 2', 'unmanned drone'),
#   ('office', 'roof'),
#   ('office', 'there'),
#   ('roof', 'there')},
#  {('Anwar al-Awlaki', 'piper'), ('Atiyah Abd al-Rahman', 'aide')},
#  {("George O'Toole", 'John Joseph Moakley'), ('Jeff Bauman', 'spectator')},
#  {('Birmingham Six,', 'Six men')},
#  {('Asia Siddiqui', 'client'), ('citizens', 'pair'), ('homeland', 'nation')},
#  {('John Morrow', 'workman'), ("Paddy McGurk's", 'Paddy McManus')},
#  set(),
#  set(),
#  set(),
#  {('Abdifatah W', 'companion')}]

# %%
per_example_result = []
count = 0
for i, coref_pairs in enumerate(coref_pairs_non_single_mention):
    ex = examples[i]
    per_example_result.append([])
    templates = ex['templates']
    text = ex['doctext']

    for pair in set(coref_pairs):
        blocked = set()
        sorted_pairs = sorted(list(pair), key=len, reverse=True)
        example_result = []
        for word in sorted_pairs:
            pattern = re.compile(re.escape(word))
            positions = [match.start() for match in re.finditer(pattern, text)]
            positions = set(positions).difference(blocked)
            example_result.append(positions)
            for i in range(len(word)):
                blocked = blocked.union([p + i for p in positions])
        if len(example_result[0]) == 0 or len(example_result[1]) == 0:
            continue
        per_example_result[-1].append((sorted_pairs[0], example_result[0], sorted_pairs[1], example_result[1]))
        count += len(example_result[0]) * len(example_result[1])

# %%
count
# Out:
# 200244

# %%
per_example_result
# Out:
# [[('The Taliban', {0, 4748, 4918}, 'insurgents', {3054, 3854, 4267}),
#   ('insurgents', {3054, 3854, 4267}, 'militants', {5093}),
#   ('official',
#    {161, 349, 434, 887, 1247, 1381, 1894, 2013, 2284, 2317, 2982, 3148, 3659},
#    'source',
#    {1062, 5133}),
#   ('The Taliban', {0, 4748, 4918}, 'militants', {5093}),
#   ('compound', {89, 4515}, 'complex', {1194, 2389, 4423}),
#   ('members', {33, 1123, 1303, 5155}, '100', {29, 1119, 1299}),
#   ('building', {1846}, 'complex', {1194, 2389, 4423}),
#   ('training center', {269, 661}, 'campus', {599, 758}),
#   ('compound', {89, 4515}, 'campus', {599, 758}),
#   ('training center', {269, 661}, 'complex', {1194, 2389, 4423}),
#   ('militants',
#    {5093},
#    'Taliban',
#    {4, 906, 2949, 3540, 3599, 3968, 4259, 4452, 4752, 4922, 5744}),
#   ('member', {33, 1123, 1303, 1414, 5155}, 'Hotak', {1404, 1658}),
#   ('Sharif Hotak', {1397}, 'Hotak', {1658}),
#   ('over 100', {1294}, 'members', {33, 1123, 1303, 5155}),
#   ('Sharif Hotak', {1397}, 'member', {33, 1123, 1303, 1414, 5155}),
#   ('representatives',
#    {3472, 3607},
#    'officials',
#    {887, 1894, 2013, 2982, 3659}),
#   ('insurgents',
#    {3054, 3854, 4267},
#    'Taliban',
#    {4, 906, 2949, 3540, 3599, 3968, 4259, 4452, 4752, 4922, 5744}),
#   ('The Taliban',
#    {0, 4748, 4918},
#    'Taliban',
#    {906, 2949, 3540, 3599, 3968, 4259, 4452, 5744}),
#   ('more than 100', {19, 1109}, 'members', {33, 1123, 1303, 5155}),
#   ('over 100', {1294}, '100', {29, 1119}),
#   ('capital',
#    {699, 3519, 4611},
#    'Kabul',
#    {385, 1582, 1643, 1925, 2296, 2329, 3913, 4621}),
#   ('Taliban',
#    {4, 906, 2949, 3540, 3599, 3968, 4259, 4452, 4752, 4922, 5744},
#    'group',
#    {4377}),
#   ('more than 100', {19, 1109}, 'over 100', {1294}),
#   ('Kabul city', {1582}, 'capital', {699, 3519, 4611}),
#   ('training center', {269, 661}, 'compound', {89, 4515}),
#   ('complex', {1194, 2389, 4423}, 'campus', {599, 758}),
#   ('The Taliban', {0, 4748, 4918}, 'group', {4377})],
#  [],
#  [('Dzhokhar Tsarnaev',
#    {135},
#    'Tsarnaev',
#    {562,
#     653,
#     819,
#     905,
#     1138,
#     1336,
#     1576,
#     1714,
#     2093,
#     2436,
#     2735,
#     2873,
#     2985,
#     3256,
#     3637,
#     4069,
#     4316}),
#   ('Boston', {0, 112, 3449, 4632}, 'here', {1037, 3734}),
#   ('person', {2376, 4033}, 'son', {4001}),
#   ('immigrant',
#    {3678},
#    'Tsarnaev',
#    {144,
#     562,
#     653,
#     819,
#     905,
#     1138,
#     1336,
#     1576,
#     1714,
#     2093,
#     2436,
#     2735,
#     2873,
#     2985,
#     3256,
#     3637,
#     4069,
#     4316}),
#   ('Dzhokhar Tsarnaev', {135}, 'bomber', {128}),
#   ('Patricia Campbell', {2273}, 'mother', {2297}),
#   ('immigrant', {3678}, 'Chechen', {376}),
#   ('Krystle Campbell', {2307, 2641}, 'daughter', {2524}),
#   ('brother', {1053, 1280, 1643, 4129}, 'Martin', {4007}),
#   ('Tsarnaev',
#    {144,
#     562,
#     653,
#     819,
#     905,
#     1138,
#     1336,
#     1576,
#     1714,
#     2093,
#     2436,
#     2735,
#     2873,
#     2985,
#     3256,
#     3637,
#     4069,
#     4316},
#    'Chechen',
#    {376}),
#   ('Chechen', {376}, 'bomber', {128}),
#   ('Tamerlan', {1063, 1295}, 'brother', {1053, 1280, 1643, 4129}),
#   ('Karen Rand McWatters', {2676}, 'McWatters', {2969}),
#   ('American', {3758, 3821, 3871}, 'America', {3328, 3472}),
#   ('Karen Rand McWatters', {2676}, 'friend', {2667}),
#   ('victims', {202, 1845, 2155, 3619}, 'people', {948, 1831, 3051}),
#   ('American', {3758, 3821, 3871}, 'Boston', {0, 112, 3449, 4632}),
#   ('immigrant', {3678}, 'bomber', {128}),
#   ('Martin', {4007}, 'son', {2379, 4001, 4036}),
#   ('America', {3328, 3472, 3758, 3821, 3871}, 'Boston', {0, 112, 3449, 4632}),
#   ('Tsarnaev',
#    {144,
#     562,
#     653,
#     819,
#     905,
#     1138,
#     1336,
#     1576,
#     1714,
#     2093,
#     2436,
#     2735,
#     2873,
#     2985,
#     3256,
#     3637,
#     4069,
#     4316},
#    'Bomber',
#    {16}),
#   ('American', {3758, 3821, 3871}, 'here', {1037, 3734}),
#   ('America', {3328, 3472, 3758, 3821, 3871}, 'here', {1037, 3734}),
#   ('Dzhokhar Tsarnaev', {135}, 'immigrant', {3678}),
#   ('Tsarnaev',
#    {144,
#     562,
#     653,
#     819,
#     905,
#     1138,
#     1336,
#     1576,
#     1714,
#     2093,
#     2436,
#     2735,
#     2873,
#     2985,
#     3256,
#     3637,
#     4069,
#     4316},
#    'bomber',
#    {128})],
#  [('country', {1838}, 'Afghan', {1717, 1987, 2204}),
#   ('Afghanistan', {1717, 2204}, 'Afghan', {1987}),
#   ('Afghan', {1717, 1987, 2204}, 'where', {1731}),
#   ('Afghanistan', {1717, 2204}, 'country', {1838}),
#   ('Pakistan', {347, 2229, 2602}, 'hub', {2246}),
#   ('Afghanistan', {1717, 2204}, 'where', {1731}),
#   ('country', {1838}, 'where', {1731}),
#   ('civilians', {461, 1504}, 'people', {1255}),
#   ('drones', {329, 559}, 'drone', {180, 841, 1272, 2253, 2502})],
#  [('Provisional IRA', {20}, 'IRA', {619, 1169, 1724}),
#   ('cell', {2030}, 'unit', {638, 1173, 1728, 2143}),
#   ('Irish', {322, 485, 2472}, 'IRA', {32, 619, 1169, 1724}),
#   ('cell', {2030}, 'ASU', {645}),
#   ('Balcombe Street Gang', {668, 1067}, 'ASU', {645}),
#   ('unit', {638, 1173, 1728, 2143}, 'ASU', {645}),
#   ('Balcombe Street Gang', {668, 1067}, 'cell', {2030}),
#   ('a bomb',
#    {992, 1742},
#    'bomb',
#    {36, 262, 762, 1052, 1103, 1193, 1258, 1603, 1877, 1940, 2193, 2301}),
#   ('civilians', {1296}, 'people', {165, 1785, 1980, 2343}),
#   ('Gang', {684, 1083}, 'ASU', {645}),
#   ('Gang', {684, 1083}, 'unit', {638, 1173, 1728, 2143}),
#   ('Balcombe Street Gang', {668, 1067}, 'unit', {638, 1173, 1728, 2143}),
#   ('house', {94, 1136}, 'pub', {87, 330, 1129, 1339, 1540, 1936, 2480}),
#   ('Caterham Arms public house',
#    {73, 1115},
#    'pub',
#    {330, 1339, 1540, 1936, 2480})],
#  [('department', {3641}, 'Police', {1009, 2137, 2496, 2916, 3132, 5111}),
#   ('Donald Trump', {8015}, 'nominee', {8007, 8405}),
#   ('spokesman', {4156, 5765, 10052}, 'Donald', {4138, 5745, 8015}),
#   ('Andrew Cuomo', {15}, 'Cuomo', {293, 4564, 4879, 4953, 5249, 5555, 5858}),
#   ('neighborhood',
#    {7450},
#    'area',
#    {3282, 3381, 3535, 5589, 5728, 6296, 8595, 8703, 8814}),
#   ('attacker', {9995}, 'soldier', {10012}),
#   ('New York Police Department',
#    {2487},
#    'police',
#    {555, 979, 2252, 2412, 3318, 4149, 5673, 5758, 8791, 9920}),
#   ('soldier',
#    {10012},
#    'man',
#    {2895, 4162, 5771, 5881, 7199, 7418, 7634, 8884, 9228, 9836, 10058, 10541}),
#   ('New York Police Department',
#    {2487},
#    'Police',
#    {1009, 2137, 2916, 3132, 5111}),
#   ('where',
#    {6306, 7747},
#    'area',
#    {3282, 3381, 3535, 5589, 5728, 6296, 8595, 8703, 8814}),
#   ('Bill de Blasio', {1194}, 'DeBlasio', {2062}),
#   ('Keith Salomon', {6739}, 'Salomon', {7024}),
#   ('nominee', {8007, 8405}, 'Trump', {8022, 8236}),
#   ('Police',
#    {1009, 2137, 2496, 2916, 3132, 5111},
#    'police',
#    {555, 979, 2252, 2412, 3318, 4149, 5673, 5758, 8791, 9920}),
#   ('de Blasio', {1199, 1396}, 'DeBlasio', {2062}),
#   ('attacker',
#    {9995},
#    'man',
#    {2895, 4162, 5771, 5881, 7199, 7418, 7634, 8884, 9228, 9836, 10058, 10541}),
#   ('New York',
#    {0,
#     328,
#     970,
#     1179,
#     1659,
#     1930,
#     2487,
#     2926,
#     3737,
#     4900,
#     5096,
#     7818,
#     8175,
#     8575,
#     8838,
#     9214,
#     10382,
#     10596},
#    'city',
#    {7071, 9066}),
#   ('New York',
#    {0,
#     328,
#     970,
#     1179,
#     1659,
#     1930,
#     2487,
#     2926,
#     3737,
#     4900,
#     5096,
#     7818,
#     8175,
#     8575,
#     8838,
#     9214,
#     10382,
#     10596},
#    'state',
#    {3335, 3746, 4713, 8898, 10081}),
#   ('Bill de Blasio', {1194}, 'de Blasio', {1396}),
#   ('New York Police Department', {2487}, 'department', {3641}),
#   ('department',
#    {3641},
#    'police',
#    {555, 979, 2252, 2412, 3318, 4149, 5673, 5758, 8791, 9920})],
#  [('IEDs', {1144, 3740}, 'IED', {1900, 3301, 3663, 4033, 4407}),
#   ('explosive devices',
#    {1118, 3142},
#    'IED',
#    {1144, 1900, 3301, 3663, 3740, 4033, 4407}),
#   ('Boston Marathon', {259}, 'Boston', {899, 1494, 2240}),
#   ('explosive devices', {1118, 3142}, 'IEDs', {1144, 3740}),
#   ('Pakistani', {2645}, 'Pakistan', {1433})],
#  [('Bomber', {22}, 'bomber', {64}),
#   ('Ahmad Khan Rahimi',
#    {71},
#    'Rahimi',
#    {268, 661, 932, 1082, 1265, 1761, 2008, 2331}),
#   ('Ahmad Khan Rahimi', {71}, 'bomber', {64}),
#   ('Bomber',
#    {22},
#    'Rahimi',
#    {82, 268, 661, 932, 1082, 1265, 1761, 2008, 2331}),
#   ('citizen',
#    {726},
#    'Rahimi',
#    {82, 268, 661, 932, 1082, 1265, 1761, 2008, 2331}),
#   ('Ahmad Khan Rahimi', {71}, 'Bomber', {22}),
#   ('Prosecutors', {675}, 'prosecutors', {1061, 1309, 1716}),
#   ('Rahimi',
#    {82, 268, 661, 932, 1082, 1265, 1761, 2008, 2331},
#    'bomber',
#    {64})],
#  [],
#  [('brothers', {1430, 2261}, 'suspects', {135, 413, 2195}),
#   ('Tamerlan Tsarnaev',
#    {571, 920, 959},
#    'brother',
#    {561, 1045, 1430, 2028, 2261}),
#   ('wounded', {2396}, '264', {2371}),
#   ('Tamerlan Tsarnaev', {571, 920, 959}, 'Tsarnaev', {442, 1421, 1707}),
#   ('Sean Collier', {1382}, 'policeman', {1372}),
#   ('Suspects', {8}, 'brothers', {1430, 2261}),
#   ('Tamerlan Tsarnaev', {571, 920, 959}, 'Tamerlan', {1596}),
#   ('Boylston Street', {1147}, 'thoroughfare', {1174}),
#   ('Suspects', {8}, 'suspects', {135, 413, 2195}),
#   ('Suspects', {8}, 'Tsarnaev', {442, 580, 929, 968, 1421, 1707}),
#   ('Tamerlan',
#    {571, 920, 959, 1596},
#    'brother',
#    {561, 1045, 1430, 2028, 2261}),
#   ('Tamerlan',
#    {571, 920, 959, 1596},
#    'Tsarnaev',
#    {442, 580, 929, 968, 1421, 1707}),
#   ('brothers', {1430, 2261}, 'sons', {240}),
#   ('Tsarnaev', {442, 580, 929, 968, 1421, 1707}, 'brothers', {1430, 2261}),
#   ('suspects', {135, 413, 2195}, 'sons', {240}),
#   ('Dzhokhar', {1053, 1829, 1967}, 'brother', {561, 1045, 1430, 2028, 2261})],
#  [('Dzhokhar Tsarnaev',
#    {0, 1000, 1197, 2390, 2992, 3335, 3502},
#    'Tsarnaev',
#    {83, 214, 750, 1669, 1891, 2126, 2193, 2567, 2796, 3288}),
#   ('his close friend', {113}, 'Stephen Silva', {132}),
#   ('another person', {3253}, '26', {590, 2884, 3437}),
#   ('Ruger pistol', {1047}, 'a gun', {447}),
#   ('Ruger pistol', {1047}, 'gun', {449, 534, 1066, 1827, 1940, 3613}),
#   ('the bombs', {974, 2156, 2644, 2971}, 'two', {610, 1815, 2581, 2729}),
#   ('lifeguards', {311}, 'Tsarnaevs', {2126, 2796}),
#   ('Both brothers', {1743}, 'Tsarnaevs', {2126, 2796}),
#   ('Tamerlan Tsarnaev',
#    {741, 1660, 1882, 2184, 2558, 3279},
#    'another person',
#    {3253}),
#   ('Tamerlan',
#    {579, 741, 1660, 1882, 1991, 2184, 2558, 3279},
#    '26',
#    {590, 2884, 3437}),
#   ('handguns', {1823}, 'two', {610, 1815, 2581, 2729}),
#   ('Sean Collier', {1117}, 'officer', {1109}),
#   ('the bombs', {974, 2156, 2644, 2971}, 'bombs', {2760}),
#   ('Tamerlan Tsarnaev',
#    {741, 1660, 1882, 2184, 2558, 3279},
#    'Tamerlan',
#    {579, 1991}),
#   ('his close friend', {113}, 'Silva', {140, 164, 227, 428, 1025}),
#   ('Dzhokhar Tsarnaev', {0, 1000, 1197, 2390, 2992, 3335, 3502}, '19', {99}),
#   ('bombs', {978, 2160, 2648, 2760, 2975}, 'two', {610, 1815, 2581, 2729}),
#   ('Stephen Silva', {132}, 'Silva', {164, 227, 428, 1025}),
#   ('Whole Foods', {3032}, 'store', {2230, 3199}),
#   ('Dzhokhar Tsarnaev',
#    {0, 1000, 1197, 2390, 2992, 3335, 3502},
#    'Dzhokhar',
#    {2306}),
#   ('another person',
#    {3253},
#    'Tamerlan',
#    {579, 741, 1660, 1882, 1991, 2184, 2558, 3279}),
#   ('Tamerlan Tsarnaev',
#    {741, 1660, 1882, 2184, 2558, 3279},
#    '26',
#    {590, 2884, 3437}),
#   ('a gun', {447}, 'gun', {534, 1066, 1827, 1940, 3613}),
#   ('Both brothers', {1743}, 'lifeguards', {311})],
#  [('Osama bin Laden', {124}, 'bin Laden', {632, 876}),
#   ('Osama bin Laden', {124}, 'suspect', {349}),
#   ('Bin Laden', {114}, 'suspect', {349}),
#   ('bin Laden', {130, 632, 876}, 'suspect', {349}),
#   ('Bin Laden', {114}, 'bin Laden', {130, 632, 876})],
#  [('president', {145, 632, 775, 1671}, 'Ghani', {162, 211, 792, 1121}),
#   ('Ashraf Ghani', {155, 785}, 'Ghani', {211, 1121}),
#   ('ground', {745}, 'site', {835, 1224}),
#   ('people', {59, 597, 867, 993, 1481}, '26', {186, 990}),
#   ('President', {1111}, 'president', {145, 632, 775, 1671}),
#   ('Ashraf Ghani', {155, 785}, 'president', {145, 632, 775, 1671}),
#   ('President', {1111}, 'Ghani', {162, 211, 792, 1121}),
#   ('people', {59, 597, 867, 993, 1481}, '22', {324, 1478}),
#   ('victims', {1087}, 'dead', {419})],
#  [('suspects',
#    {1680, 1859, 2651, 2999},
#    'men',
#    {94, 1827, 2593, 2872, 2951, 3863, 4106}),
#   ('Bilal Mohammed', {218}, 'client', {4233}),
#   ('Chinese', {2240, 3987}, 'China', {700, 2112}),
#   ('Thailand', {362, 2049}, 'Thai', {0, 816, 915, 2322, 3951}),
#   ('Chuchart Kanpai', {1898}, 'lawyer', {1891, 4217}),
#   ('Bilal Mohammed', {218}, 'Bilal', {595, 3574, 3681, 4207, 4340}),
#   ('Mieraili', {237, 605}, 'Yusufu', {246, 3633, 3913}),
#   ('suspect',
#    {481, 1680, 1859, 2651, 2999, 4299},
#    'men',
#    {94, 1827, 2593, 2872, 2951, 3863, 4106}),
#   ('destination', {1032}, 'Shrine', {38, 431, 1005, 2216, 3187}),
#   ('suspects', {1680, 1859, 2651, 2999}, 'suspect', {481, 4299}),
#   ('Erawan Shrine', {424, 998, 2209, 3180}, 'Shrine', {38}),
#   ('Bilal Mohammed', {218}, 'man', {2444, 3203, 3604}),
#   ('suspects',
#    {1680, 1859, 2651, 2999},
#    'two',
#    {90, 1609, 1676, 1855, 2647, 2995, 3854, 4197}),
#   ('Mieraili Yusufu', {237}, 'Yusufu', {3633, 3913}),
#   ('client', {4233}, 'man', {2444, 3203, 3604}),
#   ('client', {4233}, 'Bilal', {218, 595, 3574, 3681, 4207, 4340}),
#   ('Mieraili Yusufu', {237}, 'Mieraili', {605}),
#   ('Police', {531, 1504, 2895, 3554, 4038, 4154}, 'police', {2496, 3869}),
#   ('Chinese', {2240, 3987}, 'where', {2120}),
#   ('destination', {1032}, 'shrine', {157, 2522, 3273, 3425}),
#   ('Erawan Shrine', {424, 998, 2209, 3180}, 'shrine', {157, 2522, 3273, 3425}),
#   ('Thailand', {362, 2049}, 'country', {1468}),
#   ('men',
#    {94, 1827, 2593, 2872, 2951, 3863, 4106},
#    'two',
#    {90, 1609, 1676, 1855, 2647, 2995, 3854, 4197}),
#   ('National Police', {2886}, 'police', {2496, 3869}),
#   ('Bilal', {218, 595, 3574, 3681, 4207, 4340}, 'man', {2444, 3203, 3604}),
#   ('National Police', {2886}, 'Police', {531, 1504, 3554, 4038, 4154}),
#   ('China', {700, 2112}, 'where', {2120}),
#   ('country', {1468}, 'Thai', {0, 362, 816, 915, 2049, 2322, 3951}),
#   ('Authorities', {5, 1355}, 'authorities', {371, 920}),
#   ('Erawan Shrine', {424, 998, 2209, 3180}, 'destination', {1032}),
#   ('Shrine', {38, 431, 1005, 2216, 3187}, 'shrine', {157, 2522, 3273, 3425})],
#  [('Nestor Reverol', {2445}, 'Reverol', {2771}),
#   ('government',
#    {307, 1524, 2085, 2479, 4014, 4748},
#    'the',
#    {123,
#     250,
#     542,
#     627,
#     697,
#     768,
#     894,
#     930,
#     994,
#     1208,
#     1250,
#     1469,
#     1474,
#     1547,
#     1875,
#     2081,
#     2111,
#     2168,
#     2191,
#     2289,
#     2325,
#     2360,
#     2390,
#     2475,
#     2499,
#     2595,
#     2631,
#     2686,
#     2885,
#     2898,
#     2919,
#     2940,
#     2952,
#     3087,
#     3111,
#     3123,
#     3140,
#     3162,
#     3232,
#     3283,
#     3295,
#     3354,
#     3367,
#     3423,
#     3479,
#     3526,
#     3664,
#     3870,
#     3933,
#     3946,
#     3971,
#     3999,
#     4150,
#     4169,
#     4194,
#     4209,
#     4267,
#     4466,
#     4486,
#     4509,
#     4561,
#     4597,
#     4650,
#     4719,
#     4820}),
#   ('apartment', {2956, 3127, 3312}, 'building', {1113, 2830}),
#   ('Venezuela',
#    {48, 267, 296, 1513, 2411, 2690, 4003, 4213},
#    'the',
#    {123,
#     250,
#     542,
#     627,
#     697,
#     768,
#     894,
#     930,
#     994,
#     1208,
#     1250,
#     1469,
#     1474,
#     1547,
#     1875,
#     2081,
#     2111,
#     2168,
#     2191,
#     2289,
#     2325,
#     2360,
#     2390,
#     2475,
#     2499,
#     2595,
#     2631,
#     2686,
#     2885,
#     2898,
#     2919,
#     2940,
#     2952,
#     3087,
#     3111,
#     3123,
#     3140,
#     3162,
#     3232,
#     3283,
#     3295,
#     3354,
#     3367,
#     3423,
#     3479,
#     3526,
#     3664,
#     3870,
#     3933,
#     3946,
#     3971,
#     3999,
#     4150,
#     4169,
#     4194,
#     4209,
#     4267,
#     4466,
#     4486,
#     4509,
#     4561,
#     4597,
#     4650,
#     4719,
#     4820}),
#   ('Venezuela',
#    {48, 267, 296, 1513, 2411, 2690, 4003, 4213},
#    'state',
#    {587, 1254, 3427}),
#   ('Venezuelan', {296, 1513, 2690, 4003, 4213}, 'state', {587, 1254, 3427}),
#   ('Venezuelan',
#    {296, 1513, 2690, 4003, 4213},
#    'government',
#    {307, 1524, 2085, 2479, 4014, 4748}),
#   ('vicinity', {3144}, 'where', {745, 3156, 3913}),
#   ('government',
#    {307, 1524, 2085, 2479, 4014, 4748},
#    'Venezuela',
#    {48, 267, 296, 1513, 2411, 2690, 4003, 4213}),
#   ('Nicolás Maduro', {396}, 'president', {62, 254, 457, 2635}),
#   ('President', {386}, 'president', {62, 254, 457, 2635}),
#   ('drones',
#    {21, 169, 421, 809, 1551, 1742, 2172, 2364, 3668, 3803, 4723},
#    'drone',
#    {898,
#     1064,
#     1086,
#     1478,
#     2115,
#     2252,
#     2599,
#     2753,
#     2910,
#     3166,
#     3243,
#     3893,
#     4067}),
#   ('government',
#    {307, 1524, 2085, 2479, 4014, 4748},
#    'state',
#    {587, 1254, 3427}),
#   ('President', {386}, 'Maduro', {404, 643, 1273, 3449, 3630}),
#   ('Venezuelan', {296, 1513, 2690, 4003, 4213}, 'Venezuela', {48, 267, 2411}),
#   ('Nestor Reverol', {2445}, 'minister', {2434}),
#   ('Nicolás Maduro', {396}, 'President', {386}),
#   ('minister', {2434}, 'Reverol', {2452, 2771}),
#   ('president', {62, 254, 457, 2635}, 'Maduro', {404, 643, 1273, 3449, 3630}),
#   ('Nicolás Maduro', {396}, 'Maduro', {643, 1273, 3449, 3630})],
#  [('country',
#    {65, 3841, 4368},
#    'Iraq',
#    {25, 2514, 3132, 3522, 3658, 4038, 4118, 4296, 4399, 4768}),
#   ('Baaj', {3072}, 'town', {567, 2102, 2474, 2905, 3064, 3268, 3404, 3586}),
#   ('Mosul', {3043}, 'city', {2869, 3035}),
#   ('Heet', {3412}, 'town', {567, 2102, 2474, 2905, 3064, 3268, 3404, 3586}),
#   ('Tarmiyah',
#    {2110},
#    'town',
#    {567, 2102, 2474, 2905, 3064, 3268, 3404, 3586}),
#   ('Taji',
#    {575, 773},
#    'town',
#    {567, 2102, 2474, 2905, 3064, 3268, 3404, 3586}),
#   ('Iraqi',
#    {2514, 3132, 3522, 4038},
#    'Iraq',
#    {25, 3658, 4118, 4296, 4399, 4768}),
#   ('Diyala province', {2248}, 'province', {2630, 2892}),
#   ('Dhuluiyah',
#    {2482},
#    'town',
#    {567, 2102, 2474, 2905, 3064, 3268, 3404, 3586}),
#   ('country', {65, 3841, 4368}, 'Iraqi', {2514, 3132, 3522, 4038})],
#  [('Cuba',
#    {0, 140, 378, 481, 1020, 1149, 1283, 1576, 1700, 1818},
#    'home',
#    {449}),
#   ('Colombia',
#    {15, 121, 706, 1374, 1561, 1914, 2082},
#    'country',
#    {547, 1508, 2271}),
#   ('government',
#    {1722, 1824},
#    'Colombia',
#    {15, 121, 706, 1374, 1561, 1914, 2082}),
#   ('National Liberation Army',
#    {185},
#    'group',
#    {84, 312, 992, 1125, 1541, 2258, 2550}),
#   ('country', {547, 1508, 2271}, 'home', {449}),
#   ('Ivan Duque', {343}, 'President', {333, 2015}),
#   ('home', {449}, 'host', {387, 615, 2485, 2595}),
#   ('President',
#    {333, 2015},
#    'Duque',
#    {348, 890, 1133, 1329, 1397, 2313, 2426}),
#   ('Nicolas Rodriguez', {1612}, 'Rodriguez', {1802}),
#   ('country',
#    {547, 1508, 2271},
#    'Cuba',
#    {0, 140, 378, 481, 1020, 1149, 1283, 1576, 1700, 1818}),
#   ('group',
#    {84, 312, 992, 1125, 1541, 2258, 2550},
#    'ELN',
#    {212, 458, 734, 958, 1592, 2218, 2353, 2380}),
#   ('country', {547, 1508, 2271}, 'host', {387, 615, 2485, 2595}),
#   ('Cuba',
#    {0, 140, 378, 481, 1020, 1149, 1283, 1576, 1700, 1818},
#    'host',
#    {387, 615, 2485, 2595}),
#   ('government', {1722, 1824}, 'country', {547, 1508, 2271}),
#   ('Cuban', {1700, 1818}, 'Cuba', {0, 140, 378, 481, 1020, 1149, 1283, 1576}),
#   ('government', {1722, 1824}, 'host', {387, 615, 2485, 2595}),
#   ('government',
#    {1722, 1824},
#    'Cuba',
#    {0, 140, 378, 481, 1020, 1149, 1283, 1576, 1700, 1818}),
#   ('National Liberation Army',
#    {185},
#    'ELN',
#    {212, 458, 734, 958, 1592, 2218, 2353, 2380}),
#   ('Nicolas Rodriguez', {1612}, 'commander', {1602, 1682})],
#  [('Town', {644, 4122, 4650}, 'city', {1598, 2082}),
#   ('republican', {5616, 5861, 6276}, 'Irish', {1895, 5554, 6334, 6693}),
#   ('James McDade', {697, 3236}, 'bomber', {690, 2438}),
#   ('lieutenant', {3915}, 'McDade', {703, 3242, 3904}),
#   ('Birmingham',
#    {263, 1148, 1199, 1527, 2767, 3121, 3933, 4400, 5169, 5374},
#    'Town',
#    {644, 4122, 4650}),
#   ('Irish',
#    {1895, 5554, 6334, 6693},
#    'IRA',
#    {150,
#     325,
#     686,
#     874,
#     1332,
#     1843,
#     3401,
#     3660,
#     3869,
#     3959,
#     4164,
#     5324,
#     5473,
#     6038,
#     6190,
#     6461,
#     6733}),
#   ('Brian Hambleton', {2006}, 'Brian', {2545}),
#   ('Kieran Conway', {289}, 'Conway', {1231, 2322, 2857, 4764, 5738, 6044}),
#   ('McDade', {703, 3242, 3904}, 'bomber', {690, 2438}),
#   ('Birmingham Post & Mail', {1199}, 'Birmingham Mail', {4400}),
#   ('James McDade', {697, 3236}, 'McDade', {3904}),
#   ('Kieran Conway', {289}, 'head', {313}),
#   ('organisation',
#    {417},
#    'IRA',
#    {150,
#     325,
#     686,
#     874,
#     1332,
#     1843,
#     3401,
#     3660,
#     3869,
#     3959,
#     4164,
#     5324,
#     5473,
#     6038,
#     6190,
#     6461,
#     6733}),
#   ('James McDade', {697, 3236}, 'volunteer', {3253}),
#   ('lieutenant', {3915}, 'bomber', {690, 2438}),
#   ('Conway', {296, 1231, 2322, 2857, 4764, 5738, 6044}, 'head', {313}),
#   ('republican',
#    {5616, 5861, 6276},
#    'IRA',
#    {150,
#     325,
#     686,
#     874,
#     1332,
#     1843,
#     3401,
#     3660,
#     3869,
#     3959,
#     4164,
#     5324,
#     5473,
#     6038,
#     6190,
#     6461,
#     6733}),
#   ('Fighter', {6939}, 'Conway', {296, 1231, 2322, 2857, 4764, 5738, 6044}),
#   ('republican', {5616, 5861, 6276}, 'group', {234}),
#   ('British', {3186, 6322}, 'England', {1340, 3312, 4821}),
#   ('Irishmen', {1895}, 'bombers', {2438}),
#   ('volunteer', {3253}, 'McDade', {703, 3242, 3904}),
#   ('organisation', {417}, 'group', {234}),
#   ('Fighter', {6939}, 'head', {313}),
#   ('Birmingham',
#    {263, 1148, 1199, 1527, 2767, 3121, 3933, 4400, 5169, 5374},
#    'city',
#    {1598, 2082}),
#   ('James McDade', {697, 3236}, 'lieutenant', {3915}),
#   ('organisation', {417}, 'Irish', {1895, 5554, 6334, 6693}),
#   ('people', {3457}, '21', {1694, 2102, 3454, 4388, 4467})],
#  [('suspect', {1430, 1548}, 'man', {84, 520, 1030, 1309, 1518, 2333}),
#   ('Yamamoto', {316, 803}, 'man', {84, 520, 1030, 1309, 1518, 2333}),
#   ('Police', {791}, 'police', {61, 298, 1001, 1423}),
#   ('the unemployed man', {1015}, 'Yamamoto', {316, 803}),
#   ('Yasuo Yamamoto', {310}, 'man', {84, 520, 1030, 1309, 1518, 2333}),
#   ('Yamamoto', {316, 803}, 'suspect', {1430, 1548}),
#   ('Yasuo Yamamoto', {310}, 'Yamamoto', {803}),
#   ('Yasuo Yamamoto', {310}, 'suspect', {1430, 1548}),
#   ('the unemployed man', {1015}, 'man', {84, 520, 1309, 1518, 2333})],
#  [],
#  [('Syria',
#    {44,
#     179,
#     308,
#     490,
#     680,
#     1079,
#     1265,
#     1317,
#     1706,
#     1753,
#     1889,
#     2036,
#     2214,
#     2522,
#     2977},
#    'there',
#    {803, 2426, 2859}),
#   ('Badia', {1771, 1947, 1970, 2849}, 'spot', {1836}),
#   ('General', {387}, 'general', {33, 286, 1068, 1116}),
#   ('area', {2768, 2902, 3065}, 'spot', {1836}),
#   ('country',
#    {1418, 1569, 1803},
#    'Syrian',
#    {490, 1265, 1317, 1706, 1889, 2036, 2214, 2977}),
#   ('Badia', {1771, 1947, 1970, 2849}, 'zone', {3032}),
#   ('Syrian',
#    {490, 1265, 1317, 1706, 1889, 2036, 2214, 2977},
#    'there',
#    {803, 2426, 2859}),
#   ('Vyacheslav Gladkikh', {395}, 'general', {33, 286, 1068, 1116}),
#   ('Vyacheslav Gladkikh', {395}, 'General', {387}),
#   ('agency', {641}, 'Tass', {631}),
#   ('country', {1418, 1569, 1803}, 'there', {803, 2426, 2859}),
#   ('Syrian',
#    {490, 1265, 1317, 1706, 1889, 2036, 2214, 2977},
#    'Syria',
#    {44, 179, 308, 680, 1079, 1753, 2522}),
#   ('spot', {1836}, 'zone', {3032}),
#   ('Islamic State', {1193}, 'IS', {1508, 1844, 1933, 2352, 2475, 2885}),
#   ('area', {2768, 2902, 3065}, 'zone', {3032}),
#   ('country',
#    {1418, 1569, 1803},
#    'Syria',
#    {44,
#     179,
#     308,
#     490,
#     680,
#     1079,
#     1265,
#     1317,
#     1706,
#     1753,
#     1889,
#     2036,
#     2214,
#     2522,
#     2977})],
#  [('government',
#    {1119,
#     1589,
#     1935,
#     2262,
#     3033,
#     3133,
#     3204,
#     3479,
#     3573,
#     3760,
#     4028,
#     4328,
#     4640,
#     5376,
#     5941,
#     6564,
#     7995,
#     8300,
#     8790,
#     9402,
#     9954,
#     10485,
#     10532},
#    'state',
#    {2824, 4065, 5530, 5883, 10822, 10868}),
#   ('government',
#    {1119,
#     1589,
#     1935,
#     2262,
#     3033,
#     3133,
#     3204,
#     3479,
#     3573,
#     3760,
#     4028,
#     4328,
#     4640,
#     5376,
#     5941,
#     6564,
#     7995,
#     8300,
#     8790,
#     9402,
#     9954,
#     10485,
#     10532},
#    'employer',
#    {4054}),
#   ('Government', {0, 839}, 'employer', {4054}),
#   ('the government',
#    {1115, 2258, 3200, 3756, 4024, 4636, 5372, 5937, 8786, 9398, 9950, 10528},
#    'state',
#    {2824, 4065, 5530, 5883, 10822, 10868}),
#   ('the government',
#    {1115, 2258, 3200, 3756, 4024, 4636, 5372, 5937, 8786, 9398, 9950, 10528},
#    'Government',
#    {0, 839}),
#   ('Gabriela Ramírez', {8679}, 'Ramírez', {8903}),
#   ('the opposition',
#    {2081, 6036, 6624, 10226},
#    'opposition',
#    {1048, 2177, 3705, 9359, 9514, 9701, 9969, 10784}),
#   ('employer', {4054}, 'state', {2824, 4065, 5530, 5883, 10822, 10868}),
#   ('the government',
#    {1115, 2258, 3200, 3756, 4024, 4636, 5372, 5937, 8786, 9398, 9950, 10528},
#    'government',
#    {1589, 1935, 3033, 3133, 3479, 3573, 4328, 6564, 7995, 8300, 10485}),
#   ('Hugo Chávez', {2700}, 'Chávez', {7084, 8751, 8952, 9044}),
#   ('Government',
#    {0, 839},
#    'government',
#    {1119,
#     1589,
#     1935,
#     2262,
#     3033,
#     3133,
#     3204,
#     3479,
#     3573,
#     3760,
#     4028,
#     4328,
#     4640,
#     5376,
#     5941,
#     6564,
#     7995,
#     8300,
#     8790,
#     9402,
#     9954,
#     10485,
#     10532}),
#   ('Government', {0, 839}, 'state', {2824, 4065, 5530, 5883, 10822, 10868}),
#   ('the government',
#    {1115, 2258, 3200, 3756, 4024, 4636, 5372, 5937, 8786, 9398, 9950, 10528},
#    'employer',
#    {4054})],
#  [('Rue Victor Hugo', {183}, 'street', {176}),
#   ('Islamic State', {2430}, 'group', {2455}),
#   ('Police', {0, 691, 894, 2019}, 'police', {1184, 1979, 2148, 2951, 3104}),
#   ('Christophe Castaner', {2101}, 'Minister', {2092})],
#  [('region', {1394, 2261}, 'state', {3355}),
#   ('Dagestan',
#    {0, 76, 641, 1073, 1505, 1656, 1957, 2729, 2833, 2940, 3009, 3373, 3496},
#    'place',
#    {314, 1528, 2400}),
#   ('republic',
#    {380, 996, 1226, 1745, 1994, 2203, 3596, 3682},
#    'region',
#    {1394, 2261}),
#   ('Dagestan',
#    {0, 76, 641, 1073, 1505, 1656, 1957, 2729, 2833, 2940, 3009, 3373, 3496},
#    'land',
#    {109}),
#   ('Republic of Dagestan', {64}, 'state', {3355}),
#   ('Russian', {56, 884, 1686, 2014, 3543, 3648}, 'Moscow', {2473}),
#   ('Russian Federation', {2014}, 'Moscow', {2473}),
#   ('Dagestani',
#    {2833},
#    'republic',
#    {380, 996, 1226, 1745, 1994, 2203, 3596, 3682}),
#   ('Dagestani',
#    {2833},
#    'Dagestan',
#    {0, 76, 641, 1073, 1505, 1656, 1957, 2729, 2940, 3009, 3373, 3496}),
#   ('province', {1211}, 'region', {1394, 2261}),
#   ('place', {314, 1528, 2400}, 'land', {109}),
#   ('republic',
#    {380, 996, 1226, 1745, 1994, 2203, 3596, 3682},
#    'state',
#    {3355}),
#   ('Dagestan',
#    {0, 76, 641, 1073, 1505, 1656, 1957, 2729, 2833, 2940, 3009, 3373, 3496},
#    'region',
#    {1394, 2261}),
#   ('Moscow',
#    {2473},
#    'Russia',
#    {56, 150, 884, 1176, 1488, 1686, 2014, 2244, 3443, 3543, 3648}),
#   ('Republic of Dagestan',
#    {64},
#    'republic',
#    {380, 996, 1226, 1745, 1994, 2203, 3596, 3682}),
#   ('Republic of Dagestan',
#    {64},
#    'Dagestan',
#    {0, 641, 1073, 1505, 1656, 1957, 2729, 2833, 2940, 3009, 3373, 3496}),
#   ('Russian Federation',
#    {2014},
#    'Russia',
#    {56, 150, 884, 1176, 1488, 1686, 2244, 3443, 3543, 3648}),
#   ('Russian',
#    {56, 884, 1686, 2014, 3543, 3648},
#    'Russia',
#    {150, 1176, 1488, 2244, 3443}),
#   ('Dagestan',
#    {0, 76, 641, 1073, 1505, 1656, 1957, 2729, 2833, 2940, 3009, 3373, 3496},
#    'republic',
#    {380, 996, 1226, 1745, 1994, 2203, 3596, 3682}),
#   ('Republic of Dagestan', {64}, 'region', {1394, 2261}),
#   ('Russian Federation', {2014}, 'Russian', {56, 884, 1686, 3543, 3648}),
#   ('province',
#    {1211},
#    'republic',
#    {380, 996, 1226, 1745, 1994, 2203, 3596, 3682}),
#   ('Dagestani', {2833}, 'place', {314, 1528, 2400}),
#   ('Dagestan',
#    {0, 76, 641, 1073, 1505, 1656, 1957, 2729, 2833, 2940, 3009, 3373, 3496},
#    'state',
#    {3355}),
#   ('province', {1211}, 'state', {3355}),
#   ('Republic of Dagestan', {64}, 'land', {109}),
#   ('republic', {380, 996, 1226, 1745, 1994, 2203, 3596, 3682}, 'land', {109}),
#   ('Russian Federation', {2014}, 'Federal', {1791}),
#   ('Federal', {1791}, 'Russian', {56, 884, 1686, 2014, 3543, 3648}),
#   ('Republic of Dagestan', {64}, 'place', {314, 1528, 2400}),
#   ('Dagestan',
#    {0, 76, 641, 1073, 1505, 1656, 1957, 2729, 2833, 2940, 3009, 3373, 3496},
#    'province',
#    {1211}),
#   ('Federal',
#    {1791},
#    'Russia',
#    {56, 150, 884, 1176, 1488, 1686, 2014, 2244, 3443, 3543, 3648})],
#  [],
#  [('insurgents', {190}, 'gunmen', {41})],
#  [('Venezuelans', {101, 1653}, 'country', {267, 560}),
#   ('the government', {737, 955}, 'country', {267, 560}),
#   ('the government', {737, 955}, 'Venezuelans', {101, 1653})],
#  [('These people', {528, 1558}, 'people', {317, 805, 950})],
#  [('Alejandro Pérez', {716}, 'Brayan Oropeza', {734}),
#   ('Juan Requesens', {619, 987, 1156}, 'lawmaker', {610, 978}),
#   ('Yanin Pernía', {765}, 'Luis Guerra', {751})],
#  [('Tamerlan Tsarnaev', {1408}, 'brother', {1398}),
#   ('people', {512}, 'three', {358, 506, 2441}),
#   ('Tamerlan', {1408, 2391}, 'brother', {1398}),
#   ('Tamerlan Tsarnaev', {1408}, 'Tamerlan', {2391})],
#  [('militants', {2, 105, 274, 538, 709, 959}, 'Four', {533})],
#  [('William Craig', {4454}, 'Minister', {4528}),
#   ('Minister', {4528}, 'leader', {4470, 4930, 5264}),
#   ('Provisional IRA', {188, 329, 2058, 2357}, 'Provisionals', {3939}),
#   ('William Craig', {4454}, 'leader', {4470, 4930, 5264}),
#   ('Belfast',
#    {1169, 2334, 3173, 3871, 4079, 4918, 5544},
#    'city',
#    {389, 1492, 3623, 5324, 5884}),
#   ('station', {3000, 6149}, 'where', {4908, 6159}),
#   ('Lord Carrington', {118, 4038}, 'secretary', {106})],
#  [('suspect', {28, 727, 1137, 1559}, 'man', {623, 803, 1042, 1612, 1635}),
#   ('Christophe Castaner', {2018}, 'minister', {2007}),
#   ('Chérif Chekatt', {3028}, 'killer', {3019}),
#   ('Police', {1101, 1489, 2577}, 'police', {7, 997, 1804, 2194, 3058}),
#   ('Victor Hugo street', {880, 2173}, 'street', {161, 967}),
#   ('Lyon', {183, 764, 1911, 2062}, 'city', {175, 1782})],
#  [('country',
#    {2875},
#    'the',
#    {112,
#     293,
#     402,
#     450,
#     501,
#     824,
#     909,
#     1005,
#     1013,
#     1107,
#     1344,
#     1488,
#     1559,
#     1568,
#     1590,
#     1617,
#     1641,
#     1646,
#     1871,
#     1899,
#     1947,
#     2290,
#     2295,
#     2400,
#     2490,
#     2513,
#     2546,
#     2578,
#     2625,
#     2639,
#     2750,
#     2757,
#     2871,
#     2932,
#     3061,
#     3406,
#     3534,
#     3604,
#     3631,
#     3645,
#     3706,
#     3756,
#     3957,
#     4108,
#     4292,
#     4323,
#     4358,
#     4374,
#     4408}),
#   ('country', {2875}, 'UK', {237, 2754, 4378}),
#   ('British', {541, 853, 3206}, 'country', {2875}),
#   ('British', {541, 853, 3206}, 'UK', {237, 2754, 4378}),
#   ('aircraft', {9}, 'missiles', {2333}),
#   ('government',
#    {773, 1909},
#    'the',
#    {112,
#     293,
#     402,
#     450,
#     501,
#     824,
#     909,
#     1005,
#     1013,
#     1107,
#     1344,
#     1488,
#     1559,
#     1568,
#     1590,
#     1617,
#     1641,
#     1646,
#     1871,
#     1899,
#     1947,
#     2290,
#     2295,
#     2400,
#     2490,
#     2513,
#     2546,
#     2578,
#     2625,
#     2639,
#     2750,
#     2757,
#     2871,
#     2932,
#     3061,
#     3406,
#     3534,
#     3604,
#     3631,
#     3645,
#     3706,
#     3756,
#     3957,
#     4108,
#     4292,
#     4323,
#     4358,
#     4374,
#     4408}),
#   ('unmanned aerial vehicles', {145}, 'missiles', {2333}),
#   ('missiles', {2333}, 'UAVs', {172, 603, 2040}),
#   ('British',
#    {541, 853, 3206},
#    'the',
#    {112,
#     293,
#     402,
#     450,
#     501,
#     824,
#     909,
#     1005,
#     1013,
#     1107,
#     1344,
#     1488,
#     1559,
#     1568,
#     1590,
#     1617,
#     1641,
#     1646,
#     1871,
#     1899,
#     1947,
#     2290,
#     2295,
#     2400,
#     2490,
#     2513,
#     2546,
#     2578,
#     2625,
#     2639,
#     2750,
#     2757,
#     2871,
#     2932,
#     3061,
#     3406,
#     3534,
#     3604,
#     3631,
#     3645,
#     3706,
#     3756,
#     3957,
#     4108,
#     4292,
#     4323,
#     4358,
#     4374,
#     4408}),
#   ('the',
#    {112,
#     293,
#     402,
#     450,
#     501,
#     824,
#     909,
#     1005,
#     1013,
#     1107,
#     1344,
#     1488,
#     1559,
#     1568,
#     1590,
#     1617,
#     1641,
#     1646,
#     1871,
#     1899,
#     1947,
#     2290,
#     2295,
#     2400,
#     2490,
#     2513,
#     2546,
#     2578,
#     2625,
#     2639,
#     2750,
#     2757,
#     2871,
#     2932,
#     3061,
#     3406,
#     3534,
#     3604,
#     3631,
#     3645,
#     3706,
#     3756,
#     3957,
#     4108,
#     4292,
#     4323,
#     4358,
#     4374,
#     4408},
#    'UK',
#    {237, 2754, 4378}),
#   ('weaponised consumer drones',
#    {57},
#    'drones',
#    {513, 566, 1629, 1818, 2825, 3143, 3522, 3873, 4098, 4245, 4503}),
#   ('chemicals', {2114}, 'material', {2138}),
#   ('helicopter', {3272}, 'Chinook', {3264}),
#   ('unmanned aerial vehicles', {145}, 'aircraft', {9}),
#   ('unmanned aerial vehicles', {145}, 'UAVs', {172, 603, 2040}),
#   ('soil',
#    {549},
#    'the',
#    {112,
#     293,
#     402,
#     450,
#     501,
#     824,
#     909,
#     1005,
#     1013,
#     1107,
#     1344,
#     1488,
#     1559,
#     1568,
#     1590,
#     1617,
#     1641,
#     1646,
#     1871,
#     1899,
#     1947,
#     2290,
#     2295,
#     2400,
#     2490,
#     2513,
#     2546,
#     2578,
#     2625,
#     2639,
#     2750,
#     2757,
#     2871,
#     2932,
#     3061,
#     3406,
#     3534,
#     3604,
#     3631,
#     3645,
#     3706,
#     3756,
#     3957,
#     4108,
#     4292,
#     4323,
#     4358,
#     4374,
#     4408}),
#   ('government', {773, 1909}, 'British', {541, 853, 3206}),
#   ('government', {773, 1909}, 'UK', {237, 2754, 4378}),
#   ('aircraft', {9}, 'UAVs', {172, 603, 2040})],
#  [('members', {94, 133, 1231, 1985, 2233}, 'victims', {2132}),
#   ('Bagram Air Base', {1187}, 'Bagram', {25, 2061, 2651, 2682, 2713}),
#   ('Zabiullah Mujahid', {890}, 'spokesperson', {914}),
#   ('victims', {2132}, 'six', {77, 122, 1965}),
#   ('Ash Carter', {1346}, 'Secretary', {1325, 1866}),
#   ('Bagram Air Base', {1187}, 'Bagram Airfield', {2061, 2651, 2682, 2713}),
#   ('Bagram Airfield', {2061, 2651, 2682, 2713}, 'Bagram', {25, 1187}),
#   ('members', {94, 133, 1231, 1985, 2233}, 'six', {77, 122, 1965})],
#  [('victims', {1466, 1596}, 'people', {143, 369, 494, 850, 1839}),
#   ('victims', {1466, 1596}, 'workers', {1351}),
#   ('Sean MacStiofain', {2513, 3346}, 'leader', {2506, 3325}),
#   ('station', {1186, 1306}, 'bus', {1182, 1294, 1302, 1347}),
#   ('Oxford St', {1168, 1278}, 'bus', {1182, 1294, 1302, 1347}),
#   ('Oxford Street bus', {1168}, 'Oxford St', {1278}),
#   ('organisation',
#    {2544, 2976},
#    'IRA',
#    {257, 676, 2080, 2188, 2502, 2856, 3321}),
#   ('more', {399}, '130', {395, 1660}),
#   ('bombs', {307, 907, 1046, 1108}, 'car', {443, 1104, 2100}),
#   ('area', {2477, 3140, 3564}, 'part', {2732, 3175}),
#   ('Belfast', {265, 1265}, 'city', {324, 699, 1201, 1720, 3187, 3764}),
#   ('bombs', {307, 907, 1046, 1108}, 'Car', {1042}),
#   ('Bogside', {3132}, 'part', {2732, 3175}),
#   ('Derry', {2325, 3148}, 'city', {324, 699, 1201, 1720, 3187, 3764}),
#   ('Car', {1042}, 'car', {443, 1104, 2100}),
#   ('Oxford Street bus', {1168}, 'station', {1186, 1306}),
#   ('Oxford Street bus', {1168}, 'bus', {1294, 1302, 1347}),
#   ('workers', {1351}, 'people', {143, 369, 494, 850, 1839}),
#   ('Oxford St', {1168, 1278}, 'station', {1186, 1306})],
#  [('Aragua',
#    {55, 490, 1166, 1543, 1693, 2095},
#    's',
#    {15,
#     24,
#     53,
#     62,
#     86,
#     111,
#     119,
#     135,
#     140,
#     153,
#     163,
#     165,
#     222,
#     250,
#     252,
#     257,
#     273,
#     300,
#     312,
#     333,
#     361,
#     375,
#     382,
#     397,
#     407,
#     423,
#     437,
#     438,
#     455,
#     480,
#     568,
#     571,
#     579,
#     589,
#     612,
#     664,
#     699,
#     707,
#     714,
#     743,
#     747,
#     780,
#     799,
#     800,
#     818,
#     832,
#     860,
#     898,
#     901,
#     923,
#     934,
#     940,
#     1001,
#     1034,
#     1042,
#     1132,
#     1135,
#     1180,
#     1184,
#     1191,
#     1199,
#     1229,
#     1258,
#     1272,
#     1279,
#     1349,
#     1350,
#     1355,
#     1374,
#     1412,
#     1422,
#     1431,
#     1457,
#     1459,
#     1486,
#     1499,
#     1517,
#     1529,
#     1536,
#     1552,
#     1583,
#     1618,
#     1635,
#     1641,
#     1650,
#     1662,
#     1687,
#     1702,
#     1742,
#     1767,
#     1769,
#     1810,
#     1868,
#     1893,
#     1897,
#     1904,
#     1914,
#     1919,
#     1922,
#     1947,
#     1986,
#     2002,
#     2024,
#     2029,
#     2040,
#     2054,
#     2072,
#     2111,
#     2112,
#     2117,
#     2186,
#     2202}),
#   ('Aragua', {55, 490, 1166, 1543, 1693, 2095}, 'state', {62, 111, 1191}),
#   ('Central Hospital of Maracay', {263}, 'hospital', {395}),
#   ('the Maracay Central Hospital', {1464}, 'hospital', {395}),
#   ('the Maracay Central Hospital',
#    {1464},
#    'Central Hospital of Maracay',
#    {263})],
#  [('Eliseo Bayo', {3098}, 'actress', {3051}),
#   ('Antonio Durán', {2971}, 'worker', {2964}),
#   ('group', {293, 1838, 2360}, 'ETA', {299, 1590, 2301, 2756, 3858}),
#   ('Rolando Cafe', {326, 1050, 2629}, 'Rolando', {14, 72, 3429, 3641}),
#   ('Two', {1247}, 'two', {801, 974, 1375}),
#   ('Eliseo Bayo', {3098}, 'writer', {3091}),
#   ('Vicente Sainz de la Peña', {2924}, 'director', {2915}),
#   ('Carlos Arias Navarro', {2136}, 'Minister', {2127}),
#   ('Rolando Cafe', {326, 1050, 2629}, 'building', {616, 885, 2663}),
#   ('Vicente Sainz de la Peña', {2924}, 'worker', {2964}),
#   ('Bernardo Badell', {2993}, 'pilot', {2987}),
#   ('organisation', {1883}, 'ETA', {299, 1590, 2301, 2756, 3858}),
#   ('Rolando', {14, 72, 326, 1050, 2629, 3429, 3641}, 'cafe', {80, 1463, 1773}),
#   ('Rolando cafe', {72}, 'cafe', {1463, 1773}),
#   ('Rolando Cafe', {326, 1050, 2629}, 'cafe', {80, 1463, 1773}),
#   ('Antonio Durán', {2971}, 'director', {2915}),
#   ('Rolando cafe', {72}, 'building', {616, 885, 2663}),
#   ('building',
#    {616, 885, 2663},
#    'Rolando',
#    {14, 72, 326, 1050, 2629, 3429, 3641}),
#   ('people', {138, 709}, '12', {1258}),
#   ('customers', {1446}, 'employees', {1432}),
#   ('Forest', {2790, 3219, 3385, 3590, 3618}, 'wife', {2799, 3017}),
#   ('María Paz Ballesteros', {3059}, 'writer', {3091}),
#   ('organisation', {1883}, 'group', {293, 1838, 2360}),
#   ('María del Carmen Nadal', {3022}, 'wife', {2799, 3017}),
#   ('building', {616, 885, 2663}, 'cafe', {80, 1463, 1773}),
#   ('Vicente Sainz de la Peña', {2924}, 'Antonio Durán', {2971}),
#   ('María Paz Ballesteros', {3059}, 'actress', {3051}),
#   ('Eva Forest', {2786, 3215, 3586}, 'wife', {2799, 3017}),
#   ('María Paz Ballesteros', {3059}, 'Eliseo Bayo', {3098}),
#   ('Eva Forest', {2786, 3215, 3586}, 'Forest', {3385, 3618})],
#  [('Tazhayakov', {203, 400, 602}, 'Friend', {15}),
#   ('student', {226}, 'friend', {72, 431, 581}),
#   ('Tazhayakov', {203, 400, 602}, 'friend', {72, 431, 581}),
#   ('Azamat Tazhayakov', {196}, 'friend', {72, 431, 581}),
#   ('student', {226}, 'Friend', {15}),
#   ('Azamat Tazhayakov', {196}, 'friends', {581}),
#   ('Tazhayakov', {203, 400, 602}, 'friends', {581}),
#   ('Azamat Tazhayakov', {196}, 'Tazhayakov', {400, 602}),
#   ('friends', {581}, 'Friend', {15}),
#   ('friends', {581}, 'friend', {72, 431}),
#   ('Azamat Tazhayakov', {196}, 'student', {226}),
#   ('Friend', {15}, 'friend', {72, 431, 581})],
#  [('McVeigh',
#    {95,
#     341,
#     530,
#     883,
#     1011,
#     1391,
#     1749,
#     1825,
#     2088,
#     2425,
#     2544,
#     2811,
#     3150,
#     3520},
#    'man',
#    {126, 3370}),
#   ('Yuhua Bai', {2854}, 'owner', {4, 275, 2866}),
#   ('caller', {3028}, 'Kling', {561, 2723, 3055}),
#   ('Scott Mendeloff', {793}, 'prosecutor', {782, 1182, 1441, 2835}),
#   ('Ryder',
#    {145, 508, 1513, 2042},
#    'truck',
#    {29, 151, 414, 514, 1519, 2048, 2201, 2318, 2472, 2666}),
#   ('Elliott',
#    {265, 284, 820, 895, 935, 1120, 1541, 2001, 2388, 2526, 2778},
#    'owner',
#    {4, 275, 2866}),
#   ('Eldon Elliott', {259}, 'owner', {4, 275, 2866}),
#   ('Scott Mendeloff', {793}, 'Mendeloff', {855}),
#   ('Junction City', {52, 1471, 1844, 2893}, 'where', {1872, 1985}),
#   ('Timothy McVeigh',
#    {87, 875},
#    'McVeigh',
#    {341, 530, 1011, 1391, 1749, 1825, 2088, 2425, 2544, 2811, 3150, 3520}),
#   ('Prosecutors', {1807, 2172, 3327}, 'prosecutors', {1182, 1441, 2835}),
#   ('Timothy McVeigh', {87, 875}, 'man', {126, 3370}),
#   ('depot', {1979}, 'where', {1872, 1985}),
#   ('jurors', {622, 3509}, 'jury', {3223}),
#   ('Ryder truck',
#    {145, 508, 1513, 2042},
#    'truck',
#    {29, 414, 2201, 2318, 2472, 2666}),
#   ('Eldon Elliott',
#    {259},
#    'Elliott',
#    {284, 820, 895, 935, 1120, 1541, 2001, 2388, 2526, 2778}),
#   ('Geary Lake', {2210}, 'there', {724, 988, 2324}),
#   ('Robert Kling', {554, 2716}, 'Kling', {3055}),
#   ('prosecutor', {782, 1182, 1441, 2835}, 'Mendeloff', {799, 855}),
#   ('Murrah Federal Building', {1584}, 'building', {206})],
#  [],
#  [('Duffield',
#    {301, 518, 988, 1619, 1806, 2207, 3067},
#    'driver',
#    {73, 674, 735, 789, 2404}),
#   ('Terry Duffield', {295}, 'driver', {73, 674, 735, 789, 2404}),
#   ('Terry Duffield', {295}, 'client', {2315}),
#   ('Duffield', {301, 518, 988, 1619, 1806, 2207, 3067}, 'client', {2315}),
#   ('client', {2315}, 'driver', {73, 674, 735, 789, 2404})],
#  [('Naser Jason Abdo', {207}, 'defendant', {825, 1942}),
#   ('defendant', {825, 1942}, 'Abdo', {219, 434, 768, 1196, 1378}),
#   ('Naser Jason Abdo', {207}, 'soldier', {845, 1352}),
#   ('soldier', {845, 1352}, 'Abdo', {219, 434, 768, 1196, 1378}),
#   ('defendant', {825, 1942}, 'soldier', {845, 1352}),
#   ('Naser Jason Abdo', {207}, 'Abdo', {434, 768, 1196, 1378})],
#  [('Saddam Hussein', {131, 1257, 3659}, 'Hussein', {3292}),
#   ('Timothy McVeigh', {2197}, 'bomber', {2190}),
#   ('Saddam Hussein',
#    {131, 1257, 3659},
#    'Saddam',
#    {427, 570, 1187, 2068, 3006, 4175, 4503}),
#   ('Hussein',
#    {138, 1264, 3292, 3666},
#    'Saddam',
#    {131, 427, 570, 1187, 1257, 2068, 3006, 3659, 4175, 4503}),
#   ('Timothy McVeigh', {2197}, 'McVeigh', {2329}),
#   ('McVeigh', {2205, 2329}, 'bomber', {2190})],
#  [('center', {781}, 'where', {747})],
#  [('the government', {1641, 2741, 4135}, 'Venezuela', {0, 965, 1059, 2327}),
#   ('the government',
#    {1641, 2741, 4135},
#    'nation',
#    {101, 408, 808, 1523, 2862, 3845}),
#   ('the government', {1641, 2741, 4135}, 'country', {684, 2727, 3074}),
#   ('nation',
#    {101, 408, 808, 1523, 2862, 3845},
#    's',
#    {12,
#     17,
#     32,
#     45,
#     47,
#     92,
#     95,
#     96,
#     98,
#     99,
#     151,
#     160,
#     179,
#     183,
#     196,
#     205,
#     223,
#     225,
#     264,
#     350,
#     385,
#     436,
#     443,
#     475,
#     501,
#     507,
#     533,
#     566,
#     581,
#     585,
#     632,
#     633,
#     635,
#     636,
#     639,
#     681,
#     693,
#     773,
#     784,
#     795,
#     877,
#     879,
#     889,
#     902,
#     911,
#     914,
#     920,
#     931,
#     937,
#     944,
#     977,
#     999,
#     1010,
#     1015,
#     1020,
#     1045,
#     1070,
#     1074,
#     1108,
#     1117,
#     1131,
#     1144,
#     1170,
#     1175,
#     1205,
#     1254,
#     1267,
#     1286,
#     1299,
#     1301,
#     1319,
#     1364,
#     1369,
#     1374,
#     1399,
#     1437,
#     1464,
#     1475,
#     1487,
#     1491,
#     1517,
#     1518,
#     1520,
#     1521,
#     1575,
#     1584,
#     1588,
#     1593,
#     1633,
#     1659,
#     1686,
#     1711,
#     1741,
#     1745,
#     1777,
#     1793,
#     1814,
#     1823,
#     1849,
#     1885,
#     1887,
#     1908,
#     1929,
#     1947,
#     1956,
#     1989,
#     2015,
#     2053,
#     2060,
#     2066,
#     2096,
#     2102,
#     2108,
#     2122,
#     2129,
#     2148,
#     2153,
#     2181,
#     2190,
#     2234,
#     2246,
#     2252,
#     2274,
#     2293,
#     2342,
#     2361,
#     2375,
#     2429,
#     2438,
#     2478,
#     2489,
#     2501,
#     2515,
#     2524,
#     2533,
#     2553,
#     2555,
#     2557,
#     2559,
#     2572,
#     2581,
#     2631,
#     2637,
#     2643,
#     2645,
#     2652,
#     2666,
#     2684,
#     2688,
#     2698,
#     2702,
#     2758,
#     2768,
#     2788,
#     2797,
#     2822,
#     2845,
#     2856,
#     2857,
#     2859,
#     2860,
#     2882,
#     2888,
#     2906,
#     2913,
#     2922,
#     2948,
#     2952,
#     2971,
#     2985,
#     2996,
#     3025,
#     3027,
#     3105,
#     3113,
#     3131,
#     3137,
#     3141,
#     3150,
#     3162,
#     3184,
#     3199,
#     3243,
#     3269,
#     3291,
#     3292,
#     3304,
#     3305,
#     3328,
#     3344,
#     3355,
#     3367,
#     3415,
#     3417,
#     3448,
#     3459,
#     3475,
#     3502,
#     3510,
#     3550,
#     3604,
#     3627,
#     3674,
#     3696,
#     3700,
#     3776,
#     3781,
#     3811,
#     3835,
#     3919,
#     3941,
#     3953,
#     3969,
#     3995,
#     4016,
#     4060,
#     4073,
#     4091,
#     4110,
#     4165}),
#   ('the government', {1641, 2741, 4135}, 'government', {2459, 3120}),
#   ('Venezuela',
#    {0, 965, 1059, 2327},
#    's',
#    {12,
#     17,
#     32,
#     45,
#     47,
#     92,
#     95,
#     96,
#     98,
#     99,
#     151,
#     160,
#     179,
#     183,
#     196,
#     205,
#     223,
#     225,
#     264,
#     350,
#     385,
#     436,
#     443,
#     475,
#     501,
#     507,
#     533,
#     566,
#     581,
#     585,
#     632,
#     633,
#     635,
#     636,
#     639,
#     681,
#     693,
#     773,
#     784,
#     795,
#     877,
#     879,
#     889,
#     902,
#     911,
#     914,
#     920,
#     931,
#     937,
#     944,
#     977,
#     999,
#     1010,
#     1015,
#     1020,
#     1045,
#     1070,
#     1074,
#     1108,
#     1117,
#     1131,
#     1144,
#     1170,
#     1175,
#     1205,
#     1254,
#     1267,
#     1286,
#     1299,
#     1301,
#     1319,
#     1364,
#     1369,
#     1374,
#     1399,
#     1437,
#     1464,
#     1475,
#     1487,
#     1491,
#     1517,
#     1518,
#     1520,
#     1521,
#     1575,
#     1584,
#     1588,
#     1593,
#     1633,
#     1659,
#     1686,
#     1711,
#     1741,
#     1745,
#     1777,
#     1793,
#     1814,
#     1823,
#     1849,
#     1885,
#     1887,
#     1908,
#     1929,
#     1947,
#     1956,
#     1989,
#     2015,
#     2053,
#     2060,
#     2066,
#     2096,
#     2102,
#     2108,
#     2122,
#     2129,
#     2148,
#     2153,
#     2181,
#     2190,
#     2234,
#     2246,
#     2252,
#     2274,
#     2293,
#     2342,
#     2361,
#     2375,
#     2429,
#     2438,
#     2478,
#     2489,
#     2501,
#     2515,
#     2524,
#     2533,
#     2553,
#     2555,
#     2557,
#     2559,
#     2572,
#     2581,
#     2631,
#     2637,
#     2643,
#     2645,
#     2652,
#     2666,
#     2684,
#     2688,
#     2698,
#     2702,
#     2758,
#     2768,
#     2788,
#     2797,
#     2822,
#     2845,
#     2856,
#     2857,
#     2859,
#     2860,
#     2882,
#     2888,
#     2906,
#     2913,
#     2922,
#     2948,
#     2952,
#     2971,
#     2985,
#     2996,
#     3025,
#     3027,
#     3105,
#     3113,
#     3131,
#     3137,
#     3141,
#     3150,
#     3162,
#     3184,
#     3199,
#     3243,
#     3269,
#     3291,
#     3292,
#     3304,
#     3305,
#     3328,
#     3344,
#     3355,
#     3367,
#     3415,
#     3417,
#     3448,
#     3459,
#     3475,
#     3502,
#     3510,
#     3550,
#     3604,
#     3627,
#     3674,
#     3696,
#     3700,
#     3776,
#     3781,
#     3811,
#     3835,
#     3919,
#     3941,
#     3953,
#     3969,
#     3995,
#     4016,
#     4060,
#     4073,
#     4091,
#     4110,
#     4165}),
#   ('apartment', {3384, 3524}, 'building', {2470, 3534}),
#   ('country', {684, 2727, 3074}, 'nation', {101, 408, 808, 1523, 2862, 3845}),
#   ('the government', {1641, 2741, 4135}, 'where', {1857, 2735, 3082, 3557}),
#   ('government',
#    {1645, 2459, 2745, 3120, 4139},
#    'nation',
#    {101, 408, 808, 1523, 2862, 3845}),
#   ('government',
#    {1645, 2459, 2745, 3120, 4139},
#    's',
#    {12,
#     17,
#     32,
#     45,
#     47,
#     92,
#     95,
#     96,
#     98,
#     99,
#     151,
#     160,
#     179,
#     183,
#     196,
#     205,
#     223,
#     225,
#     264,
#     350,
#     385,
#     436,
#     443,
#     475,
#     501,
#     507,
#     533,
#     566,
#     581,
#     585,
#     632,
#     633,
#     635,
#     636,
#     639,
#     681,
#     693,
#     773,
#     784,
#     795,
#     877,
#     879,
#     889,
#     902,
#     911,
#     914,
#     920,
#     931,
#     937,
#     944,
#     977,
#     999,
#     1010,
#     1015,
#     1020,
#     1045,
#     1070,
#     1074,
#     1108,
#     1117,
#     1131,
#     1144,
#     1170,
#     1175,
#     1205,
#     1254,
#     1267,
#     1286,
#     1299,
#     1301,
#     1319,
#     1364,
#     1369,
#     1374,
#     1399,
#     1437,
#     1464,
#     1475,
#     1487,
#     1491,
#     1517,
#     1518,
#     1520,
#     1521,
#     1575,
#     1584,
#     1588,
#     1593,
#     1633,
#     1659,
#     1686,
#     1711,
#     1741,
#     1745,
#     1777,
#     1793,
#     1814,
#     1823,
#     1849,
#     1885,
#     1887,
#     1908,
#     1929,
#     1947,
#     1956,
#     1989,
#     2015,
#     2053,
#     2060,
#     2066,
#     2096,
#     2102,
#     2108,
#     2122,
#     2129,
#     2148,
#     2153,
#     2181,
#     2190,
#     2234,
#     2246,
#     2252,
#     2274,
#     2293,
#     2342,
#     2361,
#     2375,
#     2429,
#     2438,
#     2478,
#     2489,
#     2501,
#     2515,
#     2524,
#     2533,
#     2553,
#     2555,
#     2557,
#     2559,
#     2572,
#     2581,
#     2631,
#     2637,
#     2643,
#     2645,
#     2652,
#     2666,
#     2684,
#     2688,
#     2698,
#     2702,
#     2758,
#     2768,
#     2788,
#     2797,
#     2822,
#     2845,
#     2856,
#     2857,
#     2859,
#     2860,
#     2882,
#     2888,
#     2906,
#     2913,
#     2922,
#     2948,
#     2952,
#     2971,
#     2985,
#     2996,
#     3025,
#     3027,
#     3105,
#     3113,
#     3131,
#     3137,
#     3141,
#     3150,
#     3162,
#     3184,
#     3199,
#     3243,
#     3269,
#     3291,
#     3292,
# ...
#     7588,
#     7871,
#     9840,
#     10494,
#     10599,
#     10870,
#     12715,
#     14266,
#     15040,
#     15157,
#     15819,
#     16098,
#     17408,
#     17550,
#     17695,
#     18287,
#     18967,
#     19097,
#     22476,
#     23078,
#     23240,
#     24810,
#     25757,
#     26318},
#    'enemy',
#    {5293, 16121}),
#   ('United States',
#    {61,
#     1203,
#     1560,
#     2069,
#     4362,
#     4861,
#     5246,
#     5659,
#     5883,
#     6689,
#     7588,
#     7871,
#     9840,
#     10494,
#     10599,
#     10870,
#     12715,
#     14266,
#     15040,
#     15157,
#     15819,
#     16098,
#     17408,
#     17550,
#     17695,
#     18287,
#     18967,
#     19097,
#     22476,
#     23078,
#     23240,
#     24810,
#     25757,
#     26318},
#    'here',
#    {165,
#     1299,
#     1436,
#     4353,
#     4753,
#     4944,
#     17635,
#     17889,
#     21913,
#     22420,
#     24326,
#     24332,
#     26243,
#     26268}),
#   ('government',
#    {923,
#     1039,
#     4407,
#     4620,
#     4800,
#     7552,
#     7767,
#     9615,
#     11273,
#     11707,
#     13485,
#     13651,
#     14709,
#     14962,
#     15722,
#     15777,
#     17228,
#     19950,
#     21165,
#     24934,
#     25608,
#     26077},
#    'American',
#    {614, 978, 7432, 19435, 20780, 26434}),
#   ('American', {614, 978, 7432, 19435, 20780, 26434}, 'itself', {25878}),
#   ('United States',
#    {61,
#     1203,
#     1560,
#     2069,
#     4362,
#     4861,
#     5246,
#     5659,
#     5883,
#     6689,
#     7588,
#     7871,
#     9840,
#     10494,
#     10599,
#     10870,
#     12715,
#     14266,
#     15040,
#     15157,
#     15819,
#     16098,
#     17408,
#     17550,
#     17695,
#     18287,
#     18967,
#     19097,
#     22476,
#     23078,
#     23240,
#     24810,
#     25757,
#     26318},
#    'Washington',
#    {1580,
#     1909,
#     7378,
#     20984,
#     21936,
#     22566,
#     23016,
#     23311,
#     23497,
#     24553,
#     24888,
#     25828,
#     26356}),
#   ('Tomahawks', {12735}, 'missile', {12627, 17517}),
#   ('Pakistan',
#    {504,
#     1281,
#     2428,
#     2707,
#     4469,
#     4775,
#     6718,
#     9001,
#     9024,
#     10446,
#     10514,
#     10808,
#     11161,
#     11560,
#     11697,
#     11760,
#     12309,
#     13553,
#     13745,
#     13885,
#     13977,
#     14647,
#     14818,
#     15095,
#     15130,
#     15193,
#     15326,
#     15451,
#     15601,
#     15887,
#     15973,
#     16076,
#     16841,
#     16970,
#     17366,
#     23190,
#     23294},
#    'country',
#    {14150, 15522, 16947}),
#   ('government',
#    {923,
#     1039,
#     4407,
#     4620,
#     4800,
#     7552,
#     7767,
#     9615,
#     11273,
#     11707,
#     13485,
#     13651,
#     14709,
#     14962,
#     15722,
#     15777,
#     17228,
#     19950,
#     21165,
#     24934,
#     25608,
#     26077},
#    'here',
#    {165,
#     1299,
#     1436,
#     4353,
#     4753,
#     4944,
#     17635,
#     17889,
#     21913,
#     22420,
#     24326,
#     24332,
#     26243,
#     26268}),
#   ('citizen', {17819, 19271, 20653, 20862}, 'piper', {18048}),
#   ('drones',
#    {89,
#     398,
#     560,
#     861,
#     1310,
#     2182,
#     2334,
#     2920,
#     3243,
#     6256,
#     6399,
#     6608,
#     8417,
#     8504,
#     8632,
#     9259,
#     12088,
#     12935,
#     13328,
#     13425,
#     14499,
#     15698,
#     16513,
#     16603,
#     16876,
#     20967,
#     21495,
#     21596,
#     22057,
#     22153,
#     22441,
#     22940,
#     24316,
#     24745,
#     25030,
#     25153,
#     26235,
#     26344},
#    'drone',
#    {220,
#     1133,
#     1419,
#     1620,
#     1785,
#     1893,
#     2036,
#     2666,
#     3639,
#     3876,
#     5173,
#     5972,
#     6951,
#     8022,
#     8311,
#     8814,
#     9112,
#     9346,
#     9498,
#     9687,
#     11215,
#     12386,
#     12979,
#     13182,
#     13607,
#     13791,
#     13933,
#     14129,
#     14398,
#     14684,
#     15215,
#     15379,
#     16023,
#     16167,
#     16256,
#     16347,
#     16634,
#     16741,
#     17125,
#     17285,
#     17467,
#     17669,
#     17864,
#     18768,
#     20623,
#     20908,
#     21766,
#     22340,
#     22767,
#     24673,
#     25546}),
#   ('government',
#    {923,
#     1039,
#     4407,
#     4620,
#     4800,
#     7552,
#     7767,
#     9615,
#     11273,
#     11707,
#     13485,
#     13651,
#     14709,
#     14962,
#     15722,
#     15777,
#     17228,
#     19950,
#     21165,
#     24934,
#     25608,
#     26077},
#    'Pakistani',
#    {6718,
#     9001,
#     10808,
#     11560,
#     11697,
#     15095,
#     15973,
#     16076,
#     16841,
#     16970,
#     17366,
#     23294}),
#   ('Yemeni',
#    {6732, 12893, 14238, 16985},
#    'Yemen',
#    {515,
#     2441,
#     4480,
#     4788,
#     7695,
#     12787,
#     13566,
#     14057,
#     14422,
#     14660,
#     16199,
#     17880}),
#   ('government',
#    {923,
#     1039,
#     4407,
#     4620,
#     4800,
#     7552,
#     7767,
#     9615,
#     11273,
#     11707,
#     13485,
#     13651,
#     14709,
#     14962,
#     15722,
#     15777,
#     17228,
#     19950,
#     21165,
#     24934,
#     25608,
#     26077},
#    'country',
#    {14150, 15522, 16947}),
#   ('Washington',
#    {1580,
#     1909,
#     7378,
#     20984,
#     21936,
#     22566,
#     23016,
#     23311,
#     23497,
#     24553,
#     24888,
#     25828,
#     26356},
#    'government',
#    {923,
#     1039,
#     4407,
#     4620,
#     4800,
#     7552,
#     7767,
#     9615,
#     11273,
#     11707,
#     13485,
#     13651,
#     14709,
#     14962,
#     15722,
#     15777,
#     17228,
#     19950,
#     21165,
#     24934,
#     25608,
#     26077}),
#   ('Pakistani',
#    {6718,
#     9001,
#     10808,
#     11560,
#     11697,
#     15095,
#     15973,
#     16076,
#     16841,
#     16970,
#     17366,
#     23294},
#    'country',
#    {14150, 15522, 16947}),
#   ('country',
#    {14150, 15522, 16947},
#    'Yemen',
#    {515,
#     2441,
#     4480,
#     4788,
#     6732,
#     7695,
#     12787,
#     12893,
#     13566,
#     14057,
#     14238,
#     14422,
#     14660,
#     16199,
#     16985,
#     17880}),
#   ('United States',
#    {61,
#     1203,
#     1560,
#     2069,
#     4362,
#     4861,
#     5246,
#     5659,
#     5883,
#     6689,
#     7588,
#     7871,
#     9840,
#     10494,
#     10599,
#     10870,
#     12715,
#     14266,
#     15040,
#     15157,
#     15819,
#     16098,
#     17408,
#     17550,
#     17695,
#     18287,
#     18967,
#     19097,
#     22476,
#     23078,
#     23240,
#     24810,
#     25757,
#     26318},
#    'American',
#    {614, 978, 7432, 19435, 20780, 26434}),
#   ('Yemenis',
#    {16985},
#    'Yemen',
#    {515,
#     2441,
#     4480,
#     4788,
#     6732,
#     7695,
#     12787,
#     12893,
#     13566,
#     14057,
#     14238,
#     14422,
#     14660,
#     16199,
#     17880}),
#   ('Awlaki',
#    {17800, 17914, 18010, 18237, 19004, 19373, 20835},
#    'piper',
#    {18048}),
#   ('United States',
#    {61,
#     1203,
#     1560,
#     2069,
#     4362,
#     4861,
#     5246,
#     5659,
#     5883,
#     6689,
#     7588,
#     7871,
#     9840,
#     10494,
#     10599,
#     10870,
#     12715,
#     14266,
#     15040,
#     15157,
#     15819,
#     16098,
#     17408,
#     17550,
#     17695,
#     18287,
#     18967,
#     19097,
#     22476,
#     23078,
#     23240,
#     24810,
#     25757,
#     26318},
#    'government',
#    {923,
#     1039,
#     4407,
#     4620,
#     4800,
#     7552,
#     7767,
#     9615,
#     11273,
#     11707,
#     13485,
#     13651,
#     14709,
#     14962,
#     15722,
#     15777,
#     17228,
#     19950,
#     21165,
#     24934,
#     25608,
#     26077}),
#   ('American', {614, 978, 7432, 19435, 20780, 26434}, 'enemy', {5293, 16121}),
#   ('United States',
#    {61,
#     1203,
#     1560,
#     2069,
#     4362,
#     4861,
#     5246,
#     5659,
#     5883,
#     6689,
#     7588,
#     7871,
#     9840,
#     10494,
#     10599,
#     10870,
#     12715,
#     14266,
#     15040,
#     15157,
#     15819,
#     16098,
#     17408,
#     17550,
#     17695,
#     18287,
#     18967,
#     19097,
#     22476,
#     23078,
#     23240,
#     24810,
#     25757,
#     26318},
#    'people',
#    {7609, 12807, 19444, 19555}),
#   ('Washington',
#    {1580,
#     1909,
#     7378,
#     20984,
#     21936,
#     22566,
#     23016,
#     23311,
#     23497,
#     24553,
#     24888,
#     25828,
#     26356},
#    'enemy',
#    {5293, 16121}),
#   ('Baitullah Mehsud',
#    {10833},
#    'leader',
#    {458,
#     2485,
#     2748,
#     2807,
#     2856,
#     3830,
#     3855,
#     10826,
#     11001,
#     14900,
#     20739,
#     21328,
#     26682}),
#   ('government',
#    {923,
#     1039,
#     4407,
#     4620,
#     4800,
#     7552,
#     7767,
#     9615,
#     11273,
#     11707,
#     13485,
#     13651,
#     14709,
#     14962,
#     15722,
#     15777,
#     17228,
#     19950,
#     21165,
#     24934,
#     25608,
#     26077},
#    'own',
#    {3007, 4928, 6667, 6772, 7548, 10987, 15571, 17224, 18669, 21511, 22971}),
#   ('country',
#    {14150, 15522, 16947},
#    'own',
#    {3007, 4928, 6667, 6772, 7548, 10987, 15571, 17224, 18669, 21511, 22971}),
#   ('Pakistani',
#    {6718,
#     9001,
#     10808,
#     11560,
#     11697,
#     15095,
#     15973,
#     16076,
#     16841,
#     16970,
#     17366,
#     23294},
#    'own',
#    {3007, 4928, 6667, 6772, 7548, 10987, 15571, 17224, 18669, 21511, 22971}),
#   ('Washington',
#    {1580,
#     1909,
#     7378,
#     20984,
#     21936,
#     22566,
#     23016,
#     23311,
#     23497,
#     24553,
#     24888,
#     25828,
#     26356},
#    'itself',
#    {25878}),
#   ('government',
#    {923,
#     1039,
#     4407,
#     4620,
#     4800,
#     7552,
#     7767,
#     9615,
#     11273,
#     11707,
#     13485,
#     13651,
#     14709,
#     14962,
#     15722,
#     15777,
#     17228,
#     19950,
#     21165,
#     24934,
#     25608,
#     26077},
#    'Pakistan',
#    {504,
#     1281,
#     2428,
#     2707,
#     4469,
#     4775,
#     6718,
#     9001,
#     9024,
#     10446,
#     10514,
#     10808,
#     11161,
#     11560,
#     11697,
#     11760,
#     12309,
#     13553,
#     13745,
#     13885,
#     13977,
#     14647,
#     14818,
#     15095,
#     15130,
#     15193,
#     15326,
#     15451,
#     15601,
#     15887,
#     15973,
#     16076,
#     16841,
#     16970,
#     17366,
#     23190,
#     23294}),
#   ('Washington',
#    {1580,
#     1909,
#     7378,
#     20984,
#     21936,
#     22566,
#     23016,
#     23311,
#     23497,
#     24553,
#     24888,
#     25828,
#     26356},
#    'American',
#    {614, 978, 7432, 19435, 20780, 26434}),
#   ('country', {14150, 15522, 16947}, 'Yemeni', {6732, 12893, 14238, 16985}),
#   ('United States',
#    {61,
#     1203,
#     1560,
#     2069,
#     4362,
#     4861,
#     5246,
#     5659,
#     5883,
#     6689,
#     7588,
#     7871,
#     9840,
#     10494,
#     10599,
#     10870,
#     12715,
#     14266,
#     15040,
#     15157,
#     15819,
#     16098,
#     17408,
#     17550,
#     17695,
#     18287,
#     18967,
#     19097,
#     22476,
#     23078,
#     23240,
#     24810,
#     25757,
#     26318},
#    'itself',
#    {25878}),
#   ('Pakistan',
#    {504,
#     1281,
#     2428,
#     2707,
#     4469,
#     4775,
#     6718,
#     9001,
#     9024,
#     10446,
#     10514,
#     10808,
#     11161,
#     11560,
#     11697,
#     11760,
#     12309,
#     13553,
#     13745,
#     13885,
#     13977,
#     14647,
#     14818,
#     15095,
#     15130,
#     15193,
#     15326,
#     15451,
#     15601,
#     15887,
#     15973,
#     16076,
#     16841,
#     16970,
#     17366,
#     23190,
#     23294},
#    'own',
#    {3007, 4928, 6667, 6772, 7548, 10987, 15571, 17224, 18669, 21511, 22971}),
#   ('citizen',
#    {17819, 19271, 20653, 20862},
#    'Awlaki',
#    {17800, 17914, 18010, 18237, 19004, 19373, 20835}),
#   ('American',
#    {614, 978, 7432, 19435, 20780, 26434},
#    'here',
#    {165,
#     1299,
#     1436,
#     4353,
#     4753,
#     4944,
#     17635,
#     17889,
#     21913,
#     22420,
#     24326,
#     24332,
#     26243,
#     26268}),
#   ('Yemenis', {16985}, 'Yemeni', {6732, 12893, 14238}),
#   ('Washington',
#    {1580,
#     1909,
#     7378,
#     20984,
#     21936,
#     22566,
#     23016,
#     23311,
#     23497,
#     24553,
#     24888,
#     25828,
#     26356},
#    'here',
#    {165,
#     1299,
#     1436,
#     4353,
#     4753,
#     4944,
#     17635,
#     17889,
#     21913,
#     22420,
#     24326,
#     24332,
#     26243,
#     26268}),
#   ('Pakistani',
#    {6718,
#     9001,
#     10808,
#     11560,
#     11697,
#     15095,
#     15973,
#     16076,
#     16841,
#     16970,
#     17366,
#     23294},
#    'Pakistan',
#    {504,
#     1281,
#     2428,
#     2707,
#     4469,
#     4775,
#     9024,
#     10446,
#     10514,
#     11161,
#     11760,
#     12309,
#     13553,
#     13745,
#     13885,
#     13977,
#     14647,
#     14818,
#     15130,
#     15193,
#     15326,
#     15451,
#     15601,
#     15887,
#     23190})],
#  [('Dzhokhar Tsarnaev',
#    {321, 961, 990, 1243, 2147, 2783},
#    'Tsarnaev',
#    {460, 805, 1722, 1966, 2576, 2757}),
#   ('Jeff Bauman', {191}, 'spectator', {181}),
#   ('Tsarnaev',
#    {330, 460, 805, 970, 999, 1252, 1722, 1966, 2156, 2576, 2757, 2792},
#    'suspect',
#    {1406, 2027, 2139}),
#   ('brothers', {1731}, 'suspects', {1406, 2027}),
#   ('Rebekah Gregory', {2492}, 'survivor', {53, 2301, 2483}),
#   ('spectator', {181}, 'Bauman', {196, 364, 1452, 1584, 1771}),
#   ('Tamerlan Tsarnaev', {1957}, 'brother', {479, 893, 1214, 1286, 1731, 2814}),
#   ('Tsarnaevs', {805, 2757}, 'suspects', {1406, 2027}),
#   ('Dzhokhar Tsarnaev',
#    {321, 961, 990, 1243, 2147, 2783},
#    'suspect',
#    {1406, 2027, 2139}),
#   ('Jeff Bauman', {191}, 'survivor', {53, 2301, 2483}),
#   ('brother',
#    {479, 893, 1214, 1286, 1731, 2814},
#    'suspect',
#    {1406, 2027, 2139}),
#   ('courthouse', {351, 2088}, 'where', {2099}),
#   ('Tamerlan Tsarnaev', {1957}, 'Tamerlan', {487, 1112, 1157, 1475}),
#   ('Tsarnaevs', {805, 2757}, 'brothers', {1731}),
#   ('Tsarnaev',
#    {330, 460, 805, 970, 999, 1252, 1722, 1966, 2156, 2576, 2757, 2792},
#    'brother',
#    {479, 893, 1214, 1286, 1731, 2814}),
#   ('Jeff Bauman', {191}, 'Bauman', {364, 1452, 1584, 1771}),
#   ('Tamerlan',
#    {487, 1112, 1157, 1475, 1957},
#    'brother',
#    {479, 893, 1214, 1286, 1731, 2814}),
#   ('Rebekah Gregory', {2492}, 'two', {1645, 2368, 2995}),
#   ('Judy Clarke', {1021}, 'lawyer', {598, 911, 1012}),
#   ('spectator', {181}, 'survivor', {53, 2301, 2483}),
#   ('survivor', {53, 2301, 2483}, 'Bauman', {196, 364, 1452, 1584, 1771}),
#   ('Dzhokhar Tsarnaev',
#    {321, 961, 990, 1243, 2147, 2783},
#    'brother',
#    {479, 893, 1214, 1286, 1731, 2814})],
#  [('Winters', {530, 1165, 1730, 2168, 2550, 2755}, 'lawyer', {215, 517, 2537}),
#   ('Kevin Winters', {524, 2544}, 'lawyer', {215, 517, 2537}),
#   ('Maxine', {1604}, 'sister', {1547, 1597, 2105}),
#   ('Six men', {686}, 'people', {254, 495, 1373, 1432}),
#   ('Brother', {1535}, 'Julie', {1554, 2019}),
#   ('Kevin Winters', {524, 2544}, 'Winters', {1165, 1730, 2168, 2755})],
#  [('Asia Siddiqui', {223}, 'Siddiqui', {1909, 2019, 2222, 2550, 3585, 4060}),
#   ('undercover',
#    {325, 814, 3117, 3229, 3748},
#    'officer',
#    {336, 365, 3042, 3128, 3188, 3240, 3272, 3338, 3382}),
#   ('American', {1423, 1590}, 'homeland', {1251}),
#   ('Siddiqui', {228, 1909, 2019, 2222, 2550, 3585, 4060}, 'client', {2064}),
#   ('citizens', {2566}, 'pair', {850}),
#   ('Muhanad Mahmoud Al Farekh', {1293, 1615}, 'Al Farekh', {4386, 4664}),
#   ('Asia Siddiqui', {223}, '31', {1920}),
#   ('American', {1423, 1590}, 'nation', {5045}),
#   ('Siddiqui', {228, 1909, 2019, 2222, 2550, 3585, 4060}, '31', {1920}),
#   ('Noelle Velentzas',
#    {202},
#    'Velentzas',
#    {564, 1856, 2146, 2444, 3098, 3349}),
#   ('New York City', {3021}, 'New York', {173, 1362, 1531, 3899}),
#   ('federal court', {1345, 1671}, 'court', {88, 545, 1274, 1765, 2429}),
#   ('citizens', {2566}, 'women', {903, 1717, 2671}),
#   ('officer',
#    {336, 365, 3042, 3128, 3188, 3240, 3272, 3338, 3382},
#    'agent',
#    {825, 4627}),
#   ('undercover', {325, 814, 3117, 3229, 3748}, 'agent', {825, 4627}),
#   ('officers', {3042, 3272, 3338}, 'two', {3017, 3334, 4405, 4682}),
#   ('Velentzas', {209, 564, 1856, 2146, 2444, 3098, 3349}, '28', {1868}),
#   ('homeland', {1251}, 'nation', {5045}),
#   ('Asia Siddiqui', {223}, 'client', {2064}),
#   ('women', {903, 1717, 2671}, 'pair', {850})],
#  [('victims', {286, 822}, 'people', {179, 2811, 2898, 3056, 3331}),
#   ('loyalists', {1196, 1399, 2046, 2714}, 'loyalist', {1846}),
#   ('Robert Campbell', {2186}, 'member', {653, 1529, 2177, 3183}),
#   ('North Queens Street', {558}, 'area', {740, 960, 1134, 1270, 2134}),
#   ('building', {780}, 'bar', {247, 551, 668, 1953}),
#   ('John Morrow', {2277}, 'workman', {2293})],
#  [],
#  [('Nicolas Maduro', {10, 372, 2012}, 'President', {0, 362, 1061}),
#   ('President', {0, 362, 1061}, 'Maduro', {18, 380, 1071, 2020, 2158, 2800}),
#   ('Nicolas Maduro', {10, 372, 2012}, 'Maduro', {1071, 2158, 2800}),
#   ('Nicolas Maduro', {10, 372, 2012}, 'the president', {606}),
#   ('the president', {606}, 'Maduro', {18, 380, 1071, 2020, 2158, 2800}),
#   ('Nicolas Maduro', {10, 372, 2012}, 'president', {610, 2138}),
#   ('president', {610, 2138}, 'Maduro', {18, 380, 1071, 2020, 2158, 2800}),
#   ('the president', {606}, 'President', {0, 362, 1061}),
#   ('President', {0, 362, 1061}, 'president', {610, 2138})],
#  [],
#  [('suspect', {34, 666, 1007}, 'Omar D', {690, 869}),
#   ('Abdifatah W', {796}, 'companion', {786})]]

# %%
print("#Test Coref: ", sum([sum([len(pairs[1]) * len(pairs[3]) for pairs in ex]) for ex in per_example_result[:test_start]]))
print("#Dev Coref:  ",
      sum([sum([len(pairs[1]) * len(pairs[3]) for pairs in ex]) for ex in per_example_result[test_start:train_start]]))
print("#Train Coref:", sum([sum([len(pairs[1]) * len(pairs[3]) for pairs in ex]) for ex in per_example_result[train_start:]]))
# Out:
# #Test Coref:  3626
# #Dev Coref:   3076
# #Train Coref: 193542

# %%
coref_positive_examples = coref_pairs_non_single_mention

# %%
gtt_tokens = json.load(open("../../Model/GTT/TokenizedDoc/GTT_MUC1700_FullTextTokenized.json"))
gttsent_tokens = json.load(open("../../Model/GTT/TokenizedDoc/GTT_MUC1700_SentCatTokenized.json"))
tanl_tokens = json.load(open("../../Model/TANL/TokenizedDoc/muc1700.json"))
#tanl_sent_tokens = json.load(open("../../Model/TANL/TokenizedDoc/tanl_token_25749.json"))
dygie_tokens = json.load(open("../../Model/Dygie/dygiepp/TokenizedDoc/muc1700_list_of_tokenlist.json"))
rawbert_tokens = json.load(open("../../Model/NaiveBERT/tokenized_muc1700.json"))
model_token_pairs = [(gtt_tokens, "gtt"), (gttsent_tokens, "gtt_sent"), (tanl_tokens, "tanl"),
                     (dygie_tokens, "dygie"), (rawbert_tokens, "raw")]#, (tanl_sent_tokens, "tanl_sent")]


for docid in tqdm(range(example_len )):
    tanl_clean = clean(" ".join(tanl_tokens[docid]))
    for i, (_, model_name) in enumerate(model_token_pairs):
        if "tanl" in model_name:
            continue
        truncate = 0
        total_len = 0
        while total_len < len(tanl_clean):
            total_len += len(clean(model_token_pairs[i][0][docid][truncate]))
            truncate += 1
            if truncate >= len(model_token_pairs[i][0][docid]):
                break
        model_token_pairs[i][0][docid] = model_token_pairs[i][0][docid][:truncate]
# Out:
#   0%|          | 0/246 [00:00<?, ?it/s]

# %%
# Coref
coref_data = defaultdict(lambda: defaultdict(list))
for tokens, model_name in model_token_pairs:
    all_results = set()
    for per_example_pairs, label in [(coref_positive_examples, 1), (coref_negative_examples, 0)]:
        for doc_i, example_pairs in tqdm(enumerate(per_example_pairs)):
            for pair in example_pairs:
                pair0_indices = indices_in_tokenized_text(tokens=tokens[doc_i], role_filler=pair[0])
                pair1_indices = indices_in_tokenized_text(tokens=tokens[doc_i], role_filler=pair[1])
                pair0_indices = set(pair0_indices)
                pair1_indices = set(pair1_indices).difference(pair0_indices)
                for index0 in pair0_indices:
                    for index1 in pair1_indices:
                        result = {"doc_i": doc_i, "index0": index0, "index1": index1, "label": label}
                        if tuple(result.values()) not in all_results:
                            all_results.add(result.values())
                        else:
                            continue
                        coref_data[model_name]["test" if doc_i < 200 else ("dev" if doc_i < 400 else "train")].append(
                            result)
json.dump(coref_data, open("../XY/XY_bool_CoRef.json", "w+"))
# Out:
# 1700it [00:02, 835.69it/s]
# 1700it [00:05, 286.53it/s]
# 1700it [00:01, 869.03it/s]
# 1700it [00:05, 318.55it/s]
# 1700it [00:03, 557.68it/s]
# 1700it [00:08, 208.27it/s]
# 1700it [00:01, 968.34it/s]
# 1700it [00:04, 351.79it/s]
# 1700it [00:01, 885.74it/s]
# 1700it [00:06, 256.31it/s]

# %%
[[len(v[x]) for x in v] for v in coref_data.values()]
# Out:
# [[1479, 1073, 3149],
#  [1479, 1073, 3149],
#  [1483, 1113, 3167],
#  [1487, 1144, 3180],
#  [1487, 1144, 3181]]

# %%
coref_data
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {'gtt': defaultdict(list,
#                          {'test': [{'doc_i': 1,
#                             'index0': 35,
#                             'index1': 59,
#                             'label': 1},
#                            {'doc_i': 1,
#                             'index0': 208,
#                             'index1': 59,
#                             'label': 1},
#                            {'doc_i': 1,
#                             'index0': 146,
#                             'index1': 59,
#                             'label': 1},
#                            {'doc_i': 1,
#                             'index0': 183,
#                             'index1': 59,
#                             'label': 1},
#                            {'doc_i': 1,
#                             'index0': 60,
#                             'index1': 59,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 164,
#                             'index1': 165,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 155,
#                             'index1': 227,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 155,
#                             'index1': 363,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 155,
#                             'index1': 341,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 155,
#                             'index1': 373,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 155,
#                             'index1': 286,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 164,
#                             'index1': 227,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 164,
#                             'index1': 363,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 164,
#                             'index1': 341,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 164,
#                             'index1': 373,
#                             'label': 1},
#                            {'doc_i': 12,
#                             'index0': 164,
#                             'index1': 286,
#                             'label': 1},
#                            {'doc_i': 13,
#                             'index0': 153,
#                             'index1': 154,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 165,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 139,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 17,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 274,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 148,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 245,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 282,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 188,
#                             'label': 1},
#                            {'doc_i': 16,
#                             'index0': 7,
#                             'index1': 221,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 115,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 115,
#                             'index1': 311,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 310,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 310,
#                             'index1': 311,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 115,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 115,
#                             'index1': 311,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 310,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 310,
#                             'index1': 311,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 38,
#                             'index1': 74,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 40,
#                             'index1': 74,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 75,
#                             'index1': 74,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 111,
#                             'index1': 74,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 7,
#                             'index1': 74,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 40,
#                             'index1': 127,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 75,
#                             'index1': 127,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 111,
#                             'index1': 127,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 7,
#                             'index1': 127,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 38,
#                             'index1': 127,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 115,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 115,
#                             'index1': 311,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 310,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 310,
#                             'index1': 311,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 115,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 115,
#                             'index1': 311,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 310,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 17,
#                             'index0': 310,
#                             'index1': 311,
#                             'label': 1},
#                            {'doc_i': 18,
#                             'index0': 14,
#                             'index1': 21,
#                             'label': 1},
#                            {'doc_i': 19,
#                             'index0': 216,
#                             'index1': 217,
#                             'label': 1},
#                            {'doc_i': 19,
#                             'index0': 216,
#                             'index1': 217,
#                             'label': 1},
#                            {'doc_i': 19,
#                             'index0': 216,
#                             'index1': 217,
#                             'label': 1},
#                            {'doc_i': 19,
#                             'index0': 216,
#                             'index1': 217,
#                             'label': 1},
#                            {'doc_i': 21,
#                             'index0': 122,
#                             'index1': 123,
#                             'label': 1},
#                            {'doc_i': 21,
#                             'index0': 122,
#                             'index1': 123,
#                             'label': 1},
#                            {'doc_i': 21,
#                             'index0': 122,
#                             'index1': 123,
#                             'label': 1},
#                            {'doc_i': 21,
#                             'index0': 122,
#                             'index1': 123,
#                             'label': 1},
#                            {'doc_i': 21,
#                             'index0': 67,
#                             'index1': 68,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 161,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 98,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 194,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 290,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 78,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 143,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 18,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 52,
#                             'index1': 91,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 161,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 98,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 290,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 194,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 78,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 143,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 18,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 193,
#                             'index1': 52,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 161,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 98,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 290,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 194,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 78,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 143,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 18,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 97,
#                             'index1': 52,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 161,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 98,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 290,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 194,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 78,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 143,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 18,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 289,
#                             'index1': 52,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 161,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 98,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 290,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 194,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 78,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 143,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 18,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 77,
#                             'index1': 52,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 161,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 98,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 290,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 194,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 78,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 143,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 18,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 142,
#                             'index1': 52,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 161,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 98,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 290,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 194,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 78,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 143,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 18,
#                             'label': 1},
#                            {'doc_i': 23,
#                             'index0': 17,
#                             'index1': 52,
#                             'label': 1},
#                            {'doc_i': 29,
#                             'index0': 72,
#                             'index1': 73,
#                             'label': 1},
#                            {'doc_i': 30,
#                             'index0': 69,
#                             'index1': 70,
#                             'label': 1},
#                            {'doc_i': 31,
#                             'index0': 27,
#                             'index1': 312,
#                             'label': 1},
#                            {'doc_i': 31,
#                             'index0': 316,
#                             'index1': 312,
#                             'label': 1},
#                            {'doc_i': 36,
#                             'index0': 59,
#                             'index1': 99,
#                             'label': 1},
#                            {'doc_i': 36,
#                             'index0': 45,
#                             'index1': 99,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 80,
#                             'index1': 156,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 157,
#                             'index1': 156,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 224,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 3,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 134,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 47,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 241,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 31,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 224,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 241,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 39,
#                             'index0': 31,
#                             'index1': 197,
#                             'label': 1},
#                            {'doc_i': 40,
#                             'index0': 158,
#                             'index1': 160,
#                             'label': 1},
#                            {'doc_i': 40,
#                             'index0': 158,
#                             'index1': 163,
#                             'label': 1},
#                            {'doc_i': 43,
#                             'index0': 21,
#                             'index1': 68,
#                             'label': 1},
#                            {'doc_i': 43,
#                             'index0': 21,
#                             'index1': 68,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 96,
#                             'index1': 207,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 96,
#                             'index1': 225,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 96,
#                             'index1': 116,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 96,
#                             'index1': 207,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 96,
#                             'index1': 206,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 96,
#                             'index1': 206,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 225,
#                             'index1': 206,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 116,
#                             'index1': 206,
#                             'label': 1},
#                            {'doc_i': 45,
#                             'index0': 207,
#                             'index1': 206,
#                             'label': 1},
#                            {'doc_i': 53,
#                             'index0': 236,
#                             'index1': 237,
#                             'label': 1},
#                            {'doc_i': 56,
#                             'index0': 121,
#                             'index1': 178,
#                             'label': 1},
#                            {'doc_i': 56,
#                             'index0': 180,
#                             'index1': 178,
#                             'label': 1},
#                            {'doc_i': 56,
#                             'index0': 32,
#                             'index1': 42,
#                             'label': 1},
#                            {'doc_i': 56,
#                             'index0': 32,
#                             'index1': 266,
#                             'label': 1},
#                            {'doc_i': 56,
#                             'index0': 32,
#                             'index1': 53,
#                             'label': 1},
#                            {'doc_i': 56,
#                             'index0': 32,
#                             'index1': 95,
#                             'label': 1},
#                            {'doc_i': 59,
#                             'index0': 59,
#                             'index1': 78,
#                             'label': 1},
#                            {'doc_i': 59,
#                             'index0': 57,
#                             'index1': 80,
#                             'label': 1},
#                            {'doc_i': 59,
#                             'index0': 57,
#                             'index1': 61,
#                             'label': 1},
#                            {'doc_i': 59,
#                             'index0': 57,
#                             'index1': 103,
#                             'label': 1},
#                            {'doc_i': 59,
#                             'index0': 59,
#                             'index1': 75,
#                             'label': 1},
#                            {'doc_i': 59,
#                             'index0': 59,
#                             'index1': 80,
#                             'label': 1},
#                            {'doc_i': 59,
#                             'index0': 59,
#                             'index1': 61,
#                             'label': 1},
#                            {'doc_i': 59,
#                             'index0': 59,
#                             'index1': 103,
#                             'label': 1},
#                            {'doc_i': 60,
#                             'index0': 320,
#                             'index1': 323,
#                             'label': 1},
#                            {'doc_i': 60,
#                             'index0': 74,
#                             'index1': 72,
#                             'label': 1},
#                            {'doc_i': 60,
#                             'index0': 74,
#                             'index1': 17,
#                             'label': 1},
#                            {'doc_i': 60,
#                             'index0': 20,
#                             'index1': 72,
#                             'label': 1},
#                            {'doc_i': 60,
#                             'index0': 20,
#                             'index1': 17,
#                             'label': 1},
#                            {'doc_i': 60,
#                             'index0': 7,
#                             'index1': 72,
#                             'label': 1},
#                            {'doc_i': 60,
#                             'index0': 7,
#                             'index1': 17,
#                             'label': 1},
#                            {'doc_i': 67,
#                             'index0': 378,
#                             'index1': 380,
#                             'label': 1},
#                            {'doc_i': 67,
#                             'index0': 135,
#                             'index1': 378,
#                             'label': 1},
#                            {'doc_i': 72,
#                             'index0': 89,
#                             'index1': 90,
#                             'label': 1},
#                            {'doc_i': 72,
#                             'index0': 57,
#                             'index1': 69,
#                             'label': 1},
#                            {'doc_i': 73,
#                             'index0': 206,
#                             'index1': 210,
#                             'label': 1},
#                            {'doc_i': 77,
#                             'index0': 120,
#                             'index1': 122,
#                             'label': 1},
#                            {'doc_i': 79,
#                             'index0': 156,
#                             'index1': 166,
#                             'label': 1},
#                            {'doc_i': 79,
#                             'index0': 156,
#                             'index1': 286,
#                             'label': 1},
#                            {'doc_i': 83,
#                             'index0': 78,
#                             'index1': 88,
#                             'label': 1},
#                            {'doc_i': 83,
#                             'index0': 78,
#                             'index1': 164,
#                             'label': 1},
#                            {'doc_i': 84,
#                             'index0': 252,
#                             'index1': 253,
#                             'label': 1},
#                            {'doc_i': 87,
#                             'index0': 35,
#                             'index1': 87,
#                             'label': 1},
#                            {'doc_i': 87,
#                             'index0': 197,
#                             'index1': 87,
#                             'label': 1},
#                            {'doc_i': 87,
#                             'index0': 69,
#                             'index1': 87,
#                             'label': 1},
#                            {'doc_i': 87,
#                             'index0': 76,
#                             'index1': 87,
#                             'label': 1},
#                            {'doc_i': 87,
#                             'index0': 302,
#                             'index1': 87,
#                             'label': 1},
#                            {'doc_i': 90,
#                             'index0': 63,
#                             'index1': 159,
#                             'label': 1},
#                            {'doc_i': 90,
#                             'index0': 160,
#                             'index1': 159,
#                             'label': 1},
#                            {'doc_i': 90,
#                             'index0': 180,
#                             'index1': 159,
#                             'label': 1},
#                            {'doc_i': 90,
#                             'index0': 71,
#                             'index1': 159,
#                             'label': 1},
#                            {'doc_i': 90,
#                             'index0': 183,
#                             'index1': 188,
#                             'label': 1},
#                            {'doc_i': 90,
#                             'index0': 183,
#                             'index1': 184,
#                             'label': 1},
#                            {'doc_i': 93,
#                             'index0': 108,
#                             'index1': 161,
#                             'label': 1},
#                            {'doc_i': 93,
#                             'index0': 108,
#                             'index1': 330,
#                             'label': 1},
#                            {'doc_i': 93,
#                             'index0': 108,
#                             'index1': 110,
#                             'label': 1},
#                            {'doc_i': 93,
#                             'index0': 108,
#                             'index1': 232,
#                             'label': 1},
#                            {'doc_i': 93,
#                             'index0': 108,
#                             'index1': 202,
#                             'label': 1},
#                            {'doc_i': 93,
#                             'index0': 108,
#                             'index1': 202,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 7,
#                             'index1': 230,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 7,
#                             'index1': 312,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 249,
#                             'index1': 312,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 230,
#                             'index1': 312,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 65,
#                             'index1': 312,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 7,
#                             'index1': 312,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 226,
#                             'index1': 256,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 226,
#                             'index1': 38,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 74,
#                             'index1': 256,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 74,
#                             'index1': 38,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 14,
#                             'index1': 256,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 14,
#                             'index1': 38,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 186,
#                             'index1': 256,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 186,
#                             'index1': 38,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 283,
#                             'index1': 256,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 283,
#                             'index1': 38,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 65,
#                             'index1': 230,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 7,
#                             'index1': 230,
#                             'label': 1},
#                            {'doc_i': 96,
#                             'index0': 159,
#                             'index1': 169,
#                             'label': 1},
#                            {'doc_i': 97,
#                             'index0': 41,
#                             'index1': 43,
#                             'label': 1},
#                            {'doc_i': 97,
#                             'index0': 41,
#                             'index1': 204,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 224,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 144,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 49,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 180,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 21,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 224,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 144,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 49,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 180,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 21,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 56,
#                             'index1': 120,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 56,
#                             'index1': 57,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 209,
#                             'index1': 219,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 224,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 144,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 49,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 180,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 98,
#                             'index0': 21,
#                             'index1': 205,
#                             'label': 1},
#                            {'doc_i': 100,
#                             'index0': 50,
#                             'index1': 53,
#                             'label': 1},
#                            {'doc_i': 100,
#                             'index0': 50,
#                             'index1': 53,
#                             'label': 1},
#                            {'doc_i': 100,
#                             'index0': 50,
#                             'index1': 53,
#                             'label': 1},
#                            {'doc_i': 100,
#                             'index0': 116,
#                             'index1': 123,
#                             'label': 1},
#                            {'doc_i': 100,
#                             'index0': 116,
#                             'index1': 118,
#                             'label': 1},
#                            {'doc_i': 105,
#                             'index0': 52,
#                             'index1': 134,
#                             'label': 1},
#                            {'doc_i': 106,
#                             'index0': 139,
#                             'index1': 140,
#                             'label': 1},
#                            {'doc_i': 106,
#                             'index0': 72,
#                             'index1': 74,
#                             'label': 1},
#                            {'doc_i': 114,
#                             'index0': 264,
#                             'index1': 341,
#                             'label': 1},
#                            {'doc_i': 115,
#                             'index0': 43,
#                             'index1': 146,
#                             'label': 1},
#                            {'doc_i': 115,
#                             'index0': 43,
#                             'index1': 44,
#                             'label': 1},
#                            {'doc_i': 115,
#                             'index0': 31,
#                             'index1': 33,
#                             'label': 1},
#                            {'doc_i': 115,
#                             'index0': 31,
#                             'index1': 155,
#                             'label': 1},
#                            {'doc_i': 115,
#                             'index0': 43,
#                             'index1': 146,
#                             'label': 1},
#                            {'doc_i': 115,
#                             'index0': 43,
#                             'index1': 44,
#                             'label': 1},
#                            {'doc_i': 115,
#                             'index0': 43,
#                             'index1': 146,
#                             'label': 1},
#                            {'doc_i': 115,
#                             'index0': 43,
#                             'index1': 44,
#                             'label': 1},
#                            {'doc_i': 118,
#                             'index0': 19,
#                             'index1': 23,
#                             'label': 1},
#                            {'doc_i': 121,
#                             'index0': 23,
#                             'index1': 25,
#                             'label': 1},
#                            {'doc_i': 121,
#                             'index0': 23,
#                             'index1': 42,
#                             'label': 1},
#                            {'doc_i': 121,
#                             'index0': 23,
#                             'index1': 79,
#                             'label': 1},
#                            {'doc_i': 123,
#                             'index0': 124,
#                             'index1': 246,
#                             'label': 1},
#                            {'doc_i': 123,
#                             'index0': 225,
#                             'index1': 246,
#                             'label': 1},
#                            {'doc_i': 123,
#                             'index0': 291,
#                             'index1': 246,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 21,
#                             'index1': 134,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 211,
#                             'index1': 210,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 180,
#                             'index1': 210,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 198,
#                             'index1': 210,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 14,
#                             'index1': 210,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 13,
#                             'index1': 206,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 21,
#                             'index1': 128,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 21,
#                             'index1': 164,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 21,
#                             'index1': 134,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 21,
#                             'index1': 105,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 21,
#                             'index1': 86,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 21,
#                             'index1': 23,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 21,
#                             'index1': 120,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 13,
#                             'index1': 207,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 211,
#                             'index1': 207,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 180,
#                             'index1': 207,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 198,
#                             'index1': 207,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 14,
#                             'index1': 207,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 211,
#                             'index1': 206,
#                             'label': 1},
#                            {'doc_i': 127,
#                             'index0': 180,
# ...
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 249,
#                             'index1': 283,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 249,
#                             'index1': 172,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 108,
#                             'index1': 257,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 108,
#                             'index1': 283,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 108,
#                             'index1': 172,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 237,
#                             'index1': 257,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 237,
#                             'index1': 283,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 237,
#                             'index1': 172,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 242,
#                             'index1': 257,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 242,
#                             'index1': 283,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 242,
#                             'index1': 172,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 119,
#                             'index1': 257,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 119,
#                             'index1': 283,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 119,
#                             'index1': 172,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 121,
#                             'index1': 257,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 121,
#                             'index1': 283,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 121,
#                             'index1': 172,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 241,
#                             'index1': 257,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 241,
#                             'index1': 283,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 241,
#                             'index1': 172,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 17,
#                             'index1': 272,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 17,
#                             'index1': 209,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 17,
#                             'index1': 246,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 17,
#                             'index1': 257,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 17,
#                             'index1': 283,
#                             'label': 1},
#                            {'doc_i': 1521,
#                             'index0': 17,
#                             'index1': 172,
#                             'label': 1},
#                            {'doc_i': 1522,
#                             'index0': 172,
#                             'index1': 173,
#                             'label': 1},
#                            {'doc_i': 1522,
#                             'index0': 172,
#                             'index1': 173,
#                             'label': 1},
#                            {'doc_i': 1522,
#                             'index0': 172,
#                             'index1': 173,
#                             'label': 1},
#                            {'doc_i': 1522,
#                             'index0': 172,
#                             'index1': 173,
#                             'label': 1},
#                            {'doc_i': 1522,
#                             'index0': 17,
#                             'index1': 113,
#                             'label': 1},
#                            {'doc_i': 1522,
#                             'index0': 17,
#                             'index1': 27,
#                             'label': 1},
#                            {'doc_i': 1522,
#                             'index0': 17,
#                             'index1': 142,
#                             'label': 1},
#                            {'doc_i': 1526,
#                             'index0': 32,
#                             'index1': 125,
#                             'label': 1},
#                            {'doc_i': 1526,
#                             'index0': 127,
#                             'index1': 125,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 17,
#                             'index1': 20,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 245,
#                             'index1': 20,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 303,
#                             'index1': 20,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 160,
#                             'index1': 168,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 152,
#                             'index1': 169,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 109,
#                             'index1': 110,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 160,
#                             'index1': 169,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 168,
#                             'index1': 169,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 302,
#                             'index1': 303,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 103,
#                             'index1': 131,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 103,
#                             'index1': 173,
#                             'label': 1},
#                            {'doc_i': 1527,
#                             'index0': 152,
#                             'index1': 169,
#                             'label': 1},
#                            {'doc_i': 1529,
#                             'index0': 105,
#                             'index1': 239,
#                             'label': 1},
#                            {'doc_i': 1529,
#                             'index0': 242,
#                             'index1': 239,
#                             'label': 1},
#                            {'doc_i': 1529,
#                             'index0': 29,
#                             'index1': 239,
#                             'label': 1},
#                            {'doc_i': 1531,
#                             'index0': 10,
#                             'index1': 19,
#                             'label': 1},
#                            {'doc_i': 1531,
#                             'index0': 10,
#                             'index1': 47,
#                             'label': 1},
#                            {'doc_i': 1531,
#                             'index0': 10,
#                             'index1': 95,
#                             'label': 1},
#                            {'doc_i': 1531,
#                             'index0': 10,
#                             'index1': 19,
#                             'label': 1},
#                            {'doc_i': 1531,
#                             'index0': 10,
#                             'index1': 47,
#                             'label': 1},
#                            {'doc_i': 1531,
#                             'index0': 10,
#                             'index1': 95,
#                             'label': 1},
#                            {'doc_i': 1538,
#                             'index0': 67,
#                             'index1': 112,
#                             'label': 1},
#                            {'doc_i': 1538,
#                             'index0': 67,
#                             'index1': 73,
#                             'label': 1},
#                            {'doc_i': 1538,
#                             'index0': 67,
#                             'index1': 253,
#                             'label': 1},
#                            {'doc_i': 1538,
#                             'index0': 67,
#                             'index1': 183,
#                             'label': 1},
#                            {'doc_i': 1542,
#                             'index0': 220,
#                             'index1': 218,
#                             'label': 1},
#                            {'doc_i': 1542,
#                             'index0': 220,
#                             'index1': 42,
#                             'label': 1},
#                            {'doc_i': 1542,
#                             'index0': 45,
#                             'index1': 218,
#                             'label': 1},
#                            {'doc_i': 1542,
#                             'index0': 45,
#                             'index1': 42,
#                             'label': 1},
#                            {'doc_i': 1542,
#                             'index0': 220,
#                             'index1': 218,
#                             'label': 1},
#                            {'doc_i': 1542,
#                             'index0': 45,
#                             'index1': 218,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 19,
#                             'index1': 81,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 24,
#                             'index1': 88,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 56,
#                             'index1': 88,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 187,
#                             'index1': 88,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 215,
#                             'index1': 88,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 19,
#                             'index1': 88,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 24,
#                             'index1': 81,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 56,
#                             'index1': 81,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 187,
#                             'index1': 81,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 215,
#                             'index1': 81,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 24,
#                             'index1': 186,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 24,
#                             'index1': 214,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 24,
#                             'index1': 55,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 56,
#                             'index1': 186,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 56,
#                             'index1': 214,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 56,
#                             'index1': 55,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 187,
#                             'index1': 186,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 187,
#                             'index1': 214,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 187,
#                             'index1': 55,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 215,
#                             'index1': 186,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 215,
#                             'index1': 214,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 215,
#                             'index1': 55,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 19,
#                             'index1': 24,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 19,
#                             'index1': 56,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 19,
#                             'index1': 187,
#                             'label': 1},
#                            {'doc_i': 1545,
#                             'index0': 19,
#                             'index1': 215,
#                             'label': 1},
#                            {'doc_i': 1549,
#                             'index0': 176,
#                             'index1': 177,
#                             'label': 1},
#                            {'doc_i': 1549,
#                             'index0': 26,
#                             'index1': 280,
#                             'label': 1},
#                            ...]})})

# %%
sum([sum([len(x) for x in c]) for c in coenv_positive_examples])
# Out:
# 7168

# %%
sum([sum([len(x) for x in c]) for c in coenv_negative_examples])
# Out:
# 10798

# %%
# Coenv
coenv_data = defaultdict(lambda: defaultdict(list))
for tokens, model_name in model_token_pairs:
    all_results = set()
    for per_example_pairs, label in [(coenv_positive_examples, 1), (coenv_negative_examples, 0)]:
        for doc_i, example_pairs in tqdm(enumerate(per_example_pairs)):
            for pair in example_pairs:
                pair0_indices = indices_in_tokenized_text(tokens=tokens[doc_i], role_filler=pair[0])
                pair1_indices = indices_in_tokenized_text(tokens=tokens[doc_i], role_filler=pair[1])
                pair0_indices = set(pair0_indices)
                pair1_indices = set(pair1_indices).difference(pair0_indices)
                for index0 in pair0_indices:
                    for index1 in pair1_indices:
                        result = {"doc_i": doc_i, "index0": index0, "index1": index1, "label": label}
                        if tuple(result.values()) not in all_results:
                            all_results.add(result.values())
                        else:
                            continue
                        coenv_data[model_name]["test" if doc_i < 200 else ("dev" if doc_i < 400 else "train")].append(result)
json.dump(coenv_data, open("../XY/XY_bool_CoEnv.json", "w+"))
# Out:
# 1700it [00:08, 202.85it/s]
# 1700it [00:13, 124.87it/s]
# 1700it [00:06, 243.75it/s]
# 1700it [00:12, 137.15it/s]
# 1700it [00:11, 145.35it/s]
# 1700it [00:15, 107.08it/s]
# 1700it [00:06, 277.30it/s]
# 1700it [00:10, 160.32it/s]
# 1700it [00:07, 241.04it/s]
# 1700it [00:11, 145.68it/s]

# %%
[(k, [len(v[x]) for x in v]) for k, v in coenv_data.items()]
# Out:
# [('gtt', [1216, 1204, 4056]),
#  ('gtt_sent', [1216, 1204, 4056]),
#  ('tanl', [1218, 1244, 4059]),
#  ('dygie', [1239, 1291, 4161]),
#  ('raw', [1239, 1291, 4157])]

# %%
# Typing
typing_data = defaultdict(lambda: defaultdict(list))
for tokens, model_name in model_token_pairs:
    all_results = set()
    for doc_i, example_pairs in tqdm(enumerate(event_typing_examples)):
        for pair in example_pairs:
            label = pair[2]
            pair0_indices = indices_in_tokenized_text(tokens=tokens[doc_i], role_filler=pair[0])
            pair1_indices = indices_in_tokenized_text(tokens=tokens[doc_i], role_filler=pair[1])
            pair0_indices = set(pair0_indices)
            pair1_indices = set(pair1_indices).difference(pair0_indices)
            for index0 in pair0_indices:
                for index1 in pair1_indices:
                    result = {"doc_i": doc_i, "index0": index0, "index1": index1, "label": label}
                    if tuple(result.values()) not in all_results:
                        all_results.add(result.values())
                    else:
                        continue
                    typing_data[model_name]["test" if doc_i < 200 else ("dev" if doc_i < 400 else "train")].append(result)
json.dump(typing_data, open("../XY/XY_6way_typing.json", "w+"))
# Out:
# 1700it [00:07, 226.32it/s]
# 1700it [00:07, 230.12it/s]
# 1700it [00:11, 143.54it/s]
# 1700it [00:06, 257.07it/s]
# 1700it [00:07, 238.69it/s]

# %%
[(k, [len(v[x]) for x in v]) for k, v in typing_data.items()]
# Out:
# [('gtt', [619, 542, 1843]),
#  ('gtt_sent', [619, 542, 1843]),
#  ('tanl', [622, 547, 1871]),
#  ('dygie', [642, 552, 1895]),
#  ('raw', [642, 552, 1891])]

# %%
# Role labeling
rolelabeling_data = defaultdict(lambda: defaultdict(list))
for tokens, model_name in model_token_pairs:
    all_results = set()
    for doc_i, example_pairs in tqdm(enumerate(roling_examples)):
        for pair in example_pairs:
            label = pair[1]
            pair0_indices = indices_in_tokenized_text(tokens=tokens[doc_i], role_filler=pair[0])
            pair0_indices = set(pair0_indices)
            for index0 in pair0_indices:
                result = {"doc_i": doc_i, "index0": index0, "label": label}
                if tuple(result.values()) not in all_results:
                    all_results.add(result.values())
                else:
                    continue
                rolelabeling_data[model_name]["test" if doc_i < 200 else ("dev" if doc_i < 400 else "train")].append(result)
json.dump(rolelabeling_data, open("../XY/XY_5way_rolelabeling.json", "w+"))
# Out:
# 1700it [00:04, 355.08it/s]
# 1700it [00:05, 326.32it/s]
# 1700it [00:07, 222.06it/s]
# 1700it [00:04, 388.87it/s]
# 1700it [00:04, 364.56it/s]

# %%
[(k, [len(v[x]) for x in v]) for k, v in rolelabeling_data.items()]
# Out:
# [('gtt', [1196, 994, 4535]),
#  ('gtt_sent', [1196, 994, 4535]),
#  ('tanl', [1186, 993, 4497]),
#  ('dygie', [1190, 1001, 4536]),
#  ('raw', [1190, 1001, 4533])]

# %%
# Argument Detection
isarg_data = defaultdict(lambda: defaultdict(list))
for tokens, model_name in model_token_pairs:
    all_results = set()
    for ne_examples, label in  [(ne_pos_examples, 1), (ne_neg_examples, 0)]:
        for doc_i, mentions in tqdm(enumerate(ne_examples)):
            for mention in mentions:
                pair0_indices = indices_in_tokenized_text(tokens=tokens[doc_i], role_filler=mention)
                pair0_indices = set(pair0_indices)
                for index0 in pair0_indices:
                    result = {"doc_i": doc_i, "index0": index0, "label": label}
                    if tuple(result.values()) not in all_results:
                        all_results.add(result.values())
                    else:
                        continue
                    isarg_data[model_name]["test" if doc_i < 200 else ("dev" if doc_i < 400 else "train")].append(result)
json.dump(isarg_data, open("../XY/XY_bool_isArg.json", "w+"))
# Out:
# 1700it [00:03, 487.95it/s]
# 1700it [00:06, 260.38it/s]
# 1700it [00:03, 501.87it/s]
# 1700it [00:06, 265.74it/s]
# 1700it [00:05, 284.09it/s]
# 1700it [00:08, 190.04it/s]
# 1700it [00:02, 578.54it/s]
# 1700it [00:07, 220.75it/s]
# 1700it [00:03, 515.23it/s]
# 1700it [00:06, 271.11it/s]

# %%
[(k, [len(v[x]) for x in v]) for k, v in isarg_data.items()]
# Out:
# [('gtt', [1679, 1750, 9406]),
#  ('gtt_sent', [1679, 1750, 9407]),
#  ('tanl', [1671, 1754, 9428]),
#  ('dygie', [1675, 1756, 9454]),
#  ('raw', [1683, 1761, 9458])]
